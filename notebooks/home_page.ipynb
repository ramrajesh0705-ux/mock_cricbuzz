# %%
st.set_page_config(page_title="🏏 Cricbuzz App", page_icon="🏏", layout="wide")

# Hide Streamlit’s default sidebar navigation
st.markdown("""
    <style>
    [data-testid="stSidebarNav"] {display: none;}
    </style>
""", unsafe_allow_html=True)

# Create custom sidebar menu
st.sidebar.title("Cricbuzz Menu")
page = st.sidebar.radio(
    "Select a page:",
    ["","Live Matches", "Player Stats", "Sql Analysis","Crud Operations"]
)

if page     == "Live Matches":
    st.switch_page("pages\live_matches.py")
elif page   == "Player Stats":
    st.switch_page("pages\player_stats.py")
elif page   == "Sql Analysis":
    st.switch_page("pages\sql_queries.py")
elif page   == "Crud Operations":
    st.switch_page("pages\crud_operations.py")
