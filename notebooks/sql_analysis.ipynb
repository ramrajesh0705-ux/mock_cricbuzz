# %%
resp = {
  "seriesMapProto": [
    {
      "date": "DECEMBER 2021",
      "series": [
        {
          "id": 3858,
          "name": "West Indies tour of Pakistan, 2021-22",
          "startDt": "1639353600000",
          "endDt": "1654992000000"
        }
      ]
    },
    {
      "date": "MAY 2022",
      "series": [
        {
          "id": 4168,
          "name": "Finland tour of Denmark, 2022",
          "startDt": "1651881600000",
          "endDt": "1651968000000"
        },
        {
          "id": 4100,
          "name": "Sri Lanka tour of Bangladesh, 2022",
          "startDt": "1652227200000",
          "endDt": "1653609600000"
        },
        {
          "id": 4149,
          "name": "Namibia tour of Zimbabwe, 2022",
          "startDt": "1652745600000",
          "endDt": "1653350400000"
        },
        {
          "id": 3806,
          "name": "West Indies tour of Netherlands, 2022",
          "startDt": "1653955200000",
          "endDt": "1654300800000"
        }
      ]
    },
    {
      "date": "JUNE 2022",
      "series": [
        {
          "id": 3641,
          "name": "New Zealand tour of England, 2022",
          "startDt": "1654128000000",
          "endDt": "1656288000000"
        },
        {
          "id": 4086,
          "name": "Australia tour of Sri Lanka, 2022",
          "startDt": "1654560000000",
          "endDt": "1657584000000"
        },
        {
          "id": 3697,
          "name": "South Africa tour of India, 2022",
          "startDt": "1654732800000",
          "endDt": "1655596800000"
        },
        {
          "id": 4156,
          "name": "Afghanistan tour of Zimbabwe, 2022",
          "startDt": "1654992000000",
          "endDt": "1656288000000"
        },
        {
          "id": 3722,
          "name": "England tour of Netherlands, 2022",
          "startDt": "1655424000000",
          "endDt": "1655856000000"
        },
        {
          "id": 4041,
          "name": "India tour of Ireland, 2022",
          "startDt": "1656201600000",
          "endDt": "1656374400000"
        }
      ]
    },
    {
      "date": "JULY 2022",
      "series": [
        {
          "id": 3636,
          "name": "India tour of England, 2022",
          "startDt": "1656633600000",
          "endDt": "1658016000000"
        },
        {
          "id": 4046,
          "name": "New Zealand tour of Ireland, 2022",
          "startDt": "1657411200000",
          "endDt": "1658448000000"
        },
        {
          "id": 3646,
          "name": "South Africa tour of England, 2022",
          "startDt": "1658188800000",
          "endDt": "1662940800000"
        },
        {
          "id": 4091,
          "name": "New Zealand tour of Scotland, 2022",
          "startDt": "1658880000000",
          "endDt": "1659225600000"
        }
      ]
    },
    {
      "date": "AUGUST 2022",
      "series": [
        {
          "id": 4051,
          "name": "South Africa v Ireland in England, 2022",
          "startDt": "1659484800000",
          "endDt": "1659657600000"
        },
        {
          "id": 4107,
          "name": "New Zealand tour of Netherlands, 2022",
          "startDt": "1659571200000",
          "endDt": "1659744000000"
        },
        {
          "id": 4079,
          "name": "Afghanistan tour of Ireland, 2022",
          "startDt": "1660003200000",
          "endDt": "1660694400000"
        },
        {
          "id": 2913,
          "name": "Pakistan tour of Netherlands, 2022",
          "startDt": "1660608000000",
          "endDt": "1661040000000"
        }
      ]
    },
    {
      "date": "OCTOBER 2022",
      "series": [
        {
          "id": 3961,
          "name": "ICC Mens T20 World Cup 2022",
          "startDt": "1665878400000",
          "endDt": "1668297600000"
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}
list_series_ids = []
matches_ids     = []

for serieslist in resp.get("seriesMapProto",[]):
    for series in serieslist.get('series'):
        list_series_ids.append(series.get('id'))

print(list_series_ids)
# Out:
# [3858, 4168, 4100, 4149, 3806, 3641, 4086, 3697, 4156, 3722, 4041, 3636, 4046, 3646, 4091, 4051, 4107, 4079, 2913, 3961]

# %%
import requests
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "7af441ff3amsh5fb3bebbee58c85p10232fjsnc79fc7ab09f3",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
       # print(response.json())
        return response.json()
    
    except Exception as ex:
        print(ex)
        return {}
    

#series_id_list = [8553, 9297, 8044, 9171, 9265, 9289, 8058, 8494, 7853, 9132, 7745, 9129, 8116, 9125, 9146, 9083, 8404, 9091, 7781, 8107, 9157, 9033, 9041, 9025, 9115, 9043, 8395, 9009, 9057, 8497, 9017, 8947, 8598, 8955, 7981, 8969, 8835, 8393, 8818, 8661, 6794, 8625, 8552, 8764, 8632, 8596, 8495, 8686, 8587, 6787, 8578, 8238, 8528, 7979, 8476, 8337, 7546, 6780, 8422, 8382, 8413, 8310, 8260, 8332, 8256, 8294, 7476, 8247, 8166, 8103, 6773, 7700, 7819, 7808, 8080, 7896, 7706, 8042, 7679, 7817, 7667, 7900, 7693, 7727, 7790, 7672, 7686, 7590, 7644, 7637, 7586, 7534, 7623, 7485, 7618, 7583, 6899, 7572, 7558, 7579, 7553, 7481, 6892, 7511, 6927, 6885, 6920, 6297, 7411]
series_id_list = [8553]
matches_ids_list = []
for series_id in series_id_list:
  print(series_id)
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      #print(mathcDetails)
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
          matches_ids_list.append(i.get('matchInfo',{}).get('matchId'))
# Out:
# 8553
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/8553

# %%
response_2025_2026 = {
  "seriesMapProto": [
    {
      "date": "FEBRUARY 2024",
      "series": [
        {
          "id": 7572,
          "name": "ICC Cricket World Cup League Two 2023-27",
          "startDt": "1707955200000",
          "endDt": "1806364800000"
        }
      ]
    },
    {
      "date": "OCTOBER 2025",
      "series": [
        {
          "id": 10895,
          "name": "South Africa tour of Pakistan, 2025",
          "startDt": "1760227200000",
          "endDt": "1762560000000"
        },
        {
          "id": 10955,
          "name": "West Indies tour of Bangladesh, 2025",
          "startDt": "1760745600000",
          "endDt": "1761868800000"
        },
        {
          "id": 10212,
          "name": "England tour of New Zealand, 2025",
          "startDt": "1760745600000",
          "endDt": "1761955200000"
        },
        {
          "id": 9596,
          "name": "India tour of Australia, 2025",
          "startDt": "1760832000000",
          "endDt": "1762560000000"
        },
        {
          "id": 11052,
          "name": "Afghanistan tour of Zimbabwe 2025",
          "startDt": "1760918400000",
          "endDt": "1762041600000"
        },
        {
          "id": 11089,
          "name": "South American Mens Championships 2025",
          "startDt": "1761782400000",
          "endDt": "1761955200000"
        },
        {
          "id": 11062,
          "name": "Cyprus Tri-Series 2025",
          "startDt": "1761868800000",
          "endDt": "1762041600000"
        }
      ]
    },
    {
      "date": "NOVEMBER 2025",
      "series": [
        {
          "id": 11069,
          "name": "Bulgaria tour of Cyprus 2025",
          "startDt": "1762128000000",
          "endDt": "1762128000000"
        },
        {
          "id": 10223,
          "name": "West Indies tour of New Zealand, 2025",
          "startDt": "1762300800000",
          "endDt": "1766361600000"
        },
        {
          "id": 11108,
          "name": "Indonesia Tri-Series 2025",
          "startDt": "1762387200000",
          "endDt": "1763078400000"
        },
        {
          "id": 10972,
          "name": "Ireland tour of Bangladesh, 2025",
          "startDt": "1762819200000",
          "endDt": "1764633600000"
        },
        {
          "id": 10933,
          "name": "Sri Lanka tour of Pakistan 2025",
          "startDt": "1762819200000",
          "endDt": "1763164800000"
        },
        {
          "id": 9638,
          "name": "South Africa tour of India, 2025",
          "startDt": "1763078400000",
          "endDt": "1766102400000"
        },
        {
          "id": 10906,
          "name": "Pakistan T20I Tri-Series 2025",
          "startDt": "1763337600000",
          "endDt": "1764374400000"
        },
        {
          "id": 9107,
          "name": "The Ashes, 2025-26",
          "startDt": "1763683200000",
          "endDt": "1767830400000"
        }
      ]
    },
    {
      "date": "DECEMBER 2025",
      "series": [
        {
          "id": 11132,
          "name": "Bahrain tour of Bhutan, 2025",
          "startDt": "1765152000000",
          "endDt": "1765670400000"
        },
        {
          "id": 11141,
          "name": "Myanmar tour of Bhutan, 2025",
          "startDt": "1766448000000",
          "endDt": "1766966400000"
        }
      ]
    },
    {
      "date": "JANUARY 2026",
      "series": [
        {
          "id": 10102,
          "name": "New Zealand tour of India, 2026",
          "startDt": "1768089600000",
          "endDt": "1769817600000"
        },
        {
          "id": 10774,
          "name": "England tour of Sri Lanka 2026",
          "startDt": "1769040000000",
          "endDt": "1770076800000"
        },
        {
          "id": 9551,
          "name": "West Indies tour of South Africa, 2026",
          "startDt": "1769472000000",
          "endDt": "1770336000000"
        }
      ]
    },
    {
      "date": "MARCH 2026",
      "series": [
        {
          "id": 10234,
          "name": "South Africa tour of New Zealand, 2026",
          "startDt": "1773532800000",
          "endDt": "1774396800000"
        }
      ]
    },
    {
      "date": "JUNE 2026",
      "series": [
        {
          "id": 10559,
          "name": "New Zealand tour of England, 2026",
          "startDt": "1780531200000",
          "endDt": "1782691200000"
        },
        {
          "id": 10532,
          "name": "India tour of England, 2026",
          "startDt": "1782864000000",
          "endDt": "1784419200000"
        }
      ]
    },
    {
      "date": "AUGUST 2026",
      "series": [
        {
          "id": 10565,
          "name": "Pakistan tour of England 2026",
          "startDt": "1787097600000",
          "endDt": "1788912000000"
        }
      ]
    },
    {
      "date": "SEPTEMBER 2026",
      "series": [
        {
          "id": 10576,
          "name": "Sri Lanka tour of England, 2026",
          "startDt": "1789430400000",
          "endDt": "1790467200000"
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
          "name": "Australia tour of Sri Lanka, 2025",
          "startDt": "1738108800000",
          "endDt": "1739491200000",
          "thumborImageId": 379130
        },
        {
          "id": 8402,
          "name": "England tour of India, 2025",
          "startDt": "1737504000000",
          "endDt": "1739318400000",
          "thumborImageId": 379130
        },
        {
          "id": 8504,
          "name": "West Indies tour of Pakistan, 2025",
          "startDt": "1736467200000",
          "endDt": "1738022400000",
          "thumborImageId": 379130
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

response_2024 = {
  "seriesMapProto": [
    {
      "date": "2024",
      "series": [
        {
          "id": 8553,
          "name": "Sri Lanka tour of New Zealand, 2024-25",
          "startDt": "1734912000000",
          "endDt": "1736553600000",
          "thumborImageId": 379130
        },
        {
          "id": 9297,
          "name": "Gulf Cricket T20I Championship, 2024",
          "startDt": "1734048000000",
          "endDt": "1734739200000",
          "thumborImageId": 379130
        },
        {
          "id": 8044,
          "name": "Pakistan tour of South Africa, 2024 -25",
          "startDt": "1733788800000",
          "endDt": "1736208000000",
          "thumborImageId": 379130
        },
        {
          "id": 9171,
          "name": "Afghanistan tour of Zimbabwe, 2024-25",
          "startDt": "1733702400000",
          "endDt": "1736121600000",
          "thumborImageId": 379130
        },
        {
          "id": 9265,
          "name": "ICC Mens T20 World Cup Americas Sub Regional Qualifier, 2024",
          "startDt": "1733443200000",
          "endDt": "1734307200000",
          "thumborImageId": 379130
        },
        {
          "id": 9289,
          "name": "Africa Continental Cup 2024",
          "startDt": "1733270400000",
          "endDt": "1734134400000",
          "thumborImageId": 379130
        },
        {
          "id": 8058,
          "name": "Sri Lanka tour of South Africa, 2024",
          "startDt": "1732665600000",
          "endDt": "1733702400000",
          "thumborImageId": 379130
        },
        {
          "id": 8494,
          "name": "Pakistan tour of Zimbabwe, 2024",
          "startDt": "1732406400000",
          "endDt": "1733356800000",
          "isFantasyHandbookEnabled": True,
          "thumborImageId": 379130
        },
        {
          "id": 7853,
          "name": "England tour of New Zealand, 2024",
          "startDt": "1732320000000",
          "endDt": "1734480000000",
          "thumborImageId": 379130
        },
        {
          "id": 9132,
          "name": "ICC Mens T20 World Cup Africa Sub Regional Qualifier C 2024",
          "startDt": "1732320000000",
          "endDt": "1732752000000",
          "thumborImageId": 379130
        },
        {
          "id": 7745,
          "name": "India tour of Australia, 2024-25",
          "startDt": "1732233600000",
          "endDt": "1736208000000",
          "thumborImageId": 379130
        },
        {
          "id": 9129,
          "name": "ICC Mens T20 World Cup Asia Qualifier B 2024",
          "startDt": "1731974400000",
          "endDt": "1732752000000",
          "thumborImageId": 379130
        },
        {
          "id": 8116,
          "name": "Bangladesh tour of West Indies, 2024",
          "startDt": "1731801600000",
          "endDt": "1734566400000",
          "isFantasyHandbookEnabled": True,
          "thumborImageId": 379130
        },
        {
          "id": 9125,
          "name": "Netherlands tour of Oman, 2024",
          "startDt": "1731456000000",
          "endDt": "1731715200000",
          "thumborImageId": 379130
        },
        {
          "id": 9146,
          "name": "Myanmar tour of Indonesia, 2024",
          "startDt": "1731369600000",
          "endDt": "1731974400000",
          "thumborImageId": 379130
        },
        {
          "id": 9083,
          "name": "New Zealand tour of Sri Lanka, 2024",
          "startDt": "1731110400000",
          "endDt": "1731974400000",
          "isFantasyHandbookEnabled": True,
          "thumborImageId": 379130
        },
        {
          "id":
        {
          "id": 7485,
          "name": "Afghanistan v Ireland in UAE, 2024",
          "startDt": "1709078400000",
          "endDt": "1710720000000",
          "thumborImageId": 379130
        },
        {
          "id": 7618,
          "name": "Hong Kong tour of Qatar 2024",
          "startDt": "1708992000000",
          "endDt": "1709251200000",
          "thumborImageId": 379130
        },
        {
          "id": 7583,
          "name": "Nepal T20I Tri-Series 2024",
          "startDt": "1708992000000",
          "endDt": "1709596800000",
          "thumborImageId": 379130
        },
        {
          "id": 6899,
          "name": "Australia tour of New Zealand, 2024",
          "startDt": "1708473600000",
          "endDt": "1710201600000",
          "thumborImageId": 379130
        },
        {
          "id": 7572,
          "name": "ICC Cricket World Cup League Two 2023-27",
          "startDt": "1707955200000",
          "endDt": "1806364800000",
          "thumborImageId": 379130
        },
        {
          "id": 7558,
          "name": "East Asia Cup 2024",
          "startDt": "1707868800000",
          "endDt": "1708128000000",
          "thumborImageId": 379130
        },
        {
          "id": 7579,
          "name": "Quadrangular Twenty20 Series in Thailand 2024",
          "startDt": "1707696000000",
          "endDt": "1708041600000",
          "thumborImageId": 379130
        },
        {
          "id": 7553,
          "name": "Canada tour of Nepal, 2024",
          "startDt": "1707350400000",
          "endDt": "1707696000000",
          "thumborImageId": 379130
        },
        {
          "id": 7481,
          "name": "Afghanistan tour of Sri Lanka, 2024",
          "startDt": "1706832000000",
          "endDt": "1708473600000",
          "thumborImageId": 379130
        },
        {
          "id": 6892,
          "name": "South Africa tour of New Zealand, 2024",
          "startDt": "1706486400000",
          "endDt": "1708128000000",
          "thumborImageId": 379130
        },
        {
          "id": 7511,
          "name": "ACC Mens T20I Challenger Cup 2024",
          "startDt": "1706313600000",
          "endDt": "1707609600000",
          "thumborImageId": 379130
        },
        {
          "id": 6927,
          "name": "England tour of India, 2024",
          "startDt": "1706140800000",
          "endDt": "1710115200000",
          "thumborImageId": 379130
        },
        {
          "id": 6885,
          "name": "Pakistan tour of New Zealand, 2024",
          "startDt": "1705017600000",
          "endDt": "1705795200000",
          "thumborImageId": 379130
        },
        {
          "id": 6920,
          "name": "Afghanistan tour of India, 2024",
          "startDt": "1704931200000",
          "endDt": "1705449600000",
          "thumborImageId": 379130
        },
        {
          "id": 6297,
          "name": "West Indies tour of Australia, 2024",
          "startDt": "1704844800000",
          "endDt": "1707782400000",
          "thumborImageId": 379130
        },
        {
          "id": 7411,
          "name": "Zimbabwe tour of Sri Lanka 2024",
          "startDt": "1704499200000",
          "endDt": "1705536000000",
          "thumborImageId": 379130
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  },
  "contentFilters": [
    {
      "filterId": "fantasy",
      "filterName": "Fantasy Handbook"
    }
  ]
}

# %%
import requests
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "7af441ff3amsh5fb3bebbee58c85p10232fjsnc79fc7ab09f3",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
        print(response.json())
        return response.json()
    
    except Exception as ex:
        return {}
    

series_id_list = [8553, 9297, 8044, 9171, 9265, 9289, 8058, 8494, 7853, 9132, 7745, 9129, 8116, 9125, 9146, 9083, 8404, 9091, 7781, 8107, 9157, 9033, 9041, 9025, 9115, 9043, 8395, 9009, 9057, 8497, 9017, 8947, 8598, 8955, 7981, 8969, 8835, 8393, 8818, 8661, 6794, 8625, 8552, 8764, 8632, 8596, 8495, 8686, 8587, 6787, 8578, 8238, 8528, 7979, 8476, 8337, 7546, 6780, 8422, 8382, 8413, 8310, 8260, 8332, 8256, 8294, 7476, 8247, 8166, 8103, 6773, 7700, 7819, 7808, 8080, 7896, 7706, 8042, 7679, 7817, 7667, 7900, 7693, 7727, 7790, 7672, 7686, 7590, 7644, 7637, 7586, 7534, 7623, 7485, 7618, 7583, 6899, 7572, 7558, 7579, 7553, 7481, 6892, 7511, 6927, 6885, 6920, 6297, 7411]
matches_ids_list = []
for series_id in series_id_list:
  print(series_id)
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      #print(mathcDetails)
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
          matches_ids_list.append(i.get('matchInfo',{}).get('matchId'))
# Out:
# 3858
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/3858
# {'message': 'You have exceeded the MONTHLY quota for Requests on your current plan, BASIC. Upgrade your plan at https://rapidapi.com/cricketapilive/api/cricbuzz-cricket'}

# %%
response_7853 = {
  "matchDetails": [
    {
      "matchDetailsMap": {
        "key": "Sat, 23 Nov 2024 - Sun, 24 Nov 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 109309,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "Two-day warm-up Match",
              "matchFormat": "TEST",
              "startDate": "1732312800000",
              "endDate": "1732399200000",
              "state": "complete",
              "status": "Match drawn",
              "team1": {
                "teamId": 286,
                "teamName": "NEW ZEALAND XI",
                "teamSName": "NZXI",
                "imageId": 776339
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "John Davies Oval",
                "city": "Queenstown",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 136,
                  "wickets": 10,
                  "overs": 36.4
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 313,
                  "wickets": 5,
                  "overs": 68,
                  "isDeclared": True
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 249,
                  "wickets": 10,
                  "overs": 45.1
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 196,
                  "wickets": 9,
                  "overs": 22
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_1",
        "layout": "native_large",
        "position": 1
      }
    },
    {
      "matchDetailsMap": {
        "key": "Thu, 28 Nov 2024 - Mon, 02 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92390,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "1st Test",
              "matchFormat": "TEST",
              "startDate": "1732744800000",
              "endDate": "1733090400000",
              "state": "complete",
              "status": "England won by 8 wkts",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Hagley Oval",
                "city": "Christchurch",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 348,
                  "wickets": 10,
                  "overs": 91
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 254,
                  "wickets": 10,
                  "overs": 74.1
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 499,
                  "wickets": 10,
                  "overs": 103
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 104,
                  "wickets": 2,
                  "overs": 12.4
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "matchDetailsMap": {
        "key": "Fri, 06 Dec 2024 - Tue, 10 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92399,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "2nd Test",
              "matchFormat": "TEST",
              "startDate": "1733436000000",
              "endDate": "1733781600000",
              "state": "complete",
              "status": "England won by 323 runs",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Basin Reserve",
                "city": "Wellington",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 125,
                  "wickets": 10,
                  "overs": 34.5
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 259,
                  "wickets": 10,
                  "overs": 54.2
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 280,
                  "wickets": 10,
                  "overs": 54.4
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 427,
                  "wickets": 6,
                  "overs": 82.3,
                  "isDeclared": True
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "matchDetailsMap": {
        "key": "Sat, 14 Dec 2024 - Wed, 18 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92408,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "3rd Test",
              "matchFormat": "TEST",
              "startDate": "1734127200000",
              "endDate": "1734472800000",
              "state": "complete",
              "status": "New Zealand won by 423 runs",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Seddon Park",
                "city": "Hamilton",
                "timezone": "+13:00"
              },
              "currBatTeamId": 13,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 347,
                  "wickets": 10,
                  "overs": 97.1
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 453,
                  "wickets": 10,
                  "overs": 101.4
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 143,
                  "wickets": 10,
                  "overs": 35.4
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 234,
                  "wickets": 10,
                  "overs": 47.2
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_2",
        "layout": "native_large",
        "position": 4
      }
    }
  ],
  "appIndex": {
    "seoTitle": "England tour of New Zealand, 2024 live scores, schedule and results - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

# %%
response_7553 = {
  "matchDetails": [
    {
      "matchDetailsMap": {
        "key": "Thu, 08 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89026,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "1st ODI",
              "matchFormat": "ODI",
              "startDate": "1707363000000",
              "endDate": "1707363000000",
              "state": "complete",
              "status": "Nepal won by 7 runs",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 224,
                  "wickets": 10,
                  "overs": 50
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 217,
                  "wickets": 10,
                  "overs": 47.5
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_1",
        "layout": "native_large",
        "position": 1
      }
    },
    {
      "matchDetailsMap": {
        "key": "Sat, 10 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89033,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "2nd ODI",
              "matchFormat": "ODI",
              "startDate": "1707535800000",
              "endDate": "1707535800000",
              "state": "complete",
              "status": "Nepal won by 4 wkts",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 287,
                  "wickets": 6,
                  "overs": 45.1
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 285,
                  "wickets": 9,
                  "overs": 50
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    },
    {
      "matchDetailsMap": {
        "key": "Mon, 12 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89040,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "3rd ODI",
              "matchFormat": "ODI",
              "startDate": "1707708600000",
              "endDate": "1707708600000",
              "state": "complete",
              "status": "Nepal won by 9 wkts",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 234,
                  "wickets": 1,
                  "overs": 44.3
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 232,
                  "wickets": 8,
                  "overs": 50
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    }
  ],
  "appIndex": {
    "seoTitle": "Canada tour of Nepal, 2024 live scores, schedule and results - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

# %%
squad_ids_list = []
squad_list = {
  "squads": [
    {
      "squadType": "Test",
      "isHeader": True
    },
    {
      "squadId": 15821,
      "squadType": "Northern Knights",
      "imageId": 172343,
      "teamId": 294
    },
    {
      "squadId": 15826,
      "squadType": "Wellington",
      "imageId": 172364,
      "teamId": 314
    },
    {
      "squadId": 15831,
      "squadType": "Otago",
      "imageId": 172197,
      "teamId": 105
    },
    {
      "squadId": 15836,
      "squadType": "Auckland",
      "imageId": 172246,
      "teamId": 186
    },
    {
      "squadId": 15841,
      "squadType": "Canterbury",
      "imageId": 172362,
      "teamId": 312
    },
    {
      "squadId": 15846,
      "squadType": "Central Districts",
      "imageId": 172363,
      "teamId": 313
    }
  ],
  "appIndex": {
    "seoTitle": "Squads - Plunket Shield 2021-22 - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  },
  "seriesName": "Plunket Shield 2021-22",
  "seriesId": 3718
}
squads_list = []
team_id_vs_squad_id_list ={}
print(squad_list['squads'])
for squads in squad_list.get('squads',[]):
   if (squads.get('squadId','') != ''):
    squads_list.append(squads.get('squadId'))
    team_id_vs_squad_id_list[squads.get('squadId')] = squads.get('teamId')


print(squads_list)
print(team_id_vs_squad_id_list)
# Out:
# [{'squadType': 'Test', 'isHeader': True}, {'squadId': 15821, 'squadType': 'Northern Knights', 'imageId': 172343, 'teamId': 294}, {'squadId': 15826, 'squadType': 'Wellington', 'imageId': 172364, 'teamId': 314}, {'squadId': 15831, 'squadType': 'Otago', 'imageId': 172197, 'teamId': 105}, {'squadId': 15836, 'squadType': 'Auckland', 'imageId': 172246, 'teamId': 186}, {'squadId': 15841, 'squadType': 'Canterbury', 'imageId': 172362, 'teamId': 312}, {'squadId': 15846, 'squadType': 'Central Districts', 'imageId': 172363, 'teamId': 313}]
# [15821, 15826, 15831, 15836, 15841, 15846]
# {15821: 294, 15826: 314, 15831: 105, 15836: 186, 15841: 312, 15846: 313}

# %%
response_most_runs = {
  "filter": {
    "matchtype": [
      {
        "matchTypeId": "1",
        "matchTypeDesc": "test"
      },
      {
        "matchTypeId": "2",
        "matchTypeDesc": "odi"
      },
      {
        "matchTypeId": "3",
        "matchTypeDesc": "t20"
      }
    ],
    "team": [
      {
        "id": "96",
        "teamShortName": "AFG"
      },
      {
        "id": "13",
        "teamShortName": "NZ"
      },
      {
        "id": "12",
        "teamShortName": "ZIM"
      },
      {
        "id": "11",
        "teamShortName": "RSA"
      },
      {
        "id": "10",
        "teamShortName": "WI"
      },
      {
        "id": "9",
        "teamShortName": "ENG"
      },
      {
        "id": "6",
        "teamShortName": "BAN"
      },
      {
        "id": "5",
        "teamShortName": "SL"
      },
      {
        "id": "4",
        "teamShortName": "AUS"
      },
      {
        "id": "3",
        "teamShortName": "PAK"
      },
      {
        "id": "27",
        "teamShortName": "IRE"
      },
      {
        "id": "2",
        "teamShortName": "IND"
      }
    ],
    "selectedMatchType": "odi"
  },
  "headers": [
    "Batter",
    "M",
    "I",
    "R",
    "Avg"
  ],
  "values": [
    {
      "values": [
        "25",
        "Tendulkar",
        "463",
        "452",
        "18426",
        "44.83"
      ]
    },
    {
      "values": [
        "1413",
        "Kohli",
        "305",
        "293",
        "14255",
        "57.71"
      ]
    },
    {
      "values": [
        "104",
        "Sangakkara",
        "404",
        "380",
        "14234",
        "41.99"
      ]
    },
    {
      "values": [
        "38",
        "R Ponting",
        "375",
        "365",
        "13704",
        "42.04"
      ]
    },
    {
      "values": [
        "102",
        "S Jayasuriya",
        "445",
        "433",
        "13430",
        "32.36"
      ]
    },
    {
      "values": [
        "101",
        "Mahela",
        "448",
        "418",
        "12650",
        "33.38"
      ]
    },
    {
      "values": [
        "35",
        "Inzamam-ul-Haq",
        "378",
        "350",
        "11739",
        "39.53"
      ]
    },
    {
      "values": [
        "213",
        "Kallis",
        "328",
        "314",
        "11579",
        "44.36"
      ]
    },
    {
      "values": [
        "576",
        "Rohit",
        "276",
        "268",
        "11370",
        "49.22"
      ]
    },
    {
      "values": [
        "29",
        "S Ganguly",
        "311",
        "300",
        "11363",
        "41.02"
      ]
    },
    {
      "values": [
        "27",
        "Dravid",
        "344",
        "318",
        "10889",
        "39.17"
      ]
    },
    {
      "values": [
        "265",
        "Dhoni",
        "350",
        "297",
        "10773",
        "50.58"
      ]
    },
    {
      "values": [
        "247",
        "Gayle",
        "301",
        "294",
        "10480",
        "37.83"
      ]
    },
    {
      "values": [
        "240",
        "B Lara",
        "299",
        "289",
        "10405",
        "40.49"
      ]
    },
    {
      "values": [
        "105",
        "Dilshan",
        "330",
        "303",
        "10290",
        "39.27"
      ]
    },
    {
      "values": [
        "34",
        "M Yousuf",
        "288",
        "273",
        "9720",
        "41.72"
      ]
    },
    {
      "values": [
        "36",
        "A Gilchrist",
        "287",
        "279",
        "9619",
        "35.89"
      ]
    },
    {
      "values": [
        "370",
        "de Villiers",
        "228",
        "218",
        "9577",
        "53.50"
      ]
    },
    {
      "values": [
        "3864",
        "M Azharuddin",
        "334",
        "308",
        "9378",
        "36.92"
      ]
    },
    {
      "values": [
        "3531",
        "A Silva",
        "308",
        "296",
        "9284",
        "34.90"
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Live cricket scores, schedule, news, archive, series | Cricbuzz.com",
    "webURL": "www.cricbuzz.com"
  }
}

#print(response_most_runs.keys())
#print(response_most_runs.get('values')[0]['values'])
list_most_runs = []
for most_runs in response_most_runs.get('values',{}):
    stats = []
    stats.append(most_runs['values'][0])
    stats.append(most_runs['values'][1])
    stats.append(most_runs['values'][4])
    stats.append(most_runs['values'][5])
    list_most_runs.append(stats)

print(list_most_runs)
# Out:
# [['Tendulkar', '463', '452', '18426', '44.83'], ['Kohli', '305', '293', '14255', '57.71'], ['Sangakkara', '404', '380', '14234', '41.99'], ['R Ponting', '375', '365', '13704', '42.04'], ['S Jayasuriya', '445', '433', '13430', '32.36'], ['Mahela', '448', '418', '12650', '33.38'], ['Inzamam-ul-Haq', '378', '350', '11739', '39.53'], ['Kallis', '328', '314', '11579', '44.36'], ['Rohit', '276', '268', '11370', '49.22'], ['S Ganguly', '311', '300', '11363', '41.02'], ['Dravid', '344', '318', '10889', '39.17'], ['Dhoni', '350', '297', '10773', '50.58'], ['Gayle', '301', '294', '10480', '37.83'], ['B Lara', '299', '289', '10405', '40.49'], ['Dilshan', '330', '303', '10290', '39.27'], ['M Yousuf', '288', '273', '9720', '41.72'], ['A Gilchrist', '287', '279', '9619', '35.89'], ['de Villiers', '228', '218', '9577', '53.50'], ['M Azharuddin', '334', '308', '9378', '36.92'], ['A Silva', '308', '296', '9284', '34.90']]

# %%
resp = {
  "player": [
    {
      "name": "BATSMEN",
      "imageId": 174146
    },
    {
      "id": "1413",
      "name": "Virat Kohli",
      "imageId": 170661,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "576",
      "name": "Rohit Sharma",
      "imageId": 170658,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1446",
      "name": "Shikhar Dhawan",
      "imageId": 170660,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "11808",
      "name": "Shubman Gill",
      "imageId": 171042,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "9428",
      "name": "Shreyas Iyer",
      "imageId": 171024,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1836",
      "name": "Manish Pandey",
      "imageId": 171022,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "2195",
      "name": "Mayank Agarwal",
      "imageId": 171091,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "12094",
      "name": "Prithvi Shaw",
      "imageId": 171030,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1448",
      "name": "Cheteshwar Pujara",
      "imageId": 153263,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1447",
      "name": "Ajinkya Rahane",
      "imageId": 171082,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "name": "ALL ROUNDER",
      "imageId": 174146
    },
    {
      "id": "9647",
      "name": "Hardik Pandya",
      "imageId": 170666,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "8424",
      "name": "Hanuma Vihari",
      "imageId": 171080,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "587",
      "name": "Ravindra Jadeja",
      "imageId": 170670,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm orthodox"
    },
    {
      "id": "1593",
      "name": "Ravichandran Ashwin",
      "imageId": 153372,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "name": "WICKET KEEPER",
      "imageId": 174146
    },
    {
      "id": "8733",
      "name": "KL Rahul",
      "imageId": 170673,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "8271",
      "name": "Sanju Samson",
      "imageId": 226289,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "1465",
      "name": "Wriddhiman Saha",
      "imageId": 171058,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "10744",
      "name": "Rishabh Pant",
      "imageId": 171010,
      "battingStyle": "Left-hand bat"
    },
    {
      "name": "BOWLER",
      "imageId": 174146
    },
    {
      "id": "7909",
      "name": "Mohammed Shami",
      "imageId": 170684,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "9311",
      "name": "Jasprit  Bumrah",
      "imageId": 170685,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8292",
      "name": "Kuldeep Yadav",
      "imageId": 170683,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm chinaman"
    },
    {
      "id": "7910",
      "name": "Yuzvendra Chahal",
      "imageId": 170690,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "9715",
      "name": "Navdeep Saini",
      "imageId": 226400,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8683",
      "name": "Shardul Thakur",
      "imageId": 226224,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "1858",
      "name": "Umesh Yadav",
      "imageId": 153874,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "10808",
      "name": "Mohammed Siraj",
      "imageId": 171039,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    }
  ]
}
player_role = ""
for player in resp.get('player',{}):
    player_name = ""
    player_id   = ""
    batting_style = ""
    bowling_style = ""
    if(len(player.keys()) <= 2):
        player_role = player.get('name','')
        continue
    if(len(player.keys()) > 2):
        player_id = player.get('id',)
        player_name = player.get('name','')
        batting_style = player.get('battingStyle','')
        bowling_style = player.get('bowlingStyle','')
    print(player_role,player_id,player_name,bowling_style,batting_style)
# Out:
# BATSMEN 1413 Virat Kohli Right-arm medium Right-hand bat
# BATSMEN 576 Rohit Sharma Right-arm offbreak Right-hand bat
# BATSMEN 1446 Shikhar Dhawan Right-arm offbreak Left-hand bat
# BATSMEN 11808 Shubman Gill Right-arm offbreak Right-hand bat
# BATSMEN 9428 Shreyas Iyer Right-arm legbreak Right-hand bat
# BATSMEN 1836 Manish Pandey Right-arm medium Right-hand bat
# BATSMEN 2195 Mayank Agarwal  Right-hand bat
# BATSMEN 12094 Prithvi Shaw Right-arm offbreak Right-hand bat
# BATSMEN 1448 Cheteshwar Pujara Right-arm legbreak Right-hand bat
# BATSMEN 1447 Ajinkya Rahane Right-arm medium Right-hand bat
# ALL ROUNDER 9647 Hardik Pandya Right-arm fast-medium Right-hand bat
# ALL ROUNDER 8424 Hanuma Vihari Right-arm offbreak Right-hand bat
# ALL ROUNDER 587 Ravindra Jadeja Left-arm orthodox Left-hand bat
# ALL ROUNDER 1593 Ravichandran Ashwin Right-arm offbreak Right-hand bat
# WICKET KEEPER 8733 KL Rahul  Right-hand bat
# WICKET KEEPER 8271 Sanju Samson  Right-hand bat
# WICKET KEEPER 1465 Wriddhiman Saha  Right-hand bat
# WICKET KEEPER 10744 Rishabh Pant  Left-hand bat
# BOWLER 7909 Mohammed Shami Right-arm fast-medium Right-hand bat
# BOWLER 9311 Jasprit  Bumrah Right-arm fast Right-hand bat
# BOWLER 8292 Kuldeep Yadav Left-arm chinaman Left-hand bat
# BOWLER 7910 Yuzvendra Chahal Right-arm legbreak Right-hand bat
# BOWLER 9715 Navdeep Saini Right-arm fast Right-hand bat
# BOWLER 8683 Shardul Thakur Right-arm fast-medium Right-hand bat
# BOWLER 1858 Umesh Yadav Right-arm fast Right-hand bat
# BOWLER 10808 Mohammed Siraj Right-arm fast-medium Right-hand bat

# %%
import psycopg2
import streamlit as st
import pandas as pd
import requests


headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}
def create_connection():
    try:
        conn = psycopg2.connect(
            host="localhost",        
            port="5432",             
            database="cricbuzz",  
            user="postgres",       
            password="postgres" 
        )
        return conn
    except Exception as e:
        return None

def execute(query, params=None):
        try:
            conn = create_connection()
            with conn.cursor() as cur:
                cur.execute(query, params or ())
                conn.commit()
                return True
        except Exception as e:
            st.error(f"Error executing query: {e}")
            return False
        finally:
            if conn:
                conn.close()
create_query = "create table if not exists players (player_id int primary key,player_name char(50),playing_role char(30),batting_style char(40),bowling_style char(40),team char(40))"
execute(query=create_query)
try:
    #url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/2/players"

   # r@esponse = requests.get(url, headers=headers, params=None)
    response_india_players = {
  "player": [
    {
      "name": "BATSMEN",
      "imageId": 174146
    },
    {
      "id": "1413",
      "name": "Virat Kohli",
      "imageId": 170661,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "576",
      "name": "Rohit Sharma",
      "imageId": 170658,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1446",
      "name": "Shikhar Dhawan",
      "imageId": 170660,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "11808",
      "name": "Shubman Gill",
      "imageId": 171042,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "9428",
      "name": "Shreyas Iyer",
      "imageId": 171024,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1836",
      "name": "Manish Pandey",
      "imageId": 171022,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "2195",
      "name": "Mayank Agarwal",
      "imageId": 171091,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "12094",
      "name": "Prithvi Shaw",
      "imageId": 171030,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1448",
      "name": "Cheteshwar Pujara",
      "imageId": 153263,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1447",
      "name": "Ajinkya Rahane",
      "imageId": 171082,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "name": "ALL ROUNDER",
      "imageId": 174146
    },
    {
      "id": "9647",
      "name": "Hardik Pandya",
      "imageId": 170666,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "8424",
      "name": "Hanuma Vihari",
      "imageId": 171080,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "587",
      "name": "Ravindra Jadeja",
      "imageId": 170670,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm orthodox"
    },
    {
      "id": "1593",
      "name": "Ravichandran Ashwin",
      "imageId": 153372,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "name": "WICKET KEEPER",
      "imageId": 174146
    },
    {
      "id": "8733",
      "name": "KL Rahul",
      "imageId": 170673,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "8271",
      "name": "Sanju Samson",
      "imageId": 226289,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "1465",
      "name": "Wriddhiman Saha",
      "imageId": 171058,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "10744",
      "name": "Rishabh Pant",
      "imageId": 171010,
      "battingStyle": "Left-hand bat"
    },
    {
      "name": "BOWLER",
      "imageId": 174146
    },
    {
      "id": "7909",
      "name": "Mohammed Shami",
      "imageId": 170684,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "9311",
      "name": "Jasprit  Bumrah",
      "imageId": 170685,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8292",
      "name": "Kuldeep Yadav",
      "imageId": 170683,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm chinaman"
    },
    {
      "id": "7910",
      "name": "Yuzvendra Chahal",
      "imageId": 170690,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "9715",
      "name": "Navdeep Saini",
      "imageId": 226400,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8683",
      "name": "Shardul Thakur",
      "imageId": 226224,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "1858",
      "name": "Umesh Yadav",
      "imageId": 153874,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "10808",
      "name": "Mohammed Siraj",
      "imageId": 171039,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    }
  ]
}
    
try:
    player_role = ""
    for player in response_india_players.get('player',{}):
        player_name = ""
        player_id   = ""
        batting_style = ""
        bowling_style = ""
        if(len(player.keys()) <= 2):
            player_role = player.get('name','')
            continue
        if(len(player.keys()) > 2):
            player_id = player.get('id',)
            player_name = player.get('name','')
            batting_style = player.get('battingStyle','')
            bowling_style = player.get('bowlingStyle','')
            team     = "INDIA"
        player_info   = (player_id,player_name,player_role,batting_style,bowling_style)
        insert_query = "insert into players (player_id,player_name,playing_role,batting_style,bowling_style,team) values (%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=player_info)
except Exception as e:
    print("Error Occured",e)
finally:
    print("sucess")
# Out:
#   Cell In[8], line 241
#     try:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/2/players"

    response = requests.get(url, headers=headers, params=None)
    response_india_players = response.json()
    player_role = ""
    for player in response_india_players.get('player',{}):
        player_name = ""
        player_id   = ""
        batting_style = ""
        bowling_style = ""
        if(len(player.keys()) <= 2):
            player_role = player.get('name','')
            continue
        if(len(player.keys()) > 2):
            player_id = player.get('id',)
            player_name = player.get('name','')
            batting_style = player.get('battingStyle','')
            bowling_style = player.get('bowlingStyle','')
            team     = "INDIA"
        player_info   = (player_id,player_name,player_role,batting_style,bowling_style,team)
        insert_query = "insert into players (player_id,player_name,playing_role,batting_style,bowling_style,team) values (%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=player_info)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)
# Out:
# 2025-11-07 22:24:39.594 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.595 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.650 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.651 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.705 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.706 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.707 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.758 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:39.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.363 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.364 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.476 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.478 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.528 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.689 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.690 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:40.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.508 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.509 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.559 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.560 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.611 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.663 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.766 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:41.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.023 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.024 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.076 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-07 22:24:42.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
from datetime import datetime;
start_date = "1762071300000"
datetime.fromtimestamp(int(start_date)/1000.0)
#datetime.strptime(start_date
# Out:
# datetime.datetime(2025, 11, 2, 13, 45)

# %%
import utils.db_connection as db
create_query = "create table if not exists recent_matches (match_id int primary key,match_description varchar,team_1_name varchar,team_2_name varchar,venue_name varchar, match_date date)"
db.execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

    response = requests.get(url, headers=headers, params=None)
    data = response.json()

    typeMatches     = data.get('typeMatches',[])
    for typeMatch in typeMatches:
        series_matches = typeMatch.get('seriesMatches',[])
        for series in series_matches:
            series_data = series.get('seriesAdWrapper',{})
            series_id   = series_data.get('seriesId')
            series_name = series_data.get('seriesName')
            matches     = series_data.get('matches',[])
            for match in matches:
                match_info      = match.get('matchInfo',{})
                match_id        = match_info.get('matchId','')
                match_desc      = match_info.get('matchDesc','')
                match_format    = match_info.get('matchFormat','')
                start_date      = match_info.get('startDate','')
                team1           = match_info.get('team1',{})
                team1_name      = team1.get('teamName')
                team2           = match_info.get('team2',{})
                team2_name      = team2.get('teamName','')
                state           = match_info.get('state','')
                venue_info      = match_info.get('venueInfo',{})
                venue           = venue_info.get("ground",'')
                city            = venue_info.get('city','')
                venue_detail    = venue+","+city
                team1_scr_desc  = ""
                team2_scr_desc  = ""
                status          = match_info.get('status','')

                match_scores    = match.get('matchScore',{})
                team1_score     = match_scores.get('team1Score',{})
            
                for count,innings in enumerate(team1_score.keys(),start = 0):
                    runs            = team1_score[innings].get('runs','')
                    wickets         =str(team1_score[innings].get('wickets',''))
                    if(wickets == "None" or wickets == ''):
                        wickets = "0"
                    overs           = team1_score[innings].get('overs','')
                    if(count > 0):
                        team1_scr_desc += ' & '
                    team1_scr_desc  = team1_scr_desc+""+str(runs)+"-"+wickets+" ("+str(overs)+")"
                team2_score     = match_scores.get('team2Score',{})
                for count,innings in enumerate(team2_score.keys(),start = 0):
                    runs            = team2_score[innings].get('runs')
                    wickets         = str(team2_score[innings].get('wickets'))
                    if(wickets == "None" or wickets == ''):
                        wickets = "0"
                    overs           = team2_score[innings].get('overs')
                    if(count > 0):
                        team2_scr_desc += ' & '
                    team2_scr_desc  = team2_scr_desc+""+str(runs)+"-"+wickets+" ("+str(overs)+")"
                    
                #print(team1_scr_desc,"        ",team2_scr_desc)
                parameters = (match_id,match_desc,team1_name,team2_name,venue_detail,datetime.fromtimestamp(float(start_date)/1000.0))
                insert_query = "insert into recent_matches(match_id,match_description,team_1_name,team_2_name,venue_name,match_date) values(%s,%s,%s,%s,%s,%s)"
                db.execute(query=insert_query,params=parameters)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import psycopg2
import pandas as pd
def create_connection():
    try:
        conn = psycopg2.connect(
            host="localhost",        
            port="5432",             
            database="cricbuzz",  
            user="postgres",       
            password="postgres" 
        )
        return conn
    except Exception as e:
        return None

def execute(query, params=None):
        try:
            conn = create_connection()
            with conn.cursor() as cur:
                cur.execute(query, params or ())
                conn.commit()
                return True
        except Exception as e:
            print(f"Error executing query: {e}")
            return False
        finally:
            if conn:
                conn.close()
def fetch_records(query):
    try:
        conn = create_connection()
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        columns = [desc[0] for desc in cursor.description]
        return pd.DataFrame(rows, columns=columns)
    except Exception as e:
        st.error(f"Error fetching records: {e}")
        return pd.DataFrame()
    finally:
        conn.close()

# %%
df = fetch_records("SELECT max(player_id)+1 as new_player_id from players")
value = int(df['new_player_id'][0])
int(value)
# Out:
# 24730

# %%
import requests         
headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists most_runs_stats (player_id int,player_name varchar,format varchar,matches smallint,innings smallint,runs int,average numeric)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"mostRuns","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        matches = values[2]
        innings = values[3]
        runs = values[4]
        average = values[5]
        parameter = (id,name,format,matches,innings,runs,average)
        insert_query = "insert into most_runs_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests         
headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists most_runs_stats (player_id int,player_name varchar,format varchar,matches smallint,innings smallint,runs int,average numeric)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"mostRuns","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        matches = values[2]
        innings = values[3]
        runs = values[4]
        average = values[5]
        parameter = (id,name,format,matches,innings,runs,average)
        insert_query = "insert into most_runs_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)
# Out:
# ('25', 'Tendulkar', '200', '329', '15921', '53.79')
# ('38', 'R Ponting', '168', '287', '13378', '51.85')
# ('213', 'Kallis', '166', '280', '13289', '55.37')
# ('27', 'Dravid', '164', '286', '13288', '52.31')
# ('488', 'Cook', '161', '291', '12472', '45.35')
# ('104', 'Sangakkara', '134', '233', '12400', '57.14')
# ('240', 'B Lara', '131', '232', '11953', '52.89')
# ('244', 'Chanderpaul', '164', '280', '11867', '51.37')
# ('101', 'Mahela', '149', '252', '11814', '49.85')
# ('4672', 'A Border', '156', '265', '11174', '50.56')
# ('4712', 'S Waugh', '168', '260', '10927', '51.06')
# ('3817', 'S Gavaskar', '125', '214', '10122', '51.12')
# ('130', 'Younis Khan', '118', '213', '10099', '52.06')
# ('8019', 'Root', '117', '216', '9889', '49.20')
# ('314', 'Amla', '124', '215', '9282', '46.64')
# ('207', 'Graeme Smith', '117', '205', '9265', '48.26')
# ('5308', 'G Gooch', '118', '215', '8900', '42.58')
# ('3664', 'J Miandad', '124', '189', '8832', '52.57')
# ('35', 'Inzamam-ul-Haq', '120', '200', '8830', '49.61')
# ('28', 'V Laxman', '134', '225', '8781', '45.97')

# %%
import requests   
def extract_int(val):
    if isinstance(val, str):
        digits = re.sub(r'[^\d]', '', val)
        return int(digits) if digits else None
    return val

headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists venue_info (ground varchar,city char(100),country char(100),capacity varchar,time_zone char(75),ends varchar,home_team varchar(255))"
execute(query=create_query)
#print("table created succesfully")
list_of_venues = [371,372,418,19,18,66,1843,290,152,228,335,380,154,506,512,40,34,123,83,35]
for i in list_of_venues:
    try:
        
        print("inside the try block")
        url = f"https://cricbuzz-cricket.p.rapidapi.com/venues/v1/{i}"
        response = requests.get(url, headers=headers, params=None)
        data = response.json()
        print(data)
        ground  = data.get('ground','')
        city    = data.get('city','')
        country = data.get('country','')
        capacity = extract_int(data.get('capacity',''))
        time_zone = data.get('timezone','')
        ends    = data.get('ends','')
        home_team = data.get('homeTeam','')
        parameter = (ground,city,country,capacity,time_zone,ends,home_team)
        insert_query = "insert into venue_info values(%s,%s,%s,%s,%s,%s,%s)"
        retrned = execute(query=insert_query,params=parameter)
        print("values inserted succesfully",retrned)
    except requests.exceptions.RequestException as e:
        print("Error Occured",e)
# Out:
# inside the try block
# {'ground': 'Hagley Oval', 'city': 'Christchurch', 'country': 'New Zealand', 'timezone': '+13:00', 'established': 1886, 'capacity': '20,000', 'knownAs': 'Hagley Oval', 'homeTeam': 'Canterbury', 'curator': 'Rupert Bool', 'profile': '<b>Venue description:</b>\n\nChristchurch waited almost three years since 2011 for international cricket to return to the city. Most parts of the city were severely damaged by the earthquake in February 2011, including Lancaster Park, previously the venue for international cricket in Christchurch. The last game played here was an ODI that involved New Zealand and Pakistan. Later in 2013, Canterbury Cricket got the approval from the Environment Court to develop Hagley Oval as an international venue. \n\nHagley Oval is situated in the central city of Christchurch. The first time the Plunket Shield, New Zealand\'s domestic first-class cricket tournament, was played here was in 1907. It is the home ground of Canterbury who have been playing here since 1979. The venue has hosted three Women\'s Test matches and six Women\'s ODIs. Apart from that, two World Cup qualifier games were held here in January 2014. Scotland played both the matches, one against Kenya and the other against Canada. \n\nThe venue made its Test debut on Boxing Day 2014, when New Zealand and Sri Lanka locked horns to kick-off the 2-Test series. It is also the ground which will launch the 2015 World Cup, again involving New Zealand and Sri Lanka.\n\n<b>How does the pitch play?</b>\n\nOnly one Test match has been played on this venue. But it has come for praise from New Zealand skipper, Brendon McCullum who noted the pitch kept a good pace throughout the four days\' play. Angelo Mathews had this to say about the pitch - "The wicket was very good. It had bounce throughout the game and whoever had the skill could let the ball talk."\n\nSix of these wickets are made of Waikari Clay and five are made from Kakanui clay.  The clay is covered with ryegrass.\n\nBy <b>Akshay Maanay</b>', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/371.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Saxton Oval', 'city': 'Nelson', 'country': 'New Zealand', 'timezone': '+13:00', 'established': 2009, 'capacity': '5,000', 'knownAs': 'Saxton Oval', 'homeTeam': ' Central Districts', 'profile': "<b>Venue description:</b>\n\nSaxton Oval is also known as Saxton Field is located at Nelson, New Zealand. It came into existence when Nelson Cricket Association moved from their original home ground Trafalgar Park. The Association got an approval of $400,000 from Lottery Community Facilities Funding to build the cricket, athletics and football pavilion.\n\nOnce the ground was ready, the first ever match that it hosted was a T20 game between game Central Districts and Canterbury in 2009. In the following seasons, first-class and List A matches were played here. In 2010, New Zealand Women and Australia Women played a T20I, it was the first international game to be played at this stadium.\n\nSo far only one ODI has been played at this venue, it was between New Zealand and West Indies in January 2014. Both teams went into this game with the series being 1-1. Martin Guptill led the batting charge and was supported by the rest as the Kiwis put up a competitive total of 285 in their 50 overs. West Indies' reply was put to a halt by rain, which stopped play at the 34th over with the score being 134/5. New Zealand went on to win the game by 58 runs as per D/L. \n\n<b>How does the pitch play?</b>\n\nSo far only one ODI has taken place - which isn't really a parameter to judge the character of the pitch.\n\nBy <b>Akshay Manaay</b>", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/372.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Eden Park Outer Oval', 'city': 'Auckland', 'country': 'New Zealand', 'timezone': '+13:00', 'knownAs': 'Eden Park No. 2', 'ends': 'City End, Sandringham End', 'homeTeam': 'Auckland', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/418.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': "Lord's", 'city': 'London', 'country': 'England', 'timezone': '+01:00', 'established': 1814, 'capacity': '30000', 'knownAs': "Lord's Cricket Ground", 'ends': 'Pavilion End, Nursery End', 'homeTeam': 'Marylebone Cricket Club, Middlesex', 'floodlights': True, 'curator': 'Mick Hunt', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/19.jpg', 'imageId': '717711'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Trent Bridge', 'city': 'Nottingham', 'country': 'England', 'timezone': '+01:00', 'established': 1841, 'capacity': '15,350 (to be 17,000)', 'knownAs': 'Trent Bridge Ground', 'ends': 'Pavilion End, Radcliffe Road End', 'homeTeam': 'Nottinghamshire', 'floodlights': True, 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/18.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Headingley', 'city': 'Leeds', 'country': 'England', 'timezone': '+01:00', 'established': 1890, 'capacity': '17000', 'knownAs': 'Headingley Grounds', 'ends': 'Kirkstall Lane End, Football Stand End', 'homeTeam': 'Yorkshire', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/66.jpg', 'imageId': '717701'}
# values inserted succesfully True
# inside the try block
# {'ground': 'BCA Stadium, Kotambi', 'city': 'Vadodara', 'country': 'India', 'timezone': '+05:30', 'knownAs': 'Kotambi Stadium Vadodara', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/1843.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Niranjan Shah Stadium, Khandheri', 'city': 'Rajkot', 'country': 'India', 'timezone': '+05:30', 'established': 2009, 'capacity': '28,000', 'knownAs': 'Saurashtra Cricket Association Stadium, Khandheri Cricket Stadium', 'homeTeam': 'Saurashtra', 'floodlights': True, 'profile': "<b>Venue Description:</b> \n\nA land of 30 acres was sanctioned in 2004 near the Jamnagar highway to build this state-of-the-art cricket stadium. The construction began in 2006 and almost 75 crores was spent. The media box at the venue resembles the one at Lord's and also for the spectators to move freely, there are several aisles between the seats. It also caters as a sporting complex to various other sports like badminton, volleyball and basketball. \n\nThere are also two grounds for cricket. One is the main ground which started hosting first-class matches in 2009 and is 90 metres. The other, which is right beside, is 70 metres long and is mainly used for district games. The stadium plays hosts for Saurashtra Cricket Association (SCA) along with the Madhavrao Scindia Cricket Ground. \n\nThe venue holds together more than 60 hospitality boxes, but the SCA are against selling the tickets to corporates and only give them during an international game.   \n\n<b>How does the pitch play?</b>\n\nThe Ranji home team players Cheteshwar Pujara and Ravindra Jadeja scored triple hundreds on this ground. That should give a fair indication as to what type of wicket we can expect here - it is of course batsmen-friendly. In the two international matches played at this venue, both were high-scoring encounters. First was an ODI between England and India - the visitors scored 325 and the hosts fell short by 9 runs. \n\nThe other game played here was a T20I involving Australia and India. The Aussies riding on the back of Aaron Finch's 89 set a target of 202. Yuvraj Singh won the game for India with two balls to spare, with his quickfire unbeaten 35-ball 77.", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/290.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Holkar Cricket Stadium', 'city': 'Indore', 'country': 'India', 'timezone': '+05:30', 'knownAs': 'Maharani Usharaje Trust Cricket Ground', 'ends': 'GAIL-Madhav Rao Scindia End, Pavilion End', 'homeTeam': 'Madhya Pradesh', 'floodlights': True, 'profile': "<b>Venue Description:</b>\n\nThe Holkar stadium, formerly known as Maharani Usharaje Trust Cricket Ground, has staged quite a few ODIs. When India came face-to-face against England on April 15, 2006, the Holkar stadium became the 156th ODI venue in this country. It also hosts most of Madhya Pradesh's Ranji Trophy matches and Duleep Trophy encounters. The Kerala Tuskers too played a couple of their IPL games at this venue in 2011.\n\nIntriguingly, it is also the venue, where Virender Sehwag thwacked West Indies' attack to all corners of the ground and cracked a sparkling knock of 219 in 2011. The ground has state-of-the-art facilities. The floodlit stadium has a seating capacity touching 30,000, which is the norm for most cricket grounds in the smaller cities of India. In 2011, the Pavilions were named after C.K Nayudu and Mushtaq Ali.\n\n<b>Pitch Conditions:</b>\n\nThe wicket at the Holkar stadium usually favours the batsmen. With even bounce and short boundaries coming into play, batsmen tend to rule the roost. On expected lines, Sehwag played with sparkle and fizz, and composed that record-breaking double ton against the West Indies in 2011. Even if we go further back in time to 2006, India chased down a target a 289 set by England with seven wickets to spare.", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/152.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Vidarbha Cricket Association Stadium', 'city': 'Nagpur', 'country': 'India', 'timezone': '+05:30', 'established': 2008, 'capacity': '45,000', 'ends': 'Secretary End, Pavilon End', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/228.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Shaheed Veer Narayan Singh International Stadium', 'city': 'Raipur', 'country': 'India', 'timezone': '+05:30', 'established': 2008, 'capacity': '65,000', 'knownAs': 'Shaheed Veer Narayan Singh International Cricket Stadium,  Chhattisgarh International Cricket Stadium', 'ends': 'North End, South End', 'homeTeam': 'Delhi Daredevils, Chhattisgarh', 'floodlights': True, 'profile': "<b>Venue Description</b>:\n\nEstablished in 2008, the SVNS International Cricket Stadium is one of the newest state-of-the-art stadiums in India. The ground hosted its first major game in 2010, when the Canadian national team played against Chhattisgarh in a one-day match. In 2013, the stadium made its debut in the IPL when it was chosen as the second home venue for the Delhi Daredevils. The Daredevils won both their games here, against Pune Warriors India and Kolkata Knight Riders.\n\nFew of the 2014 IPL season matches were supposed to be played here, but due to the Lok Sabha elections and the rescheduling that followed afterwards, the venue couldn't host any games. However, the venue played host to eight Champions League T20 matches of the 2014 edition. All the six qualifiers plus two group stage games, were held here.\n\n<b>How does the pitch play</b>?\n\nThe 22-yards strip usually offers a good balance between the bat and the ball. Two IPL and eight CLT20 games have been played at this venue and only once a team has crossed 200 here. Apart from that, from time to time, the pitch offers some assistance to the pacers as well as the spinners. In all, it is a good sporting wicket, with something there for everyone to exploit.\n\nby <b>Sidhant Maheshwari</b>", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/335.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Barsapara Cricket Stadium', 'city': 'Guwahati', 'country': 'India', 'timezone': '+05:30', 'established': 2012, 'capacity': '40000', 'knownAs': 'Dr. Bhupen Hazarika Cricket Stadium, Assam Cricket Association Stadium', 'ends': 'Media End, Pavilion End', 'homeTeam': 'Assam', 'floodlights': True, 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/380.jpg', 'imageId': '731778'}
# values inserted succesfully True
# inside the try block
# {'ground': 'ACA-VDCA Cricket Stadium', 'city': 'Visakhapatnam', 'country': 'India', 'timezone': '+05:30', 'established': 2003, 'capacity': '28,000', 'ends': 'Vizzy End, DV Subba Rao End', 'homeTeam': 'Andhra', 'floodlights': True, 'profile': '<b>Venue Description</b>\n\nACA-VDCA Cricket Stadium, located in Pothinamallayya Palem, Visakhapatnam, is surrounded by the blissful facade of the picturesque hills and the leafy ramble of trees swaying in breeze. It is the home ground of Sunrisers Hyderabad in the Indian Premier League. The stadium built in 2003 is known for its excellent drainage facilities. The well-manicured, lush-green outfield at the ground has also come in for praise. The seating capacity is expected to be increased to 50,000. In fact, the Test status was also granted recently. It is the ninth ground to be awarded the Test status in India.\n\nThe first ever international match at this stadium took place between arch-rivals India and Pakistan in April 2005. It was a game in which MS Dhoni announced his arrival at the highest level with a blistering innings of 148. Since then, it has gone on to host five ODIs, one T20I and IPL fixtures related to Deccan Chargers in 2012. Sunrisers Hyderabad are expected to play three games in 2015 in the IPL. \n\n<b>Pitch Conditions</b>:\n\nHistorically, it is known for producing belters, where batsmen can play through the line on even-paced wickets. However, in recent times, spinners have made their mark. It can be exemplified by some low-scoring games in the 2013-14 Syed Mushtaq Ali Trophy.\n\nby <b>Bharath Ramaraj</b>', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/154.jpg', 'imageId': '731711'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Greenfield International Stadium', 'city': 'Thiruvananthapuram', 'country': 'India', 'timezone': '+05:30', 'capacity': '50000', 'knownAs': 'The Sports Hub, Trivandrum, Trivandrum International Stadium', 'floodlights': True, 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/506.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Perth Stadium', 'city': 'Perth', 'country': 'Australia', 'timezone': '+08:00', 'capacity': '60000', 'floodlights': True, 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/512.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Adelaide Oval', 'city': 'Adelaide', 'country': 'Australia', 'timezone': '+10:30', 'established': 1871, 'capacity': '53,583 (including standing room)', 'knownAs': 'The Adelaide Oval', 'ends': 'City End, Cathedral End', 'homeTeam': 'South Australia and Adelaide Strikers', 'floodlights': True, 'curator': 'Damien Hough', 'profile': '<b>Venue description:</b>\n\n The Adelaide Oval nestled across the backdrop of magnificence of glorious gardens and swaying trees makes for a scenic ground.\n\nRedevelopment of the ground between 2008 and 2014 at a cost of $575 million that involved constructing two new stands at the Southern and Eastern sides of the ground have perhaps taken away the blissful facade surrounding the stadium. However, the Northern hill, iconic Moreton Bay Figs and heritage scoreboard still give you a feeling of nostalgia.\n\nThe stadium hosted its first ODI back in 1975 when Australia took on the West Indies. Over the years, many riveting contests have taken place at Adelaide Oval, including West Indies\' great escape from the proverbial jaws of defeat to beat Australia by 1-run in a Test match in 1993.\n\n<b>How does the pitch play?</b>\n\nGenerally, the Adelaide Oval is reckoned to be the best batting wicket in Australia. It plays very flat on the first three days of a Test match and as the match wears on it brings the spinners into the game. From 2013, Adelaide became host to the drop-in pitches.\n\n<b>What is a drop-in pitch?</b>\n\nA drop-in pitch is a cricket pitch which is prepared away from the ground or venue in which it is used, and literally "dropped in" to place for a cricket match. This allows multi-purpose venues to host other sports and events with more versatility than a dedicated cricket ground would allow. (source: Wikipedia)\n\nFor more about drop-in pitches, have a look at this <a href="http://www.mcg.org.au/The%20MCG%20Stadium/Portable%20Cricket%20Pitches.aspx" target="_blank" title="See how a drop-in pitch is laid">link</a>\n\nBy <b>Bharath Ramraj</b>', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/40.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Sydney Cricket Ground', 'city': 'Sydney', 'country': 'Australia', 'timezone': '+11:00', 'established': 1854, 'capacity': '48,000', 'knownAs': 'Sydney Cricket Ground No. 1; Garrison Ground (1848-1877), Association Ground', 'ends': 'Paddington End, Randwick End', 'homeTeam': 'New South Wales, Sydney Sixers', 'floodlights': True, 'curator': 'Tom Parker', 'profile': "<b>Venue description:</b>\n\n One of the oldest Test venues, Sydney Cricket Ground (SCG) hosted its first Test an Ashes encounter between Australia and England, way back in 1882. A Test regular, Sydney usually holds the popular 'New Year Test' that is generally played in the first week of January. The ground is also a pre-dominant ODI venue and has hosted numerous final matches as well as the crucial semi-final in the 1992 World Cup. One of the most popular sporting venues across the world, SCG was the ground where Sir Don Bradman made his highest ever first class score of 452, for New South Wales against Queensland in 1928-29.\n\n<b>How does the pitch play?</b>\n\nSydney is known to be a good batting wicket, with the spinners coming into the picture on days 4 and 5 of a Test match. It doesn't offer the true bounce of the Gabba or the raw pace of the WACA, but turns which ensures spinners have one venue in Australia to look forward to rolling their arm over.\n\nBy <b>Pradeep Krishnamurthy</b>", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/34.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Manuka Oval', 'city': 'Canberra', 'country': 'Australia', 'timezone': '+11:00', 'established': 1929, 'capacity': '13,550', 'knownAs': 'Manuka Oval. Previously known as Manuka Circle Park', 'ends': 'Pool End, Mall End', 'homeTeam': 'Australian Capital Territory, New South Wales, Pri', 'floodlights': True, 'curator': 'Brad Van Dam', 'profile': "<b>Venue description:</b>\n\n The Manuka Oval is located in the suburb of Griffith in Manuka, Canberra. The stadium plays host to a number of sporting events other than cricket, including Australian football.\n\nThe ground was originally an open park called the 'Manuka Circle Park'. After an enclosing fence was built in 1929, it came to be recognised as the Manuka Oval. The ground hosts the yearly game between the Prime Minister’s XI (a team picked by the Australian PM) and an overseas touring team. \n\nThe ground is home to the ACT Comets, a cricket team representing Australian Capital Territory. The ground also offers a beautiful backdrop with trees encircling the entire oval, many of which were planted way back in the 1920s. \n\n<b>How does the pitch play?</b>\n\nNot many games have been hosted by Manuka Oval - which makes it difficult to gauge how the pitch may play. But looking at history, it is traditionally a very good batting wicket. \n\nBy <b>Sidhant Maheshwari</b>", 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/123.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'Nahar Singh Stadium', 'city': 'Faridabad', 'country': 'India', 'timezone': '+05:30', 'established': 1981, 'capacity': '25000', 'knownAs': 'Mayur Stadium', 'homeTeam': 'Haryana', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/83.jpg', 'imageId': '189174'}
# values inserted succesfully True
# inside the try block
# {'ground': 'The Gabba', 'city': 'Brisbane', 'country': 'Australia', 'timezone': '+10:00', 'established': 1895, 'capacity': '42000 (approx)', 'knownAs': 'The Gabba', 'ends': 'Stanley Street End, Vulture Street End', 'homeTeam': 'Queensland, Brisbane Heat', 'floodlights': True, 'curator': 'Kevin Mitchell jnr', 'profile': '<b>Venue description:</b>\n\nThe stadium is named after the Brisbane suburb of Woolloongabba, in which it is located. A 42,000 seat stadium with state-of-art facilities, the Gabba also caters to other sports - American Rules Football, Soccer, Rugby Union and even Greyhound racing. The Gabba usually hosts the first Test match of the season every November. Since its first Test in 1931, the ground has undergone drastic renovations to become one of the finest Down Under.\n\nNotably, the first ever tied Test took place at this venue in 1960. It also holds the distinction of being the first Australian venue to host a T20I.\n\n<b>How does the pitch play?</b>\n\nThe Gabba is considered to be the truest wicket available in Australia. It generally offers healthy bounce and carry to the quicks while the stroke-makers thrive on the consistent bounce available. Kevin Mitchell jnr is regarded to be the best groundsman in Australia and has resisted the calls for a drop-in pitch, saying it will be difficult to replicate the traditional characteristics, if a drop-in pitch was installed.\n\nBy <b>Deivarayn Muthu</b>', 'imageUrl': 'http://i.cricketcb.com/i/stats/fth/540x303/venue/images/35.jpg', 'imageId': '189174'}
# values inserted succesfully True

# %%
[3858, 4168, 4100, 4149, 3806, 3641, 4086, 3697, 4156, 3722, 4041, 3636, 4046, 3646, 4091, 4051, 4107, 4079, 2913, 3961]

# %%
create_query = "create table if not exists team_win_stats (match_id int primary key,match_description varchar,team_1_name varchar,team_2_name varchar,venue_name varchar, match_date date)"
db.execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/matches/v1/recent"

    response = requests.get(url, headers=headers, params=None)
    data = response.json()

    typeMatches     = data.get('typeMatches',[])
    for typeMatch in typeMatches:
        series_matches = typeMatch.get('seriesMatches',[])
        for series in series_matches:
            series_data = series.get('seriesAdWrapper',{})
            series_id   = series_data.get('seriesId')
            series_name = series_data.get('seriesName')
            matches     = series_data.get('matches',[])
            for match in matches:
                match_info      = match.get('matchInfo',{})
                match_id        = match_info.get('matchId','')
                match_desc      = match_info.get('matchDesc','')
                match_format    = match_info.get('matchFormat','')
                start_date      = match_info.get('startDate','')
                team1           = match_info.get('team1',{})
                team1_name      = team1.get('teamName')
                team2           = match_info.get('team2',{})
                team2_name      = team2.get('teamName','')
                state           = match_info.get('state','')
                venue_info      = match_info.get('venueInfo',{})
                venue           = venue_info.get("ground",'')
                city            = venue_info.get('city','')
                venue_detail    = venue+","+city
                team1_scr_desc  = ""
                team2_scr_desc  = ""
                status          = match_info.get('status','')

                match_scores    = match.get('matchScore',{})
                team1_score     = match_scores.get('team1Score',{})
            
                for count,innings in enumerate(team1_score.keys(),start = 0):
                    runs            = team1_score[innings].get('runs','')
                    wickets         =str(team1_score[innings].get('wickets',''))
                    if(wickets == "None" or wickets == ''):
                        wickets = "0"
                    overs           = team1_score[innings].get('overs','')
                    if(count > 0):
                        team1_scr_desc += ' & '
                    team1_scr_desc  = team1_scr_desc+""+str(runs)+"-"+wickets+" ("+str(overs)+")"
                team2_score     = match_scores.get('team2Score',{})
                for count,innings in enumerate(team2_score.keys(),start = 0):
                    runs            = team2_score[innings].get('runs')
                    wickets         = str(team2_score[innings].get('wickets'))
                    if(wickets == "None" or wickets == ''):
                        wickets = "0"
                    overs           = team2_score[innings].get('overs')
                    if(count > 0):
                        team2_scr_desc += ' & '
                    team2_scr_desc  = team2_scr_desc+""+str(runs)+"-"+wickets+" ("+str(overs)+")"
                    
                #print(team1_scr_desc,"        ",team2_scr_desc)
                parameters = (match_id,match_desc,team1_name,team2_name,venue_detail,datetime.fromtimestamp(float(start_date)/1000.0))
                insert_query = "insert into recent_matches(match_id,match_description,team_1_name,team_2_name,venue_name,match_date) values(%s,%s,%s,%s,%s,%s)"
                db.execute(query=insert_query,params=parameters)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests         
headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists highest_score_stats (player_id int,batter_name varchar,format varchar,highest_score smallint,balls varchar,strike_rate varchar,opponent varchar)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"highestScore","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        highest_score = values[2]
        balls = values[3]
        strike_rate = values[4]
        opponent = values[5]
        parameter = (id,name,format,highest_score,balls,strike_rate,opponent)
        insert_query = "insert into highest_score_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests         
headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query ="""CREATE TABLE if not exists matches (
    match_id BIGINT PRIMARY KEY,
    match_description VARCHAR(255),
    match_format VARCHAR(50),
    match_type VARCHAR(50),
    complete BOOLEAN,
    match_start_timestamp BIGINT,
    match_complete_timestamp BIGINT,
    year INT,
    team1_id INT,
    team1_name VARCHAR(100),
    team2_id INT,
    team2_name VARCHAR(100),
    toss_winner_id INT,
    toss_winner_name VARCHAR(100),
    toss_decision VARCHAR(50),
    result_type VARCHAR(50),
    winning_team VARCHAR(100),
    winning_team_id INT,
    winning_margin INT,
    win_by_runs BOOLEAN,
    win_by_innings BOOLEAN,
    venue_name VARCHAR(200),
    venue_city VARCHAR(100),
    venue_country VARCHAR(100),
    series_id INT,
    series_name VARCHAR(150)
);"""

#execute(query=create_query)

try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/112389/scard"

    response = requests.get(url, headers=headers, params=None)
    data = response.json()
    
    match = data.get('matchHeader',{})
    insert_query = """
        INSERT INTO matches (
            match_id, match_description, match_format, match_type, complete,
            match_start_timestamp, match_complete_timestamp, year,
            team1_id, team1_name, team2_id, team2_name,
            toss_winner_id, toss_winner_name, toss_decision,
            result_type, winning_team, winning_team_id, winning_margin,
            win_by_runs, win_by_innings, venue_name, venue_city, venue_country,
            series_id, series_name
        ) VALUES (
            %(match_id)s, %(match_description)s, %(match_format)s, %(match_type)s, %(complete)s,
            %(match_start_timestamp)s, %(match_complete_timestamp)s, %(year)s,
            %(team1_id)s, %(team1_name)s, %(team2_id)s, %(team2_name)s,
            %(toss_winner_id)s, %(toss_winner_name)s, %(toss_decision)s,
            %(result_type)s, %(winning_team)s, %(winning_team_id)s, %(winning_margin)s,
            %(win_by_runs)s, %(win_by_innings)s, %(venue_name)s, %(venue_city)s, %(venue_country)s,
            %(series_id)s, %(series_name)s
        )
        """

    values = {
        "match_id": match["matchId"],
        "match_description": match.get("matchDescription"),
        "match_format": match.get("matchFormat"),
        "match_type": match.get("matchType"),
        "complete": match.get("complete"),
        "match_start_timestamp": match.get("matchStartTimestamp"),
        "match_complete_timestamp": match.get("matchCompleteTimestamp"),
        "year": match.get("year"),
        "team1_id": match["team1"]["id"],
        "team1_name": match["team1"]["name"],
        "team2_id": match["team2"]["id"],
        "team2_name": match["team2"]["name"],
        "toss_winner_id": match["tossResults"]["tossWinnerId"],
        "toss_winner_name": match["tossResults"]["tossWinnerName"],
        "toss_decision": match["tossResults"]["decision"],
        "result_type": match["result"]["resultType"],
        "winning_team": match["result"]["winningTeam"],
        "winning_team_id": match["result"]["winningteamId"],
        "winning_margin": match["result"]["winningMargin"],
        "win_by_runs": match["result"]["winByRuns"],
        "win_by_innings": match["result"]["winByInnings"],
        "venue_name": '',
        "venue_city": '',
        "venue_country": '',
        "series_id": match["seriesId"],
        "series_name": match["seriesName"]
    }
    execute(query=insert_query,params=values)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 65
#      43     match = data.get('matchHeader',{})
#      44     insert_query = """
#      45         INSERT INTO matches (
#      46             match_id, match_description, match_format, match_type, complete,
#    (...)     61         )
#      62         """
#      64     values = {
# ---> 65         "match_id": match["matchId"],
#      66         "match_description": match.get("matchDescription"),
#      67         "match_format": match.get("matchFormat"),
#      68         "match_type": match.get("matchType"),
#      69         "complete": match.get("complete"),
#      70         "match_start_timestamp": match.get("matchStartTimestamp"),
#      71         "match_complete_timestamp": match.get("matchCompleteTimestamp"),
#      72         "year": match.get("year"),
#      73         "team1_id": match["team1"]["id"],
#      74         "team1_name": match["team1"]["name"],
#      75         "team2_id": match["team2"]["id"],
#      76         "team2_name": match["team2"]["name"],
#      77         "toss_winner_id": match["tossResults"]["tossWinnerId"],
#      78         "toss_winner_name": match["tossResults"]["tossWinnerName"],
#      79         "toss_decision": match["tossResults"]["decision"],
#      80         "result_type": match["result"]["resultType"],
#      81         "winning_team": match["result"]["winningTeam"],
#      82         "winning_team_id": match["result"]["winningteamId"],
#      83         "winning_margin": match["result"]["winningMargin"],
#      84         "win_by_runs": match["result"]["winByRuns"],
#      85         "win_by_innings": match["result"]["winByInnings"],
#      86         "venue_name": '',
#      87         "venue_city": '',
#      88         "venue_country": '',
#      89         "series_id": match["seriesId"],
#      90         "series_name": match["seriesName"]
#      91     }
#      92     execute(query=insert_query,params=values)
#      93 except requests.exceptions.RequestException as e:
#
# KeyError: 'matchId'

# %%
import requests
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
       # print(response.json())
        return response.json()
    
    except Exception as ex:
        print(ex)
        return {}
    

#series_id_list = [8553, 9297, 8044, 9171, 9265, 9289, 8058, 8494, 7853, 9132, 7745, 9129, 8116, 9125, 9146, 9083, 8404, 9091, 7781, 8107, 9157, 9033, 9041, 9025, 9115, 9043, 8395, 9009, 9057, 8497, 9017, 8947, 8598, 8955, 7981, 8969, 8835, 8393, 8818, 8661, 6794, 8625, 8552, 8764, 8632, 8596, 8495, 8686, 8587, 6787, 8578, 8238, 8528, 7979, 8476, 8337, 7546, 6780, 8422, 8382, 8413, 8310, 8260, 8332, 8256, 8294, 7476, 8247, 8166, 8103, 6773, 7700, 7819, 7808, 8080, 7896, 7706, 8042, 7679, 7817, 7667, 7900, 7693, 7727, 7790, 7672, 7686, 7590, 7644, 7637, 7586, 7534, 7623, 7485, 7618, 7583, 6899, 7572, 7558, 7579, 7553, 7481, 6892, 7511, 6927, 6885, 6920, 6297, 7411]
series_id_list = [6297]
matches_ids_list = []
for series_id in series_id_list:
  print(series_id)
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      #print(mathcDetails)
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
          matches_ids_list.append(i.get('matchInfo',{}).get('matchId'))

print(matches_ids_list)
# Out:
# 6297
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/6297
# [87493, 70326, 70333, 70340, 70347, 70354, 70361, 70368, 70375]
