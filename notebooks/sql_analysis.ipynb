          "startDt": "1677283200000",
          "endDt": "1677888000000",
          "thumborImageId": 379130
        },
        {
          "id": 5847,
          "name": "Isle of Man tour of Spain, 2023",
          "startDt": "1677196800000",
          "endDt": "1677369600000",
          "thumborImageId": 379130
        },
        {
          "id": 5952,
          "name": "Bermuda tour of Argentina, 2023",
          "startDt": "1676937600000",
          "endDt": "1677024000000",
          "thumborImageId": 379130
        },
        {
          "id": 4854,
          "name": "West Indies tour of South Africa, 2023",
          "startDt": "1676937600000",
          "endDt": "1679961600000",
          "thumborImageId": 379130
        },
        {
          "id": 5896,
          "name": "Afghanistan tour of United Arab Emirates, 2023",
          "startDt": "1676505600000",
          "endDt": "1676764800000",
          "thumborImageId": 379130
        },
        {
          "id": 5204,
          "name": "Australia tour of India, 2023",
          "startDt": "1675900800000",
          "endDt": "1679443200000",
          "thumborImageId": 379130
        },
        {
          "id": 4413,
          "name": "England tour of New Zealand, 2023",
          "startDt": "1675814400000",
          "endDt": "1677542400000",
          "thumborImageId": 379130
        },
        {
          "id": 5260,
          "name": "West Indies tour of Zimbabwe, 2023",
          "startDt": "1674864000000",
          "endDt": "1676505600000",
          "thumborImageId": 379130
        },
        {
          "id": 4847,
          "name": "England tour of South Africa, 2023",
          "startDt": "1674777600000",
          "endDt": "1675209600000",
          "thumborImageId": 379130
        },
        {
          "id": 5199,
          "name": "New Zealand tour of India, 2023",
          "startDt": "1674000000000",
          "endDt": "1675209600000",
          "thumborImageId": 379130
        },
        {
          "id": 5213,
          "name": "Ireland tour of Zimbabwe, 2023",
          "startDt": "1673481600000",
          "endDt": "1674432000000",
          "thumborImageId": 379130
        },
        {
          "id": 5197,
          "name": "Sri Lanka tour of India, 2023",
          "startDt": "1672704000000",
          "endDt": "1673740800000",
          "thumborImageId": 379130
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}
list_series_ids = []
matches_ids     = []

for serieslist in resp.get("seriesMapProto",[]):
    for series in serieslist.get('series'):
        list_series_ids.append(series.get('id'))

print(list_series_ids)
# Out:
# [7404, 7415, 6878, 7399, 6857, 7275, 7383, 6290, 6228, 7233, 7268, 7264, 7231, 7226, 7198, 7212, 7196, 6732, 7189, 7004, 7180, 7158, 7163, 6913, 6694, 4805, 7149, 7135, 6906, 6242, 4791, 6934, 7066, 6997, 6836, 5973, 6955, 6948, 6687, 6340, 6333, 6752, 6582, 6652, 6759, 6683, 6676, 6669, 6666, 6659, 6437, 4777, 6351, 6606, 6599, 6589, 5917, 6255, 6248, 6521, 4786, 6235, 6022, 6193, 6214, 5913, 4896, 6155, 4861, 6025, 5987, 5980, 5490, 5966, 4415, 5276, 5959, 5847, 5952, 4854, 5896, 5204, 4413, 5260, 4847, 5199, 5213, 5197]

# %%
import requests
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "7af441ff3amsh5fb3bebbee58c85p10232fjsnc79fc7ab09f3",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
       # print(response.json())
        return response.json()
    
    except Exception as ex:
        print(ex)
        return {}
    

#series_id_list = [8553, 9297, 8044, 9171, 9265, 9289, 8058, 8494, 7853, 9132, 7745, 9129, 8116, 9125, 9146, 9083, 8404, 9091, 7781, 8107, 9157, 9033, 9041, 9025, 9115, 9043, 8395, 9009, 9057, 8497, 9017, 8947, 8598, 8955, 7981, 8969, 8835, 8393, 8818, 8661, 6794, 8625, 8552, 8764, 8632, 8596, 8495, 8686, 8587, 6787, 8578, 8238, 8528, 7979, 8476, 8337, 7546, 6780, 8422, 8382, 8413, 8310, 8260, 8332, 8256, 8294, 7476, 8247, 8166, 8103, 6773, 7700, 7819, 7808, 8080, 7896, 7706, 8042, 7679, 7817, 7667, 7900, 7693, 7727, 7790, 7672, 7686, 7590, 7644, 7637, 7586, 7534, 7623, 7485, 7618, 7583, 6899, 7572, 7558, 7579, 7553, 7481, 6892, 7511, 6927, 6885, 6920, 6297, 7411]
series_id_list = [8553]
matches_ids_list = []
for series_id in series_id_list:
  print(series_id)
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      #print(mathcDetails)
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
          matches_ids_list.append(i.get('matchInfo',{}).get('matchId'))
# Out:
# 8553
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/8553

# %%
response_2025_2026 = {
  "seriesMapProto": [
    {
      "date": "FEBRUARY 2024",
      "series": [
        {
          "id": 7572,
          "name": "ICC Cricket World Cup League Two 2023-27",
          "startDt": "1707955200000",
          "endDt": "1806364800000"
        }
      ]
    },
    {
      "date": "OCTOBER 2025",
      "series": [
        {
          "id": 10895,
          "name": "South Africa tour of Pakistan, 2025",
          "startDt": "1760227200000",
          "endDt": "1762560000000"
        },
        {
          "id": 10955,
          "name": "West Indies tour of Bangladesh, 2025",
          "startDt": "1760745600000",
          "endDt": "1761868800000"
        },
        {
          "id": 10212,
          "name": "England tour of New Zealand, 2025",
          "startDt": "1760745600000",
          "endDt": "1761955200000"
        },
        {
          "id": 9596,
          "name": "India tour of Australia, 2025",
          "startDt": "1760832000000",
          "endDt": "1762560000000"
        },
        {
          "id": 11052,
          "name": "Afghanistan tour of Zimbabwe 2025",
          "startDt": "1760918400000",
          "endDt": "1762041600000"
        },
        {
          "id": 11089,
          "name": "South American Mens Championships 2025",
          "startDt": "1761782400000",
          "endDt": "1761955200000"
        },
        {
          "id": 11062,
          "name": "Cyprus Tri-Series 2025",
          "startDt": "1761868800000",
          "endDt": "1762041600000"
        }
      ]
    },
    {
      "date": "NOVEMBER 2025",
      "series": [
        {
          "id": 11069,
          "name": "Bulgaria tour of Cyprus 2025",
          "startDt": "1762128000000",
          "endDt": "1762128000000"
        },
        {
          "id": 10223,
          "name": "West Indies tour of New Zealand, 2025",
          "startDt": "1762300800000",
          "endDt": "1766361600000"
        },
        {
          "id": 11108,
          "name": "Indonesia Tri-Series 2025",
          "startDt": "1762387200000",
          "endDt": "1763078400000"
        },
        {
          "id": 10972,
          "name": "Ireland tour of Bangladesh, 2025",
          "startDt": "1762819200000",
          "endDt": "1764633600000"
        },
        {
          "id": 10933,
          "name": "Sri Lanka tour of Pakistan 2025",
          "startDt": "1762819200000",
          "endDt": "1763164800000"
        },
        {
          "id": 9638,
          "name": "South Africa tour of India, 2025",
          "startDt": "1763078400000",
          "endDt": "1766102400000"
        },
        {
          "id": 10906,
          "name": "Pakistan T20I Tri-Series 2025",
          "startDt": "1763337600000",
          "endDt": "1764374400000"
        },
        {
          "id": 9107,
          "name": "The Ashes, 2025-26",
          "startDt": "1763683200000",
          "endDt": "1767830400000"
        }
      ]
    },
    {
      "date": "DECEMBER 2025",
      "series": [
        {
          "id": 11132,
          "name": "Bahrain tour of Bhutan, 2025",
          "startDt": "1765152000000",
          "endDt": "1765670400000"
        },
        {
          "id": 11141,
          "name": "Myanmar tour of Bhutan, 2025",
          "startDt": "1766448000000",
          "endDt": "1766966400000"
        }
      ]
    },
    {
      "date": "JANUARY 2026",
      "series": [
        {
          "id": 10102,
          "name": "New Zealand tour of India, 2026",
          "startDt": "1768089600000",
          "endDt": "1769817600000"
        },
        {
          "id": 10774,
          "name": "England tour of Sri Lanka 2026",
          "startDt": "1769040000000",
          "endDt": "1770076800000"
        },
        {
          "id": 9551,
          "name": "West Indies tour of South Africa, 2026",
          "startDt": "1769472000000",
          "endDt": "1770336000000"
        }
      ]
    },
    {
      "date": "MARCH 2026",
      "series": [
        {
          "id": 10234,
          "name": "South Africa tour of New Zealand, 2026",
          "startDt": "1773532800000",
          "endDt": "1774396800000"
        }
      ]
    },
    {
      "date": "JUNE 2026",
      "series": [
        {
          "id": 10559,
          "name": "New Zealand tour of England, 2026",
          "startDt": "1780531200000",
          "endDt": "1782691200000"
        },
        {
          "id": 10532,
          "name": "India tour of England, 2026",
          "startDt": "1782864000000",
          "endDt": "1784419200000"
        }
      ]
    },
    {
      "date": "AUGUST 2026",
      "series": [
        {
          "id": 10565,
          "name": "Pakistan tour of England 2026",
          "startDt": "1787097600000",
          "endDt": "1788912000000"
        }
      ]
    },
    {
      "date": "SEPTEMBER 2026",
      "series": [
        {
          "id": 10576,
          "name": "Sri Lanka tour of England, 2026",
          "startDt": "1789430400000",
          "endDt": "1790467200000"
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}
response_2025 = {
  "seriesMapProto": [
    {
      "date": "2025",
      "series": [
        {
          "id": 11062,
          "name": "Cyprus Tri-Series 2025",
          "startDt": "1761868800000",
          "endDt": "1762041600000",
          "thumborImageId": 379130
        },
        {
          "id": 11089,
          "name": "South American Mens Championships 2025",
          "startDt": "1761782400000",
          "endDt": "1761955200000",
          "thumborImageId": 379130
        },
        {
          "id": 11052,
          "name": "Afghanistan tour of Zimbabwe 2025",
          "startDt": "1760918400000",
          "endDt": "1762041600000",
          "startDt": "1745020800000",
          "endDt": "1745712000000",
          "thumborImageId": 379130
        },
        {
          "id": 9692,
          "name": "Central American Cricket Championships, 2025",
          "startDt": "1744848000000",
          "endDt": "1745107200000",
          "thumborImageId": 379130
        },
        {
          "id": 9647,
          "name": "Hong Kong T20I Quadrangular Series, 2025",
          "startDt": "1744156800000",
          "endDt": "1744502400000",
          "thumborImageId": 379130
        },
        {
          "id": 9534,
          "name": "Portugal tour of Norway, 2025",
          "startDt": "1743984000000",
          "endDt": "1744156800000",
          "thumborImageId": 379130
        },
        {
          "id": 9523,
          "name": "Canada tour of Namibia, 2025",
          "startDt": "1742256000000",
          "endDt": "1742688000000",
          "thumborImageId": 379130
        },
        {
          "id": 8562,
          "name": "Pakistan tour of New Zealand, 2025",
          "startDt": "1742083200000",
          "endDt": "1743811200000",
          "thumborImageId": 379130
        },
        {
          "id": 9507,
          "name": "Falkland Islands tour of Costa Rica 2025",
          "startDt": "1741651200000",
          "endDt": "1741824000000",
          "thumborImageId": 379130
        },
        {
          "id": 9480,
          "name": "Malaysia Tri-Nation T20I Series, 2025",
          "startDt": "1741564800000",
          "endDt": "1742169600000",
          "thumborImageId": 379130
        },
        {
          "id": 9453,
          "name": "Bahrain tour of Singapore, 2025",
          "startDt": "1740700800000",
          "endDt": "1741132800000",
          "thumborImageId": 379130
        },
        {
          "id": 9451,
          "name": "USA tour of Oman T20I Series, 2025",
          "startDt": "1740009600000",
          "endDt": "1740268800000",
          "thumborImageId": 379130
        },
        {
          "id": 9325,
          "name": "ICC Champions Trophy, 2025",
          "startDt": "1739923200000",
          "endDt": "1741478400000",
          "thumborImageId": 379130
        },
        {
          "id": 9426,
          "name": "Bahrain tour of Indonesia, 2025",
          "startDt": "1739923200000",
          "endDt": "1740355200000",
          "thumborImageId": 379130
        },
        {
          "id": 8511,
          "name": "Pakistan ODI Tri-Series, 2025",
          "startDt": "1738972800000",
          "endDt": "1739491200000",
          "thumborImageId": 379130
        },
        {
          "id": 9331,
          "name": "Ireland tour of Zimbabwe, 2025",
          "startDt": "1738800000000",
          "endDt": "1740441600000",
          "thumborImageId": 379130
        },
        {
          "id": 9375,
          "name": "Malta T20I Tri-Series, 2025",
          "startDt": "1738540800000",
          "endDt": "1738713600000",
          "thumborImageId": 379130
        },
        {
          "id": 9181,
          "name": "Australia tour of Sri Lanka, 2025",
          "startDt": "1738108800000",
          "endDt": "1739491200000",
          "thumborImageId": 379130
        },
        {
          "id": 8402,
          "name": "England tour of India, 2025",
          "startDt": "1737504000000",
          "endDt": "1739318400000",
          "thumborImageId": 379130
        },
        {
          "id": 8504,
          "name": "West Indies tour of Pakistan, 2025",
          "startDt": "1736467200000",
          "endDt": "1738022400000",
          "thumborImageId": 379130
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

response_2024 = {
  "seriesMapProto": [
    {
      "date": "2024",
      "series": [
        {
          "thumborImageId": 379130
        },
        {
          "id": 7558,
          "name": "East Asia Cup 2024",
          "startDt": "1707868800000",
          "endDt": "1708128000000",
          "thumborImageId": 379130
        },
        {
          "id": 7579,
          "name": "Quadrangular Twenty20 Series in Thailand 2024",
          "startDt": "1707696000000",
          "endDt": "1708041600000",
          "thumborImageId": 379130
        },
        {
          "id": 7553,
          "name": "Canada tour of Nepal, 2024",
          "startDt": "1707350400000",
          "endDt": "1707696000000",
          "thumborImageId": 379130
        },
        {
          "id": 7481,
          "name": "Afghanistan tour of Sri Lanka, 2024",
          "startDt": "1706832000000",
          "endDt": "1708473600000",
          "thumborImageId": 379130
        },
        {
          "id": 6892,
          "name": "South Africa tour of New Zealand, 2024",
          "startDt": "1706486400000",
          "endDt": "1708128000000",
          "thumborImageId": 379130
        },
        {
          "id": 7511,
          "name": "ACC Mens T20I Challenger Cup 2024",
          "startDt": "1706313600000",
          "endDt": "1707609600000",
          "thumborImageId": 379130
        },
        {
          "id": 6927,
          "name": "England tour of India, 2024",
          "startDt": "1706140800000",
          "endDt": "1710115200000",
          "thumborImageId": 379130
        },
        {
          "id": 6885,
          "name": "Pakistan tour of New Zealand, 2024",
          "startDt": "1705017600000",
          "endDt": "1705795200000",
          "thumborImageId": 379130
        },
        {
          "id": 6920,
          "name": "Afghanistan tour of India, 2024",
          "startDt": "1704931200000",
          "endDt": "1705449600000",
          "thumborImageId": 379130
        },
        {
          "id": 6297,
          "name": "West Indies tour of Australia, 2024",
          "startDt": "1704844800000",
          "endDt": "1707782400000",
          "thumborImageId": 379130
        },
        {
          "id": 7411,
          "name": "Zimbabwe tour of Sri Lanka 2024",
          "startDt": "1704499200000",
          "endDt": "1705536000000",
          "thumborImageId": 379130
        }
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Current Running Cricket Series - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  },
  "contentFilters": [
    {
      "filterId": "fantasy",
      "filterName": "Fantasy Handbook"
    }
  ]
}

# %%
import requests
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "7af441ff3amsh5fb3bebbee58c85p10232fjsnc79fc7ab09f3",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
        print(response.json())
        return response.json()
    
    except Exception as ex:
        return {}
    

series_id_list = [8553, 9297, 8044, 9171, 9265, 9289, 8058, 8494, 7853, 9132, 7745, 9129, 8116, 9125, 9146, 9083, 8404, 9091, 7781, 8107, 9157, 9033, 9041, 9025, 9115, 9043, 8395, 9009, 9057, 8497, 9017, 8947, 8598, 8955, 7981, 8969, 8835, 8393, 8818, 8661, 6794, 8625, 8552, 8764, 8632, 8596, 8495, 8686, 8587, 6787, 8578, 8238, 8528, 7979, 8476, 8337, 7546, 6780, 8422, 8382, 8413, 8310, 8260, 8332, 8256, 8294, 7476, 8247, 8166, 8103, 6773, 7700, 7819, 7808, 8080, 7896, 7706, 8042, 7679, 7817, 7667, 7900, 7693, 7727, 7790, 7672, 7686, 7590, 7644, 7637, 7586, 7534, 7623, 7485, 7618, 7583, 6899, 7572, 7558, 7579, 7553, 7481, 6892, 7511, 6927, 6885, 6920, 6297, 7411]
matches_ids_list = []
for series_id in series_id_list:
  print(series_id)
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      #print(mathcDetails)
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
          matches_ids_list.append(i.get('matchInfo',{}).get('matchId'))
# Out:
# 3858
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/3858
# {'message': 'You have exceeded the MONTHLY quota for Requests on your current plan, BASIC. Upgrade your plan at https://rapidapi.com/cricketapilive/api/cricbuzz-cricket'}

# %%
response_7853 = {
  "matchDetails": [
    {
      "matchDetailsMap": {
        "key": "Sat, 23 Nov 2024 - Sun, 24 Nov 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 109309,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "Two-day warm-up Match",
              "matchFormat": "TEST",
              "startDate": "1732312800000",
              "endDate": "1732399200000",
              "state": "complete",
              "status": "Match drawn",
              "team1": {
                "teamId": 286,
                "teamName": "NEW ZEALAND XI",
                "teamSName": "NZXI",
                "imageId": 776339
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "John Davies Oval",
                "city": "Queenstown",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 136,
                  "wickets": 10,
                  "overs": 36.4
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 313,
                  "wickets": 5,
                  "overs": 68,
                  "isDeclared": True
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 249,
                  "wickets": 10,
                  "overs": 45.1
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 196,
                  "wickets": 9,
                  "overs": 22
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_1",
        "layout": "native_large",
        "position": 1
      }
    },
    {
      "matchDetailsMap": {
        "key": "Thu, 28 Nov 2024 - Mon, 02 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92390,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "1st Test",
              "matchFormat": "TEST",
              "startDate": "1732744800000",
              "endDate": "1733090400000",
              "state": "complete",
              "status": "England won by 8 wkts",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Hagley Oval",
                "city": "Christchurch",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 348,
                  "wickets": 10,
                  "overs": 91
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 254,
                  "wickets": 10,
                  "overs": 74.1
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 499,
                  "wickets": 10,
                  "overs": 103
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 104,
                  "wickets": 2,
                  "overs": 12.4
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "matchDetailsMap": {
        "key": "Fri, 06 Dec 2024 - Tue, 10 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92399,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "2nd Test",
              "matchFormat": "TEST",
              "startDate": "1733436000000",
              "endDate": "1733781600000",
              "state": "complete",
              "status": "England won by 323 runs",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Basin Reserve",
                "city": "Wellington",
                "timezone": "+13:00"
              },
              "currBatTeamId": 9,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 125,
                  "wickets": 10,
                  "overs": 34.5
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 259,
                  "wickets": 10,
                  "overs": 54.2
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 280,
                  "wickets": 10,
                  "overs": 54.4
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 427,
                  "wickets": 6,
                  "overs": 82.3,
                  "isDeclared": True
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "matchDetailsMap": {
        "key": "Sat, 14 Dec 2024 - Wed, 18 Dec 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 92408,
              "seriesId": 7853,
              "seriesName": "England tour of New Zealand, 2024",
              "matchDesc": "3rd Test",
              "matchFormat": "TEST",
              "startDate": "1734127200000",
              "endDate": "1734472800000",
              "state": "complete",
              "status": "New Zealand won by 423 runs",
              "team1": {
                "teamId": 13,
                "teamName": "NEW ZEALAND",
                "teamSName": "NZ",
                "imageId": 776333
              },
              "team2": {
                "teamId": 9,
                "teamName": "ENGLAND",
                "teamSName": "ENG",
                "imageId": 776237
              },
              "venueInfo": {
                "ground": "Seddon Park",
                "city": "Hamilton",
                "timezone": "+13:00"
              },
              "currBatTeamId": 13,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 347,
                  "wickets": 10,
                  "overs": 97.1
                },
                "inngs2": {
                  "inningsId": 3,
                  "runs": 453,
                  "wickets": 10,
                  "overs": 101.4
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 143,
                  "wickets": 10,
                  "overs": 35.4
                },
                "inngs2": {
                  "inningsId": 4,
                  "runs": 234,
                  "wickets": 10,
                  "overs": 47.2
                }
              }
            }
          }
        ],
        "seriesId": 7853
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_2",
        "layout": "native_large",
        "position": 4
      }
    }
  ],
  "appIndex": {
    "seoTitle": "England tour of New Zealand, 2024 live scores, schedule and results - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

# %%
response_7553 = {
  "matchDetails": [
    {
      "matchDetailsMap": {
        "key": "Thu, 08 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89026,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "1st ODI",
              "matchFormat": "ODI",
              "startDate": "1707363000000",
              "endDate": "1707363000000",
              "state": "complete",
              "status": "Nepal won by 7 runs",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 224,
                  "wickets": 10,
                  "overs": 50
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 217,
                  "wickets": 10,
                  "overs": 47.5
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_1",
        "layout": "native_large",
        "position": 1
      }
    },
    {
      "matchDetailsMap": {
        "key": "Sat, 10 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89033,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "2nd ODI",
              "matchFormat": "ODI",
              "startDate": "1707535800000",
              "endDate": "1707535800000",
              "state": "complete",
              "status": "Nepal won by 4 wkts",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 287,
                  "wickets": 6,
                  "overs": 45.1
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 285,
                  "wickets": 9,
                  "overs": 50
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    },
    {
      "matchDetailsMap": {
        "key": "Mon, 12 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 89040,
              "seriesId": 7553,
              "seriesName": "Canada tour of Nepal, 2024",
              "matchDesc": "3rd ODI",
              "matchFormat": "ODI",
              "startDate": "1707708600000",
              "endDate": "1707708600000",
              "state": "complete",
              "status": "Nepal won by 9 wkts",
              "team1": {
                "teamId": 72,
                "teamName": "NEPAL",
                "teamSName": "NEP",
                "imageId": 776331
              },
              "team2": {
                "teamId": 26,
                "teamName": "CANADA",
                "teamSName": "CAN",
                "imageId": 776227
              },
              "venueInfo": {
                "ground": "Tribhuvan University International Cricket Ground",
                "city": "Kirtipur",
                "timezone": "+05:45"
              },
              "currBatTeamId": 72,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 234,
                  "wickets": 1,
                  "overs": 44.3
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 232,
                  "wickets": 8,
                  "overs": 50
                }
              }
            }
          }
        ],
        "seriesId": 7553
      }
    }
  ],
  "appIndex": {
    "seoTitle": "Canada tour of Nepal, 2024 live scores, schedule and results - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

# %%
squad_ids_list = []
squad_list = {
  "squads": [
    {
      "squadType": "Test",
      "isHeader": True
    },
    {
      "squadId": 15821,
      "squadType": "Northern Knights",
      "imageId": 172343,
      "teamId": 294
    },
    {
      "squadId": 15826,
      "squadType": "Wellington",
      "imageId": 172364,
      "teamId": 314
    },
    {
      "squadId": 15831,
      "squadType": "Otago",
      "imageId": 172197,
      "teamId": 105
    },
    {
      "squadId": 15836,
      "squadType": "Auckland",
      "imageId": 172246,
      "teamId": 186
    },
    {
      "squadId": 15841,
      "squadType": "Canterbury",
      "imageId": 172362,
      "teamId": 312
    },
    {
      "squadId": 15846,
      "squadType": "Central Districts",
      "imageId": 172363,
      "teamId": 313
    }
  ],
  "appIndex": {
    "seoTitle": "Squads - Plunket Shield 2021-22 - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  },
  "seriesName": "Plunket Shield 2021-22",
  "seriesId": 3718
}
squads_list = []
team_id_vs_squad_id_list ={}
print(squad_list['squads'])
for squads in squad_list.get('squads',[]):
   if (squads.get('squadId','') != ''):
    squads_list.append(squads.get('squadId'))
    team_id_vs_squad_id_list[squads.get('squadId')] = squads.get('teamId')


print(squads_list)
print(team_id_vs_squad_id_list)
# Out:
# [{'squadType': 'Test', 'isHeader': True}, {'squadId': 15821, 'squadType': 'Northern Knights', 'imageId': 172343, 'teamId': 294}, {'squadId': 15826, 'squadType': 'Wellington', 'imageId': 172364, 'teamId': 314}, {'squadId': 15831, 'squadType': 'Otago', 'imageId': 172197, 'teamId': 105}, {'squadId': 15836, 'squadType': 'Auckland', 'imageId': 172246, 'teamId': 186}, {'squadId': 15841, 'squadType': 'Canterbury', 'imageId': 172362, 'teamId': 312}, {'squadId': 15846, 'squadType': 'Central Districts', 'imageId': 172363, 'teamId': 313}]
      ]
    },
    {
      "values": [
        "370",
        "de Villiers",
        "228",
        "218",
        "9577",
        "53.50"
      ]
    },
    {
      "values": [
        "3864",
        "M Azharuddin",
        "334",
        "308",
        "9378",
        "36.92"
      ]
    },
    {
      "values": [
        "3531",
        "A Silva",
        "308",
        "296",
        "9284",
        "34.90"
      ]
    }
  ],
  "appIndex": {
    "seoTitle": "Live cricket scores, schedule, news, archive, series | Cricbuzz.com",
    "webURL": "www.cricbuzz.com"
  }
}

#print(response_most_runs.keys())
#print(response_most_runs.get('values')[0]['values'])
list_most_runs = []
for most_runs in response_most_runs.get('values',{}):
    stats = []
    stats.append(most_runs['values'][0])
    stats.append(most_runs['values'][1])
    stats.append(most_runs['values'][4])
    stats.append(most_runs['values'][5])
    list_most_runs.append(stats)

print(list_most_runs)
# Out:
# [['Tendulkar', '463', '452', '18426', '44.83'], ['Kohli', '305', '293', '14255', '57.71'], ['Sangakkara', '404', '380', '14234', '41.99'], ['R Ponting', '375', '365', '13704', '42.04'], ['S Jayasuriya', '445', '433', '13430', '32.36'], ['Mahela', '448', '418', '12650', '33.38'], ['Inzamam-ul-Haq', '378', '350', '11739', '39.53'], ['Kallis', '328', '314', '11579', '44.36'], ['Rohit', '276', '268', '11370', '49.22'], ['S Ganguly', '311', '300', '11363', '41.02'], ['Dravid', '344', '318', '10889', '39.17'], ['Dhoni', '350', '297', '10773', '50.58'], ['Gayle', '301', '294', '10480', '37.83'], ['B Lara', '299', '289', '10405', '40.49'], ['Dilshan', '330', '303', '10290', '39.27'], ['M Yousuf', '288', '273', '9720', '41.72'], ['A Gilchrist', '287', '279', '9619', '35.89'], ['de Villiers', '228', '218', '9577', '53.50'], ['M Azharuddin', '334', '308', '9378', '36.92'], ['A Silva', '308', '296', '9284', '34.90']]

# %%
resp = {
  "player": [
    {
      "name": "BATSMEN",
      "imageId": 174146
    },
    {
      "id": "1413",
      "name": "Virat Kohli",
      "imageId": 170661,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "576",
      "name": "Rohit Sharma",
      "imageId": 170658,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1446",
      "name": "Shikhar Dhawan",
      "imageId": 170660,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "11808",
      "name": "Shubman Gill",
      "imageId": 171042,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "9428",
      "name": "Shreyas Iyer",
      "imageId": 171024,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1836",
      "name": "Manish Pandey",
      "imageId": 171022,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "2195",
      "name": "Mayank Agarwal",
      "imageId": 171091,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "12094",
      "name": "Prithvi Shaw",
      "imageId": 171030,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1448",
      "name": "Cheteshwar Pujara",
      "imageId": 153263,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1447",
      "name": "Ajinkya Rahane",
      "imageId": 171082,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "name": "ALL ROUNDER",
      "imageId": 174146
    },
    {
      "id": "9647",
      "name": "Hardik Pandya",
      "imageId": 170666,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "8424",
      "name": "Hanuma Vihari",
      "imageId": 171080,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "587",
      "name": "Ravindra Jadeja",
      "imageId": 170670,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm orthodox"
    },
    {
      "id": "1593",
      "name": "Ravichandran Ashwin",
      "imageId": 153372,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "name": "WICKET KEEPER",
      "imageId": 174146
    },
    {
      "id": "8733",
      "name": "KL Rahul",
      "imageId": 170673,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "8271",
      "name": "Sanju Samson",
      "imageId": 226289,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "1465",
      "name": "Wriddhiman Saha",
      "imageId": 171058,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "10744",
      "name": "Rishabh Pant",
      "imageId": 171010,
      "battingStyle": "Left-hand bat"
    },
    {
      "name": "BOWLER",
      "imageId": 174146
    },
    {
      "id": "7909",
      "name": "Mohammed Shami",
      "imageId": 170684,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "9311",
      "name": "Jasprit  Bumrah",
      "imageId": 170685,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8292",
      "name": "Kuldeep Yadav",
      "imageId": 170683,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm chinaman"
    },
    {
      "id": "7910",
      "name": "Yuzvendra Chahal",
      "imageId": 170690,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "9715",
      "name": "Navdeep Saini",
      "imageId": 226400,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8683",
      "name": "Shardul Thakur",
      "imageId": 226224,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "1858",
      "name": "Umesh Yadav",
      "imageId": 153874,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "10808",
      "name": "Mohammed Siraj",
      "imageId": 171039,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    }
  ]
}
player_role = ""
for player in resp.get('player',{}):
    player_name = ""
    player_id   = ""
    batting_style = ""
    bowling_style = ""
    if(len(player.keys()) <= 2):
        player_role = player.get('name','')
        continue
    if(len(player.keys()) > 2):
        player_id = player.get('id',)
        player_name = player.get('name','')
        batting_style = player.get('battingStyle','')
        bowling_style = player.get('bowlingStyle','')
    print(player_role,player_id,player_name,bowling_style,batting_style)

# %%
import psycopg2
import streamlit as st
import pandas as pd
import requests


headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}
def create_connection():
    try:
        conn = psycopg2.connect(
            host="localhost",        
            port="5432",             
            database="cricbuzz",  
            user="postgres",       
            password="postgres" 
        )
        return conn
    except Exception as e:
        return None

def execute(query, params=None):
        try:
            conn = create_connection()
            with conn.cursor() as cur:
                cur.execute(query, params or ())
                conn.commit()
                return True
        except Exception as e:
            st.error(f"Error executing query: {e}")
            return False
        finally:
            if conn:
                conn.close()
create_query = "create table if not exists players (player_id int primary key,player_name char(50),playing_role char(30),batting_style char(40),bowling_style char(40),team char(40))"
execute(query=create_query)
try:
    #url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/2/players"

   # r@esponse = requests.get(url, headers=headers, params=None)
    response_india_players = {
  "player": [
    {
      "name": "BATSMEN",
      "imageId": 174146
    },
    {
      "id": "1413",
      "name": "Virat Kohli",
      "imageId": 170661,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "576",
      "name": "Rohit Sharma",
      "imageId": 170658,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1446",
      "name": "Shikhar Dhawan",
      "imageId": 170660,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "11808",
      "name": "Shubman Gill",
      "imageId": 171042,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "9428",
      "name": "Shreyas Iyer",
      "imageId": 171024,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1836",
      "name": "Manish Pandey",
      "imageId": 171022,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "id": "2195",
      "name": "Mayank Agarwal",
      "imageId": 171091,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "12094",
      "name": "Prithvi Shaw",
      "imageId": 171030,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "1448",
      "name": "Cheteshwar Pujara",
      "imageId": 153263,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "1447",
      "name": "Ajinkya Rahane",
      "imageId": 171082,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm medium"
    },
    {
      "name": "ALL ROUNDER",
      "imageId": 174146
    },
    {
      "id": "9647",
      "name": "Hardik Pandya",
      "imageId": 170666,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "8424",
      "name": "Hanuma Vihari",
      "imageId": 171080,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "id": "587",
      "name": "Ravindra Jadeja",
      "imageId": 170670,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm orthodox"
    },
    {
      "id": "1593",
      "name": "Ravichandran Ashwin",
      "imageId": 153372,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm offbreak"
    },
    {
      "name": "WICKET KEEPER",
      "imageId": 174146
    },
    {
      "id": "8733",
      "name": "KL Rahul",
      "imageId": 170673,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "8271",
      "name": "Sanju Samson",
      "imageId": 226289,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "1465",
      "name": "Wriddhiman Saha",
      "imageId": 171058,
      "battingStyle": "Right-hand bat"
    },
    {
      "id": "10744",
      "name": "Rishabh Pant",
      "imageId": 171010,
      "battingStyle": "Left-hand bat"
    },
    {
      "name": "BOWLER",
      "imageId": 174146
    },
    {
      "id": "7909",
      "name": "Mohammed Shami",
      "imageId": 170684,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "9311",
      "name": "Jasprit  Bumrah",
      "imageId": 170685,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8292",
      "name": "Kuldeep Yadav",
      "imageId": 170683,
      "battingStyle": "Left-hand bat",
      "bowlingStyle": "Left-arm chinaman"
    },
    {
      "id": "7910",
      "name": "Yuzvendra Chahal",
      "imageId": 170690,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm legbreak"
    },
    {
      "id": "9715",
      "name": "Navdeep Saini",
      "imageId": 226400,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "8683",
      "name": "Shardul Thakur",
      "imageId": 226224,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    },
    {
      "id": "1858",
      "name": "Umesh Yadav",
      "imageId": 153874,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast"
    },
    {
      "id": "10808",
      "name": "Mohammed Siraj",
      "imageId": 171039,
      "battingStyle": "Right-hand bat",
      "bowlingStyle": "Right-arm fast-medium"
    }
  ]
}
    
try:
    player_role = ""
    for player in response_india_players.get('player',{}):
        player_name = ""
        player_id   = ""
        batting_style = ""
        bowling_style = ""
        if(len(player.keys()) <= 2):
            player_role = player.get('name','')
            continue
        if(len(player.keys()) > 2):
            player_id = player.get('id',)
            player_name = player.get('name','')
            batting_style = player.get('battingStyle','')
            bowling_style = player.get('bowlingStyle','')
            team     = "INDIA"
        player_info   = (player_id,player_name,player_role,batting_style,bowling_style)
        insert_query = "insert into players (player_id,player_name,playing_role,batting_style,bowling_style,team) values (%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=player_info)
except Exception as e:
    print("Error Occured",e)
finally:
    print("sucess")
# Out:
#   Cell In[8], line 241
#     try:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/2/players"

    response = requests.get(url, headers=headers, params=None)
    response_india_players = response.json()
    player_role = ""
    for player in response_india_players.get('player',{}):
        player_name = ""
        player_id   = ""
        batting_style = ""
        bowling_style = ""
        if(len(player.keys()) <= 2):
            player_role = player.get('name','')
            continue
        if(len(player.keys()) > 2):
            player_id = player.get('id',)
            player_name = player.get('name','')
            batting_style = player.get('battingStyle','')
            bowling_style = player.get('bowlingStyle','')
            team     = "INDIA"
        player_info   = (player_id,player_name,player_role,batting_style,bowling_style,team)
        insert_query = "insert into players (player_id,player_name,playing_role,batting_style,bowling_style,team) values (%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=player_info)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
from datetime import datetime;
start_date = "1762071300000"
datetime.fromtimestamp(int(start_date)/1000.0)
#datetime.strptime(start_date
# Out:
# datetime.datetime(2025, 11, 2, 13, 45)

# %%
import psycopg2
import pandas as pd
def create_connection():
    try:
        conn = psycopg2.connect(
            host="localhost",        
            port="5432",             
            database="cricbuzz",  
            user="postgres",       
            password="postgres" 
        )
        return conn
    except Exception as e:
        return None

def execute(query, params=None):
        try:
            conn = create_connection()
            with conn.cursor() as cur:
                cur.execute(query, params or ())
                conn.commit()
                return True
        except Exception as e:
            print(f"Error executing query: {e}")
            return False
        finally:
            if conn:
                conn.close()
def fetch_records(query):
    try:
        conn = create_connection()
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        columns = [desc[0] for desc in cursor.description]
        return pd.DataFrame(rows, columns=columns)
    except Exception as e:
        st.error(f"Error fetching records: {e}")
        return pd.DataFrame()
    finally:
        conn.close()

# %%
import requests
from datetime import datetime
#create_query = "create table if not exists matches (match_id int primary key,match_description varchar,team_1_name varchar,team_2_name varchar,venue_name varchar, match_date date,state char(30))"
#execute(query=create_query)
try:

    data = {
  "typeMatches": [
    {
      "matchType": "International",
      "seriesMatches": [
        {
          "seriesAdWrapper": {
            "seriesId": 10223,
            "seriesName": "West Indies tour of New Zealand, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 122610,
                  "seriesId": 10223,
                  "seriesName": "West Indies tour of New Zealand, 2025",
                  "matchDesc": "3rd T20I",
                  "matchFormat": "T20",
                  "startDate": "1762647300000",
                  "endDate": "1762659900000",
                  "state": "Complete",
                  "status": "New Zealand won by 9 runs",
                  "team1": {
                    "teamId": 13,
                    "teamName": "New Zealand",
                    "teamSName": "NZ",
                    "imageId": 776333
                  },
                  "team2": {
                    "teamId": 10,
                    "teamName": "West Indies",
                    "teamSName": "WI",
                    "imageId": 776191
                  },
                  "venueInfo": {
                    "id": 372,
                    "ground": "Saxton Oval",
                    "city": "Nelson",
                    "timezone": "+13:00",
                    "latitude": "-41.322788",
                    "longitude": "173.213882"
                  },
                  "currBatTeamId": 13,
                  "seriesStartDt": "1762300800000",
                  "seriesEndDt": "1766534400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "NZ Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 177,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 168,
                      "wickets": 10,
                      "overs": 19.5
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 122616,
                  "seriesId": 10223,
                  "seriesName": "West Indies tour of New Zealand, 2025",
                  "matchDesc": "4th T20I",
                  "matchFormat": "T20",
                  "startDate": "1762733700000",
                  "endDate": "1762746300000",
                  "state": "Complete",
                  "status": "No result  -  due to rain",
                  "team1": {
                    "teamId": 10,
                    "teamName": "West Indies",
                    "teamSName": "WI",
                    "imageId": 776191
                  },
                  "team2": {
                    "teamId": 13,
                    "teamName": "New Zealand",
                    "teamSName": "NZ",
                    "imageId": 776333
                  },
                  "venueInfo": {
                    "id": 372,
                    "ground": "Saxton Oval",
                    "city": "Nelson",
                    "timezone": "+13:00",
                    "latitude": "-41.322788",
                    "longitude": "173.213882"
                  },
                  "seriesStartDt": "1762300800000",
                  "seriesEndDt": "1766534400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 38,
                      "wickets": 1,
                      "overs": 6.3
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10933,
            "seriesName": "Sri Lanka tour of Pakistan 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 134749,
                  "seriesId": 10933,
                  "seriesName": "Sri Lanka tour of Pakistan 2025",
                  "matchDesc": "2nd ODI",
                  "matchFormat": "ODI",
                  "startDate": "1763112600000",
                  "endDate": "1763141400000",
                  "state": "Complete",
                  "status": "Pakistan won by 8 wkts",
                  "team1": {
                    "teamId": 5,
                    "teamName": "Sri Lanka",
                    "teamSName": "SL",
                    "imageId": 776254
                  },
                  "team2": {
                    "teamId": 3,
                    "teamName": "Pakistan",
                    "teamSName": "PAK",
                    "imageId": 776308
                  },
                  "venueInfo": {
                    "id": 25,
                    "ground": "Rawalpindi Cricket Stadium",
                    "city": "Rawalpindi",
                    "timezone": "+05:00",
                    "latitude": "33.651525",
                    "longitude": "73.075824"
                  },
                  "currBatTeamId": 3,
                  "seriesStartDt": "1762819200000",
                  "seriesEndDt": "1763337600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 288,
                      "wickets": 8,
                      "overs": 49.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 289,
                      "wickets": 2,
                      "overs": 48.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 134744,
                  "seriesId": 10933,
                  "seriesName": "Sri Lanka tour of Pakistan 2025",
                  "matchDesc": "1st ODI",
                  "matchFormat": "ODI",
                  "startDate": "1762853400000",
                  "endDate": "1762882200000",
                  "state": "Complete",
                  "status": "Pakistan won by 6 runs",
                  "team1": {
                    "teamId": 3,
                    "teamName": "Pakistan",
                    "teamSName": "PAK",
                    "imageId": 776308
                  },
                  "team2": {
                    "teamId": 5,
                    "teamName": "Sri Lanka",
                    "teamSName": "SL",
                    "imageId": 776254
                  },
                  "venueInfo": {
                    "id": 25,
                    "ground": "Rawalpindi Cricket Stadium",
                    "city": "Rawalpindi",
                    "timezone": "+05:00",
                    "latitude": "33.651525",
                    "longitude": "73.075824"
                  },
                  "currBatTeamId": 3,
                  "seriesStartDt": "1762819200000",
                  "seriesEndDt": "1763337600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PAK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 299,
                      "wickets": 5,
                      "overs": 49.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 293,
                      "wickets": 9,
                      "overs": 49.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "ad": {
            "name": "native_matches",
            "layout": "native_large",
            "position": 3
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11108,
            "seriesName": "Indonesia Tri-Series 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 136018,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "10th Match",
                  "matchFormat": "T20",
                  "startDate": "1762997400000",
                  "endDate": "1763010000000",
                  "state": "Complete",
                  "status": "Indonesia won by 9 wkts",
                  "team1": {
                    "teamId": 2850,
                    "teamName": "Timor Leste",
                    "teamSName": "TLS",
                    "imageId": 779912
                  },
                  "team2": {
                    "teamId": 566,
                    "teamName": "Indonesia",
                    "teamSName": "IDN",
                    "imageId": 172618
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 566,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "IDN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 70,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 71,
                      "wickets": 1,
                      "overs": 5.5
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136007,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "9th Match",
                  "matchFormat": "T20",
                  "startDate": "1762911000000",
                  "endDate": "1762923600000",
                  "state": "Complete",
                  "status": "Myanmar won by 93 runs",
                  "team1": {
                    "teamId": 565,
                    "teamName": "Myanmar",
                    "teamSName": "MMR",
                    "imageId": 172617
                  },
                  "team2": {
                    "teamId": 2850,
                    "teamName": "Timor Leste",
                    "teamSName": "TLS",
                    "imageId": 779912
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 565,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MMR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 148,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 55,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136029,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "11th Match",
                  "matchFormat": "T20",
                  "startDate": "1763013600000",
                  "endDate": "1763026200000",
                  "state": "Complete",
                  "status": "Indonesia won by 10 wkts",
                  "team1": {
                    "teamId": 565,
                    "teamName": "Myanmar",
                    "teamSName": "MMR",
                    "imageId": 172617
                  },
                  "team2": {
                    "teamId": 566,
                    "teamName": "Indonesia",
                    "teamSName": "IDN",
                    "imageId": 172618
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 566,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "IDN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 78,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 79,
                      "overs": 9.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135985,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "7th Match",
                  "matchFormat": "T20",
                  "startDate": "1762822800000",
                  "endDate": "1762835400000",
                  "state": "Complete",
                  "status": "Indonesia won by 5 wkts (DLS Method  -  due to rain)",
                  "team1": {
                    "teamId": 565,
                    "teamName": "Myanmar",
                    "teamSName": "MMR",
                    "imageId": 172617
                  },
                  "team2": {
                    "teamId": 566,
                    "teamName": "Indonesia",
                    "teamSName": "IDN",
                    "imageId": 172618
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 566,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "IDN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 102,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 76,
                      "wickets": 5,
                      "overs": 9.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135996,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "8th Match",
                  "matchFormat": "T20",
                  "startDate": "1762840800000",
                  "endDate": "1762853400000",
                  "state": "Complete",
                  "status": "Indonesia won by 10 wkts - Match reduced to 10 overs due to rain",
                  "team1": {
                    "teamId": 2850,
                    "teamName": "Timor Leste",
                    "teamSName": "TLS",
                    "imageId": 779912
                  },
                  "team2": {
                    "teamId": 566,
                    "teamName": "Indonesia",
                    "teamSName": "IDN",
                    "imageId": 172618
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 566,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "IDN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 18,
                      "wickets": 9,
                      "overs": 9.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 16,
                      "overs": 1.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135974,
                  "seriesId": 11108,
                  "seriesName": "Indonesia Tri-Series 2025",
                  "matchDesc": "6th Match",
                  "matchFormat": "T20",
                  "startDate": "1762651800000",
                  "endDate": "1762664400000",
                  "state": "Complete",
                  "status": "Myanmar won by 8 wkts - Match reduced to 8 overs per side due to rain",
                  "team1": {
                    "teamId": 2850,
                    "teamName": "Timor Leste",
                    "teamSName": "TLS",
                    "imageId": 779912
                  },
                  "team2": {
                    "teamId": 565,
                    "teamName": "Myanmar",
                    "teamSName": "MMR",
                    "imageId": 172617
                  },
                  "venueInfo": {
                    "id": 1179,
                    "ground": "Udayana Cricket Ground",
                    "city": "Bali",
                    "timezone": "+07:00",
                    "latitude": "8.409518",
                    "longitude": "115.188919"
                  },
                  "currBatTeamId": 565,
                  "seriesStartDt": "1762387200000",
                  "seriesEndDt": "1763251200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MMR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 47,
                      "wickets": 7,
                      "overs": 7.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 48,
                      "wickets": 2,
                      "overs": 2.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11179,
            "seriesName": "Afghanistan tour of Qatar, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 137833,
                  "seriesId": 11179,
                  "seriesName": "Afghanistan tour of Qatar, 2025",
                  "matchDesc": "Only T20I",
                  "matchFormat": "T20",
                  "startDate": "1762871400000",
                  "endDate": "1762884000000",
                  "state": "Complete",
                  "status": "Afghanistan won by 25 runs",
                  "team1": {
                    "teamId": 96,
                    "teamName": "Afghanistan",
                    "teamSName": "AFG",
                    "imageId": 776177
                  },
                  "team2": {
                    "teamId": 525,
                    "teamName": "Qatar",
                    "teamSName": "QAT",
                    "imageId": 172575
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 96,
                  "seriesStartDt": "1762819200000",
                  "seriesEndDt": "1762992000000",
                  "isTimeAnnounced": True,
                  "stateTitle": "AFG Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 149,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 124,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10895,
            "seriesName": "South Africa tour of Pakistan, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 134397,
                  "seriesId": 10895,
                  "seriesName": "South Africa tour of Pakistan, 2025",
                  "matchDesc": "3rd ODI",
                  "matchFormat": "ODI",
                  "startDate": "1762596000000",
                  "endDate": "1762624800000",
                  "state": "Complete",
                  "status": "Pakistan won by 7 wkts",
                  "team1": {
                    "teamId": 11,
                    "teamName": "South Africa",
                    "teamSName": "RSA",
                    "imageId": 776287
                  },
                  "team2": {
                    "teamId": 3,
                    "teamName": "Pakistan",
                    "teamSName": "PAK",
                    "imageId": 776308
                  },
                  "venueInfo": {
                    "id": 30,
                    "ground": "Iqbal Stadium",
                    "city": "Faisalabad",
                    "timezone": "+05:00",
                    "latitude": "31.433785",
                    "longitude": "73.085759"
                  },
                  "currBatTeamId": 3,
                  "seriesStartDt": "1760227200000",
                  "seriesEndDt": "1762732800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PAK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 143,
                      "wickets": 10,
                      "overs": 37.5
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 144,
                      "wickets": 3,
                      "overs": 25.1
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11183,
            "seriesName": "Hong Kong tour of Qatar 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 137842,
                  "seriesId": 11183,
                  "seriesName": "Hong Kong tour of Qatar 2025",
                  "matchDesc": "2nd T20I",
                  "matchFormat": "T20",
                  "startDate": "1763026200000",
                  "endDate": "1763038800000",
                  "state": "Complete",
                  "status": "Hong Kong won by 9 runs",
                  "team1": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "team2": {
                    "teamId": 525,
                    "teamName": "Qatar",
                    "teamSName": "QAT",
                    "imageId": 172575
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 8,
                  "seriesStartDt": "1762905600000",
                  "seriesEndDt": "1763164800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 131,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 122,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137837,
                  "seriesId": 11183,
                  "seriesName": "Hong Kong tour of Qatar 2025",
                  "matchDesc": "1st T20I",
                  "matchFormat": "T20",
                  "startDate": "1762957800000",
                  "endDate": "1762970400000",
                  "state": "Complete",
                  "status": "Qatar won by 6 runs",
                  "team1": {
                    "teamId": 525,
                    "teamName": "Qatar",
                    "teamSName": "QAT",
                    "imageId": 172575
                  },
                  "team2": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 525,
                  "seriesStartDt": "1762905600000",
                  "seriesEndDt": "1763164800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "QAT Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 109,
                      "wickets": 10,
                      "overs": 19.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 103,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 9596,
            "seriesName": "India tour of Australia, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 116963,
                  "seriesId": 9596,
                  "seriesName": "India tour of Australia, 2025",
                  "matchDesc": "5th T20I",
                  "matchFormat": "T20",
                  "startDate": "1762589700000",
                  "endDate": "1762602300000",
                  "state": "Complete",
                  "status": "No result (due to rain)",
                  "team1": {
                    "teamId": 2,
                    "teamName": "India",
                    "teamSName": "IND",
                    "imageId": 776162
                  },
                  "team2": {
                    "teamId": 4,
                    "teamName": "Australia",
                    "teamSName": "AUS",
                    "imageId": 776202
                  },
                  "venueInfo": {
                    "id": 35,
                    "ground": "The Gabba",
                    "city": "Brisbane",
                    "timezone": "+10:00",
                    "latitude": "-27.485829",
                    "longitude": "153.038055"
                  },
                  "seriesStartDt": "1760832000000",
                  "seriesEndDt": "1762732800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 52,
                      "overs": 4.5
                    }
                  }
                }
              }
            ]
          }
        }
      ]
    },
    {
      "matchType": "League",
      "seriesMatches": [
        {
          "seriesAdWrapper": {
            "seriesId": 11110,
            "seriesName": "CSA T20 Knock Out Competition 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 136167,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "15th Match",
                  "matchFormat": "T20",
                  "startDate": "1762686000000",
                  "endDate": "1762698600000",
                  "state": "Complete",
                  "status": "Knights won by 8 runs - 2nd innings reduced to 6 overs due to rain, DLS target 78 ",
                  "team1": {
                    "teamId": 281,
                    "teamName": "Knights",
                    "teamSName": "KNG",
                    "imageId": 172331
                  },
                  "team2": {
                    "teamId": 933,
                    "teamName": "Eastern Storm",
                    "teamSName": "ESTORM",
                    "imageId": 248407
                  },
                  "venueInfo": {
                    "id": 72,
                    "ground": "Mangaung Oval",
                    "city": "Bloemfontein",
                    "timezone": "+02:00",
                    "latitude": "-29.116752",
                    "longitude": "26.20519"
                  },
                  "currBatTeamId": 281,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "KNG Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 114,
                      "overs": 11.1
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 69,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136189,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "17th Match",
                  "matchFormat": "T20",
                  "startDate": "1762945200000",
                  "endDate": "1762957800000",
                  "state": "Complete",
                  "status": "Eastern Cape won by 69 runs",
                  "team1": {
                    "teamId": 927,
                    "teamName": "Eastern Cape",
                    "teamSName": "ECAPE",
                    "imageId": 248405
                  },
                  "team2": {
                    "teamId": 923,
                    "teamName": "Northern Cape",
                    "teamSName": "NCAPE",
                    "imageId": 248438
                  },
                  "venueInfo": {
                    "id": 99,
                    "ground": "Buffalo Park",
                    "city": "East London",
                    "timezone": "+02:00",
                    "latitude": "-33.006727",
                    "longitude": "27.919465"
                  },
                  "currBatTeamId": 927,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "ECAPE Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 184,
                      "wickets": 4,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 115,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136200,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "18th Match",
                  "matchFormat": "T20",
                  "startDate": "1762945200000",
                  "endDate": "1762957800000",
                  "state": "Complete",
                  "status": "Mpumalanga Rhinos won by 9 runs",
                  "team1": {
                    "teamId": 903,
                    "teamName": "Mpumalanga Rhinos",
                    "teamSName": "MPR",
                    "imageId": 248434
                  },
                  "team2": {
                    "teamId": 912,
                    "teamName": "Limpopo",
                    "teamSName": "LIMPO",
                    "imageId": 248430
                  },
                  "venueInfo": {
                    "id": 1193,
                    "ground": "Uplands College, White River",
                    "city": "Mpumalanga",
                    "timezone": "+02:00",
                    "latitude": "-25.328440",
                    "longitude": "31.017780"
                  },
                  "currBatTeamId": 903,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MPR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 123,
                      "wickets": 10,
                      "overs": 19.4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 114,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136156,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "14th Match",
                  "matchFormat": "T20",
                  "startDate": "1762599600000",
                  "endDate": "1762612200000",
                  "state": "Complete",
                  "status": "Limpopo won by 28 runs",
                  "team1": {
                    "teamId": 912,
                    "teamName": "Limpopo",
                    "teamSName": "LIMPO",
                    "imageId": 248430
                  },
                  "team2": {
                    "teamId": 927,
                    "teamName": "Eastern Cape",
                    "teamSName": "ECAPE",
                    "imageId": 248405
                  },
                  "venueInfo": {
                    "id": 772,
                    "ground": "Polokwane Cricket Club",
                    "city": "Polokwane",
                    "timezone": "+02:00",
                    "latitude": "-23.912260",
                    "longitude": "29.453550"
                  },
                  "currBatTeamId": 912,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "LIMPO Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 158,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 130,
                      "wickets": 10,
                      "overs": 19.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136148,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "13th Match",
                  "matchFormat": "T20",
                  "startDate": "1762599600000",
                  "endDate": "1762612200000",
                  "state": "Complete",
                  "status": "Garden Route Badgers won by 5 wkts",
                  "team1": {
                    "teamId": 903,
                    "teamName": "Mpumalanga Rhinos",
                    "teamSName": "MPR",
                    "imageId": 248434
                  },
                  "team2": {
                    "teamId": 918,
                    "teamName": "Garden Route Badgers",
                    "teamSName": "GRB",
                    "imageId": 247396
                  },
                  "venueInfo": {
                    "id": 468,
                    "ground": "Recreation Ground",
                    "city": "Oudtshoorn",
                    "timezone": "+02:00",
                    "latitude": "22.1970307",
                    "longitude": "-33.5934657"
                  },
                  "currBatTeamId": 918,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "GRB Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 124,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 128,
                      "wickets": 5,
                      "overs": 16.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136178,
                  "seriesId": 11110,
                  "seriesName": "CSA T20 Knock Out Competition 2025",
                  "matchDesc": "16th Match",
                  "matchFormat": "T20",
                  "startDate": "1762945200000",
                  "endDate": "1762957800000",
                  "state": "Complete",
                  "status": "Eastern Storm won by 6 wkts",
                  "team1": {
                    "teamId": 918,
                    "teamName": "Garden Route Badgers",
                    "teamSName": "GRB",
                    "imageId": 247396
                  },
                  "team2": {
                    "teamId": 933,
                    "teamName": "Eastern Storm",
                    "teamSName": "ESTORM",
                    "imageId": 248407
                  },
                  "venueInfo": {
                    "id": 468,
                    "ground": "Recreation Ground",
                    "city": "Oudtshoorn",
                    "timezone": "+02:00",
                    "latitude": "22.1970307",
                    "longitude": "-33.5934657"
                  },
                  "currBatTeamId": 933,
                  "seriesStartDt": "1761264000000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "ESTORM Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 176,
                      "wickets": 6,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 179,
                      "wickets": 4,
                      "overs": 19.1
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11146,
            "seriesName": "ACC Mens Asia Cup Rising Stars 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 137338,
                  "seriesId": 11146,
                  "seriesName": "ACC Mens Asia Cup Rising Stars 2025",
                  "matchDesc": "2nd Match, Group B",
                  "matchFormat": "T20",
                  "startDate": "1763119800000",
                  "endDate": "1763132400000",
                  "state": "Complete",
                  "status": "India A won by 148 runs",
                  "team1": {
                    "teamId": 78,
                    "teamName": "India A",
                    "teamSName": "INDA",
                    "imageId": 776181
                  },
                  "team2": {
                    "teamId": 7,
                    "teamName": "United Arab Emirates",
                    "teamSName": "UAE",
                    "imageId": 776242
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 78,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "INDA Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 297,
                      "wickets": 4,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 149,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137327,
                  "seriesId": 11146,
                  "seriesName": "ACC Mens Asia Cup Rising Stars 2025",
                  "matchDesc": "1st Match, Group B",
                  "matchFormat": "T20",
                  "startDate": "1763101800000",
                  "endDate": "1763114400000",
                  "state": "Complete",
                  "status": "Pakistan A won by 40 runs",
                  "team1": {
                    "teamId": 325,
                    "teamName": "Pakistan A",
                    "teamSName": "PAKA",
                    "imageId": 776313
                  },
                  "team2": {
                    "teamId": 304,
                    "teamName": "Oman",
                    "teamSName": "OMAN",
                    "imageId": 776328
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 325,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PAKA Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 220,
                      "wickets": 4,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 180,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137349,
                  "seriesId": 11146,
                  "seriesName": "ACC Mens Asia Cup Rising Stars 2025",
                  "matchDesc": "3rd Match, Group A",
                  "matchFormat": "T20",
                  "startDate": "1763188200000",
                  "endDate": "1763200800000",
                  "state": "Complete",
                  "status": "Bangladesh A won by 8 wkts",
                  "team1": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "team2": {
                    "teamId": 288,
                    "teamName": "Bangladesh A",
                    "teamSName": "BANA",
                    "imageId": 776212
                  },
                  "venueInfo": {
                    "id": 582,
                    "ground": "West End Park International Cricket Stadium",
                    "city": "Doha",
                    "timezone": "+03:00",
                    "latitude": "25.189391",
                    "longitude": "51.460211"
                  },
                  "currBatTeamId": 288,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1764028800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 167,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 171,
                      "wickets": 2,
                      "overs": 10.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11122,
            "seriesName": "Hong Kong Sixes 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 137215,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Bowl, Final",
                  "matchFormat": "T20",
                  "startDate": "1762667100000",
                  "endDate": "1762679700000",
                  "state": "Complete",
                  "status": "Sri Lanka won by 21 runs",
                  "team1": {
                    "teamId": 5,
                    "teamName": "Sri Lanka",
                    "teamSName": "SL",
                    "imageId": 776254
                  },
                  "team2": {
                    "teamId": 7,
                    "teamName": "United Arab Emirates",
                    "teamSName": "UAE",
                    "imageId": 776242
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 5,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SL Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 106,
                      "wickets": 2,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 85,
                      "wickets": 2,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137182,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Bowl, 6th Match (C3 V D3)",
                  "matchFormat": "T20",
                  "startDate": "1762657200000",
                  "endDate": "1762669800000",
                  "state": "Complete",
                  "status": "Sri Lanka won by 48 runs",
                  "team1": {
                    "teamId": 5,
                    "teamName": "Sri Lanka",
                    "teamSName": "SL",
                    "imageId": 776254
                  },
                  "team2": {
                    "teamId": 2,
                    "teamName": "India",
                    "teamSName": "IND",
                    "imageId": 776162
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 5,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SL Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 138,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 90,
                      "wickets": 3,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137204,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "2nd Semi-Final (WQ3 v WQ4)",
                  "matchFormat": "T20",
                  "startDate": "1762663800000",
                  "endDate": "1762676400000",
                  "state": "Complete",
                  "status": "Kuwait won by 37 runs",
                  "team1": {
                    "teamId": 298,
                    "teamName": "Kuwait",
                    "teamSName": "KUW",
                    "imageId": 776312
                  },
                  "team2": {
                    "teamId": 9,
                    "teamName": "England",
                    "teamSName": "ENG",
                    "imageId": 776237
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 298,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "KUW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 142,
                      "wickets": 6,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 105,
                      "wickets": 3,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137151,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Bowl, 5th Match (A3 V B3)",
                  "matchFormat": "T20",
                  "startDate": "1762647300000",
                  "endDate": "1762659900000",
                  "state": "Complete",
                  "status": "United Arab Emirates won by 43 runs",
                  "team1": {
                    "teamId": 7,
                    "teamName": "United Arab Emirates",
                    "teamSName": "UAE",
                    "imageId": 776242
                  },
                  "team2": {
                    "teamId": 72,
                    "teamName": "Nepal",
                    "teamSName": "NEP",
                    "imageId": 776331
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 7,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "UAE Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 129,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 86,
                      "wickets": 4,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137171,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Plate, 2nd Semi-final (LQ3 V LQ4)",
                  "matchFormat": "T20",
                  "startDate": "1762653900000",
                  "endDate": "1762666500000",
                  "state": "Complete",
                  "status": "Hong Kong won by 5 wkts ",
                  "team1": {
                    "teamId": 96,
                    "teamName": "Afghanistan",
                    "teamSName": "AFG",
                    "imageId": 776177
                  },
                  "team2": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 8,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 95,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 96,
                      "wickets": 1,
                      "overs": 5.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137138,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "3rd Quarter final (D1 V B2)",
                  "matchFormat": "T20",
                  "startDate": "1762587300000",
                  "endDate": "1762599900000",
                  "state": "Complete",
                  "status": "England won by 41 runs",
                  "team1": {
                    "teamId": 9,
                    "teamName": "England",
                    "teamSName": "ENG",
                    "imageId": 776237
                  },
                  "team2": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 9,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "ENG Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 122,
                      "wickets": 4,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 81,
                      "wickets": 6,
                      "overs": 5.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137140,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "4th Quarter final (C1 V A2)",
                  "matchFormat": "T20",
                  "startDate": "1762590600000",
                  "endDate": "1762603200000",
                  "state": "Complete",
                  "status": "Kuwait won by 4 wkts ",
                  "team1": {
                    "teamId": 96,
                    "teamName": "Afghanistan",
                    "teamSName": "AFG",
                    "imageId": 776177
                  },
                  "team2": {
                    "teamId": 298,
                    "teamName": "Kuwait",
                    "teamSName": "KUW",
                    "imageId": 776312
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 298,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "KUW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 87,
                      "wickets": 6,
                      "overs": 5.2
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 90,
                      "wickets": 2,
                      "overs": 5.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137160,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Plate, 1st Semi-final (LQ1 V LQ2)",
                  "matchFormat": "T20",
                  "startDate": "1762650600000",
                  "endDate": "1762663200000",
                  "state": "Complete",
                  "status": "Bangladesh won by 25 runs",
                  "team1": {
                    "teamId": 6,
                    "teamName": "Bangladesh",
                    "teamSName": "BAN",
                    "imageId": 776210
                  },
                  "team2": {
                    "teamId": 11,
                    "teamName": "South Africa",
                    "teamSName": "RSA",
                    "imageId": 776287
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 6,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "BAN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 128,
                      "wickets": 3,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 103,
                      "wickets": 6,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137228,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Final",
                  "matchFormat": "T20",
                  "startDate": "1762673700000",
                  "endDate": "1762686300000",
                  "state": "Complete",
                  "status": "Pakistan won by 43 runs",
                  "team1": {
                    "teamId": 3,
                    "teamName": "Pakistan",
                    "teamSName": "PAK",
                    "imageId": 776308
                  },
                  "team2": {
                    "teamId": 298,
                    "teamName": "Kuwait",
                    "teamSName": "KUW",
                    "imageId": 776312
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 3,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PAK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 135,
                      "wickets": 3,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 92,
                      "wickets": 6,
                      "overs": 5.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137226,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "Plate, Final",
                  "matchFormat": "T20",
                  "startDate": "1762670400000",
                  "endDate": "1762683000000",
                  "state": "Complete",
                  "status": "Hong Kong won by 1 wkts ",
                  "team1": {
                    "teamId": 6,
                    "teamName": "Bangladesh",
                    "teamSName": "BAN",
                    "imageId": 776210
                  },
                  "team2": {
                    "teamId": 8,
                    "teamName": "Hong Kong",
                    "teamSName": "HK",
                    "imageId": 776271
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 8,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 120,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 123,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 137193,
                  "seriesId": 11122,
                  "seriesName": "Hong Kong Sixes 2025",
                  "matchDesc": "1st Semi-Final (WQ1 v WQ2)",
                  "matchFormat": "T20",
                  "startDate": "1762660500000",
                  "endDate": "1762673100000",
                  "state": "Complete",
                  "status": "Pakistan won by 1 run",
                  "team1": {
                    "teamId": 3,
                    "teamName": "Pakistan",
                    "teamSName": "PAK",
                    "imageId": 776308
                  },
                  "team2": {
                    "teamId": 4,
                    "teamName": "Australia",
                    "teamSName": "AUS",
                    "imageId": 776202
                  },
                  "venueInfo": {
                    "id": 454,
                    "ground": "Mission Road Ground",
                    "city": "Mong Kok",
                    "timezone": "+08:00",
                    "latitude": "22.323286",
                    "longitude": "114.1828583"
                  },
                  "currBatTeamId": 3,
                  "seriesStartDt": "1762473600000",
                  "seriesEndDt": "1762819200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PAK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 121,
                      "wickets": 2,
                      "overs": 5.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 120,
                      "wickets": 5,
                      "overs": 5.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11032,
            "seriesName": "CSA T20 Challenge 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 136442,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "18th Match",
                  "matchFormat": "T20",
                  "startDate": "1763132400000",
                  "endDate": "1763145000000",
                  "state": "Complete",
                  "status": "Match tied and Super Over tied (Boland won the 2nd Super Over)",
                  "team1": {
                    "teamId": 1759,
                    "teamName": "Boland",
                    "teamSName": "BOL",
                    "imageId": 349610
                  },
                  "team2": {
                    "teamId": 90,
                    "teamName": "Dolphins",
                    "teamSName": "DOL",
                    "imageId": 172183
                  },
                  "venueInfo": {
                    "id": 207,
                    "ground": "Boland Park",
                    "city": "Paarl",
                    "timezone": "+02:00",
                    "latitude": "-33.730900",
                    "longitude": "18.970760"
                  },
                  "currBatTeamId": 1759,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 134,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 134,
                      "wickets": 10,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136403,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "14th Match",
                  "matchFormat": "T20",
                  "startDate": "1762682400000",
                  "endDate": "1762695000000",
                  "state": "Complete",
                  "status": "Dolphins won by 7 wkts",
                  "team1": {
                    "teamId": 155,
                    "teamName": "Warriors",
                    "teamSName": "WAR",
                    "imageId": 172222
                  },
                  "team2": {
                    "teamId": 90,
                    "teamName": "Dolphins",
                    "teamSName": "DOL",
                    "imageId": 172183
                  },
                  "venueInfo": {
                    "id": 74,
                    "ground": "Kingsmead",
                    "city": "Durban",
                    "timezone": "+02:00",
                    "latitude": "-29.850018",
                    "longitude": "31.027888"
                  },
                  "currBatTeamId": 90,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "DOL Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 94,
                      "wickets": 10,
                      "overs": 19.1
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 100,
                      "wickets": 3,
                      "overs": 14.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136431,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "17th Match",
                  "matchFormat": "T20",
                  "startDate": "1763031600000",
                  "endDate": "1763044200000",
                  "state": "Complete",
                  "status": "Western Province won by 9 wkts",
                  "team1": {
                    "teamId": 1766,
                    "teamName": "KwaZulu-Natal Inland - Tuskers",
                    "teamSName": "KZNIN",
                    "imageId": 349611
                  },
                  "team2": {
                    "teamId": 917,
                    "teamName": "Western Province",
                    "teamSName": "WPR",
                    "imageId": 248460
                  },
                  "venueInfo": {
                    "id": 206,
                    "ground": "City Oval",
                    "city": "Pietermaritzburg",
                    "timezone": "+02:00",
                    "latitude": "-29.551181",
                    "longitude": "30.407238"
                  },
                  "currBatTeamId": 917,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "WPR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 107,
                      "wickets": 10,
                      "overs": 19.4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 109,
                      "wickets": 1,
                      "overs": 15.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136422,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "16th Match",
                  "matchFormat": "T20",
                  "startDate": "1762873200000",
                  "endDate": "1762885800000",
                  "state": "Complete",
                  "status": "North West  -  Eastvaal Renault Dragons won by 25 runs",
                  "team1": {
                    "teamId": 922,
                    "teamName": "North West - Eastvaal Renault Dragons",
                    "teamSName": "NWEST",
                    "imageId": 248439
                  },
                  "team2": {
                    "teamId": 1766,
                    "teamName": "KwaZulu-Natal Inland - Tuskers",
                    "teamSName": "KZNIN",
                    "imageId": 349611
                  },
                  "venueInfo": {
                    "id": 102,
                    "ground": "Senwes Park",
                    "city": "Potchefstroom",
                    "timezone": "+02:00",
                    "latitude": "-26.695565",
                    "longitude": "27.100691"
                  },
                  "currBatTeamId": 922,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "NWEST Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 173,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 148,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136453,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "19th Match",
                  "matchFormat": "T20",
                  "startDate": "1763136000000",
                  "endDate": "1763148600000",
                  "state": "Complete",
                  "status": "Titans won by 7 runs",
                  "team1": {
                    "teamId": 89,
                    "teamName": "Titans",
                    "teamSName": "TIT",
                    "imageId": 172182
                  },
                  "team2": {
                    "teamId": 922,
                    "teamName": "North West - Eastvaal Renault Dragons",
                    "teamSName": "NWEST",
                    "imageId": 248439
                  },
                  "venueInfo": {
                    "id": 102,
                    "ground": "Senwes Park",
                    "city": "Potchefstroom",
                    "timezone": "+02:00",
                    "latitude": "-26.695565",
                    "longitude": "27.100691"
                  },
                  "currBatTeamId": 89,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 196,
                      "wickets": 6,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 189,
                      "wickets": 6,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136392,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "13th Match",
                  "matchFormat": "T20",
                  "startDate": "1762687800000",
                  "endDate": "1762700400000",
                  "state": "Complete",
                  "status": "Western Province won by 83 runs",
                  "team1": {
                    "teamId": 917,
                    "teamName": "Western Province",
                    "teamSName": "WPR",
                    "imageId": 248460
                  },
                  "team2": {
                    "teamId": 89,
                    "teamName": "Titans",
                    "teamSName": "TIT",
                    "imageId": 172182
                  },
                  "venueInfo": {
                    "id": 52,
                    "ground": "Newlands",
                    "city": "Cape Town",
                    "timezone": "+02:00",
                    "latitude": "-33.979629",
                    "longitude": "18.459466"
                  },
                  "currBatTeamId": 917,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "WPR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 225,
                      "wickets": 6,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 142,
                      "wickets": 10,
                      "overs": 17.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136414,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "15th Match",
                  "matchFormat": "T20",
                  "startDate": "1762876800000",
                  "endDate": "1762889400000",
                  "state": "Complete",
                  "status": "Warriors won by 8 wkts",
                  "team1": {
                    "teamId": 157,
                    "teamName": "Lions",
                    "teamSName": "LIONS",
                    "imageId": 172224
                  },
                  "team2": {
                    "teamId": 155,
                    "teamName": "Warriors",
                    "teamSName": "WAR",
                    "imageId": 172222
                  },
                  "venueInfo": {
                    "id": 73,
                    "ground": "St George's Park",
                    "city": "Gqeberha",
                    "timezone": "+02:00",
                    "latitude": "-33.966545",
                    "longitude": "25.610332"
                  },
                  "currBatTeamId": 155,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "WAR Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 146,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 151,
                      "wickets": 2,
                      "overs": 17.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 136381,
                  "seriesId": 11032,
                  "seriesName": "CSA T20 Challenge 2025",
                  "matchDesc": "12th Match",
                  "matchFormat": "T20",
                  "startDate": "1762599600000",
                  "endDate": "1762612200000",
                  "state": "Complete",
                  "status": "KwaZulu - Natal Inland - Tuskers won by 2 runs",
                  "team1": {
                    "teamId": 1766,
                    "teamName": "KwaZulu-Natal Inland - Tuskers",
                    "teamSName": "KZNIN",
                    "imageId": 349611
                  },
                  "team2": {
                    "teamId": 157,
                    "teamName": "Lions",
                    "teamSName": "LIONS",
                    "imageId": 172224
                  },
                  "venueInfo": {
                    "id": 88,
                    "ground": "The Wanderers Stadium",
                    "city": "Johannesburg",
                    "timezone": "+02:00",
                    "latitude": "-26.131141",
                    "longitude": "28.057397"
                  },
                  "currBatTeamId": 1766,
                  "seriesStartDt": "1761696000000",
                  "seriesEndDt": "1764633600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "KZNIN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 161,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 159,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  }
                }
              }
            ]
          }
        }
      ]
    },
    {
      "matchType": "Domestic",
      "seriesMatches": [
        {
          "seriesAdWrapper": {
            "seriesId": 9938,
            "seriesName": "South Africa A tour of India, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 119897,
                  "seriesId": 9938,
                  "seriesName": "South Africa A tour of India, 2025",
                  "matchDesc": "1st Unofficial ODI",
                  "matchFormat": "ODI",
                  "startDate": "1763020800000",
                  "endDate": "1763049600000",
                  "state": "Complete",
                  "status": "India A won by 4 wkts",
                  "team1": {
                    "teamId": 268,
                    "teamName": "South Africa A",
                    "teamSName": "RSAA",
                    "imageId": 776296
                  },
                  "team2": {
                    "teamId": 78,
                    "teamName": "India A",
                    "teamSName": "INDA",
                    "imageId": 776181
                  },
                  "venueInfo": {
                    "id": 290,
                    "ground": "Niranjan Shah Stadium, Khandheri",
                    "city": "Rajkot",
                    "timezone": "+05:30",
                    "latitude": "22.289721",
                    "longitude": "70.793182"
                  },
                  "currBatTeamId": 78,
                  "seriesStartDt": "1761782400000",
                  "seriesEndDt": "1763683200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "INDA Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 285,
                      "wickets": 9,
                      "overs": 50
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 290,
                      "wickets": 6,
                      "overs": 49.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 119888,
                  "seriesId": 9938,
                  "seriesName": "South Africa A tour of India, 2025",
                  "matchDesc": "2nd Unofficial Test",
                  "matchFormat": "TEST",
                  "startDate": "1762401600000",
                  "endDate": "1762686000000",
                  "state": "Complete",
                  "status": "South Africa A won by 5 wkts",
                  "team1": {
                    "teamId": 78,
                    "teamName": "India A",
                    "teamSName": "INDA",
                    "imageId": 776181
                  },
                  "team2": {
                    "teamId": 268,
                    "teamName": "South Africa A",
                    "teamSName": "RSAA",
                    "imageId": 776296
                  },
                  "venueInfo": {
                    "id": 1438087,
                    "ground": "BCCI Centre of Excellence Ground 1",
                    "city": "Bengaluru",
                    "timezone": "+05:30",
                    "latitude": "12.978853",
                    "longitude": "77.599533"
                  },
                  "currBatTeamId": 268,
                  "seriesStartDt": "1761782400000",
                  "seriesEndDt": "1763683200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "RSAA Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 255,
                      "wickets": 10,
                      "overs": 77.1
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 382,
                      "wickets": 7,
                      "overs": 89.2,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 221,
                      "wickets": 10,
                      "overs": 47.3
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 417,
                      "wickets": 5,
                      "overs": 97.6
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10317,
            "seriesName": "Ranji Trophy Elite 2025-26",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 124568,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group C",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Gujarat won by 6 wkts",
                  "team1": {
                    "teamId": 250,
                    "teamName": "Services",
                    "teamSName": "SER",
                    "imageId": 172303
                  },
                  "team2": {
                    "teamId": 163,
                    "teamName": "Gujarat",
                    "teamSName": "GUJ",
                    "imageId": 172232
                  },
                  "venueInfo": {
                    "id": 1437937,
                    "ground": "Gokulbhai Somabhai Patel Stadium",
                    "city": "Nadiad",
                    "timezone": "+05:30",
                    "latitude": "22.6598125",
                    "longitude": "72.8928782"
                  },
                  "currBatTeamId": 163,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "GUJ Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 248,
                      "wickets": 10,
                      "overs": 115
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 125,
                      "wickets": 10,
                      "overs": 37.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 256,
                      "wickets": 10,
                      "overs": 85.4
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 118,
                      "wickets": 4,
                      "overs": 21.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124618,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group D",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 242,
                    "teamName": "Hyderabad",
                    "teamSName": "HYD",
                    "imageId": 172295
                  },
                  "team2": {
                    "teamId": 171,
                    "teamName": "Rajasthan",
                    "teamSName": "RAJ",
                    "imageId": 172239
                  },
                  "venueInfo": {
                    "id": 1836,
                    "ground": "NexGen Cricket Ground",
                    "city": "Hyderabad",
                    "timezone": "+05:30",
                    "latitude": "17.4644927",
                    "longitude": "78.256925"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 364,
                      "wickets": 10,
                      "overs": 104.1
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 244,
                      "wickets": 9,
                      "overs": 78,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 269,
                      "wickets": 10,
                      "overs": 94.4
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 207,
                      "wickets": 3,
                      "overs": 57
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124563,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group C",
                  "matchFormat": "TEST",
                  "startDate": "1762570800000",
                  "endDate": "1762855200000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 247,
                    "teamName": "Tripura",
                    "teamSName": "TRI",
                    "imageId": 172300
                  },
                  "team2": {
                    "teamId": 162,
                    "teamName": "Assam",
                    "teamSName": "ASM",
                    "imageId": 172230
                  },
                  "venueInfo": {
                    "id": 316,
                    "ground": "Maharaja Bir Bikram College Stadium",
                    "city": "Agartala",
                    "timezone": "+05:30",
                    "latitude": "23.828066",
                    "longitude": "91.297049"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 602,
                      "wickets": 7,
                      "overs": 142.6,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 238,
                      "wickets": 10,
                      "overs": 77.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 367,
                      "wickets": 7,
                      "overs": 117.4,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124557,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group B",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 94,
                    "teamName": "Saurashtra",
                    "teamSName": "SAUR",
                    "imageId": 172186
                  },
                  "team2": {
                    "teamId": 244,
                    "teamName": "Kerala",
                    "teamSName": "KER",
                    "imageId": 172297
                  },
                  "venueInfo": {
                    "id": 866,
                    "ground": "KCA Cricket Ground, Mangalapuram",
                    "city": "Thiruvananthapuram",
                    "timezone": "+05:30",
                    "latitude": "8.5602859",
                    "longitude": "76.8449651"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 160,
                      "wickets": 10,
                      "overs": 55.2
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 402,
                      "wickets": 8,
                      "overs": 97.6,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 233,
                      "wickets": 10,
                      "overs": 74.5
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 154,
                      "wickets": 3,
                      "overs": 62.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124612,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group D",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Jammu and Kashmir won by 7 wkts",
                  "team1": {
                    "teamId": 81,
                    "teamName": "Delhi",
                    "teamSName": "DEL",
                    "imageId": 172175
                  },
                  "team2": {
                    "teamId": 252,
                    "teamName": "Jammu and Kashmir",
                    "teamSName": "JK",
                    "imageId": 172305
                  },
                  "venueInfo": {
                    "id": 51,
                    "ground": "Arun Jaitley Stadium",
                    "city": "Delhi",
                    "timezone": "+05:30",
                    "latitude": "28.637891",
                    "longitude": "77.243073"
                  },
                  "currBatTeamId": 252,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "JK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 211,
                      "wickets": 10,
                      "overs": 68.6
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 277,
                      "wickets": 10,
                      "overs": 69.1
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 310,
                      "wickets": 10,
                      "overs": 91.2
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 179,
                      "wickets": 3,
                      "overs": 43.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124579,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group C",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Bengal won by an innings and 120 runs",
                  "team1": {
                    "teamId": 232,
                    "teamName": "Bengal",
                    "teamSName": "BEN",
                    "imageId": 172285
                  },
                  "team2": {
                    "teamId": 246,
                    "teamName": "Railways",
                    "teamSName": "RLYS",
                    "imageId": 172299
                  },
                  "venueInfo": {
                    "id": 308,
                    "ground": "Lalbhai Contractor Stadium, Vesu",
                    "city": "Surat",
                    "timezone": "+05:30",
                    "latitude": "21.155455",
                    "longitude": "72.769226"
                  },
                  "currBatTeamId": 232,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "BEN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 474,
                      "wickets": 10,
                      "overs": 129.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 222,
                      "wickets": 10,
                      "overs": 86.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 132,
                      "wickets": 10,
                      "overs": 55.5,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124590,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group C",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Uttarakhand won by an innings and 28 runs",
                  "team1": {
                    "teamId": 200,
                    "teamName": "Haryana",
                    "teamSName": "HAR",
                    "imageId": 172260
                  },
                  "team2": {
                    "teamId": 467,
                    "teamName": "Uttarakhand",
                    "teamSName": "UTK",
                    "imageId": 172515
                  },
                  "venueInfo": {
                    "id": 288,
                    "ground": "Ch Bansi Lal Cricket Stadium",
                    "city": "Rohtak",
                    "timezone": "+05:30",
                    "latitude": "28.854644",
                    "longitude": "76.46442"
                  },
                  "currBatTeamId": 467,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "UTK Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 112,
                      "wickets": 10,
                      "overs": 48.1
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 148,
                      "wickets": 10,
                      "overs": 60.4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 288,
                      "wickets": 10,
                      "overs": 94.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124607,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group D",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Mumbai won by an innings and 120 runs",
                  "team1": {
                    "teamId": 95,
                    "teamName": "Mumbai",
                    "teamSName": "MUM",
                    "imageId": 172187
                  },
                  "team2": {
                    "teamId": 251,
                    "teamName": "Himachal Pradesh",
                    "teamSName": "HP",
                    "imageId": 172304
                  },
                  "venueInfo": {
                    "id": 341,
                    "ground": "Sharad Pawar Cricket Academy BKC",
                    "city": "Mumbai",
                    "timezone": "+05:30",
                    "latitude": "19.061309",
                    "longitude": "72.866381"
                  },
                  "currBatTeamId": 95,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MUM Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 446,
                      "wickets": 10,
                      "overs": 137.2
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 187,
                      "wickets": 10,
                      "overs": 65.5
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 139,
                      "wickets": 10,
                      "overs": 49.1,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124596,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group D",
                  "matchFormat": "TEST",
                  "startDate": "1762573500000",
                  "endDate": "1762857900000",
                  "state": "Complete",
                  "status": "Chhattisgarh won by 10 wkts",
                  "team1": {
                    "teamId": 375,
                    "teamName": "Chhattisgarh",
                    "teamSName": "CG",
                    "imageId": 172428
                  },
                  "team2": {
                    "teamId": 465,
                    "teamName": "Puducherry",
                    "teamSName": "PDC",
                    "imageId": 172513
                  },
                  "venueInfo": {
                    "id": 335,
                    "ground": "Shaheed Veer Narayan Singh International Stadium",
                    "city": "Raipur",
                    "timezone": "+05:30",
                    "latitude": "21.203523",
                    "longitude": "81.823929"
                  },
                  "currBatTeamId": 375,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "CG Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 377,
                      "wickets": 10,
                      "overs": 135.6
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 205,
                      "wickets": 10,
                      "overs": 60.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 175,
                      "wickets": 10,
                      "overs": 51.1,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124541,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group B",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Madhya Pradesh won by 3 wkts",
                  "team1": {
                    "teamId": 253,
                    "teamName": "Goa",
                    "teamSName": "GOA",
                    "imageId": 172306
                  },
                  "team2": {
                    "teamId": 167,
                    "teamName": "Madhya Pradesh",
                    "teamSName": "MP",
                    "imageId": 172236
                  },
                  "venueInfo": {
                    "id": 310,
                    "ground": "Goa Cricket Association Academy Ground",
                    "city": "Porvorim",
                    "timezone": "+05:30",
                    "latitude": "15.524168",
                    "longitude": "73.829683"
                  },
                  "currBatTeamId": 167,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MP Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 284,
                      "wickets": 10,
                      "overs": 95.5
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 230,
                      "wickets": 10,
                      "overs": 65.4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 187,
                      "wickets": 10,
                      "overs": 75.6
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 328,
                      "wickets": 7,
                      "overs": 93.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124519,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group A",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Vidarbha won by 100 runs",
                  "team1": {
                    "teamId": 248,
                    "teamName": "Vidarbha",
                    "teamSName": "VID",
                    "imageId": 172301
                  },
                  "team2": {
                    "teamId": 249,
                    "teamName": "Odisha",
                    "teamSName": "ODSA",
                    "imageId": 776395
                  },
                  "venueInfo": {
                    "id": 228,
                    "ground": "Vidarbha Cricket Association Stadium",
                    "city": "Nagpur",
                    "timezone": "+05:30",
                    "latitude": "21.013566",
                    "longitude": "79.039576"
                  },
                  "currBatTeamId": 248,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "VID Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 286,
                      "wickets": 10,
                      "overs": 118.4
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 218,
                      "wickets": 2,
                      "overs": 58.6,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 160,
                      "wickets": 10,
                      "overs": 71.6
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 244,
                      "wickets": 10,
                      "overs": 83.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124513,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group A",
                  "matchFormat": "TEST",
                  "startDate": "1762572600000",
                  "endDate": "1762857000000",
                  "state": "Complete",
                  "status": "Andhra won by 4 wkts",
                  "team1": {
                    "teamId": 92,
                    "teamName": "Tamil Nadu",
                    "teamSName": "TN",
                    "imageId": 172184
                  },
                  "team2": {
                    "teamId": 241,
                    "teamName": "Andhra",
                    "teamSName": "AP",
                    "imageId": 172294
                  },
                  "venueInfo": {
                    "id": 154,
                    "ground": "ACA-VDCA Cricket Stadium",
                    "city": "Visakhapatnam",
                    "timezone": "+05:30",
                    "latitude": "17.797459",
                    "longitude": "83.352254"
                  },
                  "currBatTeamId": 241,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "AP Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 182,
                      "wickets": 10,
                      "overs": 74.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 195,
                      "wickets": 10,
                      "overs": 70.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 177,
                      "wickets": 10,
                      "overs": 48.6
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 201,
                      "wickets": 6,
                      "overs": 41.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124508,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group A",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Uttar Pradesh won by an innings and 265 runs",
                  "team1": {
                    "teamId": 93,
                    "teamName": "Uttar Pradesh",
                    "teamSName": "UP",
                    "imageId": 172185
                  },
                  "team2": {
                    "teamId": 464,
                    "teamName": "Nagaland",
                    "teamSName": "NGL",
                    "imageId": 776394
                  },
                  "venueInfo": {
                    "id": 32,
                    "ground": "Green Park",
                    "city": "Kanpur",
                    "timezone": "+05:30",
                    "latitude": "26.482069",
                    "longitude": "80.34773"
                  },
                  "currBatTeamId": 93,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "UP Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 535,
                      "wickets": 6,
                      "overs": 138.4,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 117,
                      "wickets": 10,
                      "overs": 45.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 153,
                      "wickets": 10,
                      "overs": 51.1,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124546,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group B",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Punjab won by 8 wkts",
                  "team1": {
                    "teamId": 595,
                    "teamName": "Chandigarh",
                    "teamSName": "CDG",
                    "imageId": 244269
                  },
                  "team2": {
                    "teamId": 245,
                    "teamName": "Punjab",
                    "teamSName": "PUN",
                    "imageId": 172298
                  },
                  "venueInfo": {
                    "id": 120,
                    "ground": "Sector 16 Stadium",
                    "city": "Chandigarh",
                    "timezone": "+05:30",
                    "latitude": "30.741797",
                    "longitude": "76.774915"
                  },
                  "currBatTeamId": 245,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PUN Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 173,
                      "wickets": 10,
                      "overs": 50.6
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 195,
                      "wickets": 10,
                      "overs": 68.5
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 142,
                      "wickets": 10,
                      "overs": 57.2
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 227,
                      "wickets": 2,
                      "overs": 66.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124524,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group A",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 243,
                    "teamName": "Jharkhand",
                    "teamSName": "JHKD",
                    "imageId": 172296
                  },
                  "team2": {
                    "teamId": 170,
                    "teamName": "Baroda",
                    "teamSName": "BRD",
                    "imageId": 172238
                  },
                  "venueInfo": {
                    "id": 1843,
                    "ground": "BCA Stadium, Kotambi",
                    "city": "Vadodara",
                    "timezone": "+05:30",
                    "latitude": "22.3234",
                    "longitude": "73.1607"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 506,
                      "wickets": 10,
                      "overs": 139.6
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 226,
                      "wickets": 4,
                      "overs": 65.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 291,
                      "wickets": 10,
                      "overs": 103.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 124535,
                  "seriesId": 10317,
                  "seriesName": "Ranji Trophy Elite 2025-26",
                  "matchDesc": "Elite Group B",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 128,
                    "teamName": "Karnataka",
                    "teamSName": "KAR",
                    "imageId": 776345
                  },
                  "team2": {
                    "teamId": 254,
                    "teamName": "Maharashtra",
                    "teamSName": "MAH",
                    "imageId": 172307
                  },
                  "venueInfo": {
                    "id": 287,
                    "ground": "Maharashtra Cricket Association Stadium",
                    "city": "Pune",
                    "timezone": "+05:30",
                    "latitude": "18.674498",
                    "longitude": "73.706516"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 313,
                      "wickets": 10,
                      "overs": 110.6
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 309,
                      "wickets": 8,
                      "overs": 109.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 300,
                      "wickets": 10,
                      "overs": 99.2
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10724,
            "seriesName": "The Ford Trophy 2025-26",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 132010,
                  "seriesId": 10724,
                  "seriesName": "The Ford Trophy 2025-26",
                  "matchDesc": "15th Match",
                  "matchFormat": "ODI",
                  "startDate": "1762896600000",
                  "endDate": "1762925400000",
                  "state": "Complete",
                  "status": "No result (due to rain)",
                  "team1": {
                    "teamId": 294,
                    "teamName": "Northern Knights",
                    "teamSName": "NK",
                    "imageId": 172343
                  },
                  "team2": {
                    "teamId": 105,
                    "teamName": "Otago",
                    "teamSName": "OTG",
                    "imageId": 172197
                  },
                  "venueInfo": {
                    "id": 393,
                    "ground": "Bay Oval",
                    "city": "Mount Maunganui",
                    "timezone": "+13:00",
                    "latitude": "-37.670300",
                    "longitude": "176.212006"
                  },
                  "seriesStartDt": "1761350400000",
                  "seriesEndDt": "1771891200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 209,
                      "wickets": 5,
                      "overs": 41.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 132005,
                  "seriesId": 10724,
                  "seriesName": "The Ford Trophy 2025-26",
                  "matchDesc": "14th Match",
                  "matchFormat": "ODI",
                  "startDate": "1762896600000",
                  "endDate": "1762925400000",
                  "state": "Complete",
                  "status": "Auckland won by 54 runs",
                  "team1": {
                    "teamId": 186,
                    "teamName": "Auckland",
                    "teamSName": "AKL",
                    "imageId": 172246
                  },
                  "team2": {
                    "teamId": 314,
                    "teamName": "Wellington",
                    "teamSName": "WEL",
                    "imageId": 172364
                  },
                  "venueInfo": {
                    "id": 45,
                    "ground": "Basin Reserve",
                    "city": "Wellington",
                    "timezone": "+13:00",
                    "latitude": "-41.161720",
                    "longitude": "175.323914"
                  },
                  "currBatTeamId": 186,
                  "seriesStartDt": "1761350400000",
                  "seriesEndDt": "1771891200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "AKL Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 286,
                      "wickets": 9,
                      "overs": 49.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 232,
                      "wickets": 9,
                      "overs": 49.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 131994,
                  "seriesId": 10724,
                  "seriesName": "The Ford Trophy 2025-26",
                  "matchDesc": "13th Match",
                  "matchFormat": "ODI",
                  "startDate": "1762896600000",
                  "endDate": "1762925400000",
                  "state": "Complete",
                  "status": "Canterbury won by 8 wkts",
                  "team1": {
                    "teamId": 313,
                    "teamName": "Central Districts",
                    "teamSName": "CD",
                    "imageId": 172363
                  },
                  "team2": {
                    "teamId": 312,
                    "teamName": "Canterbury",
                    "teamSName": "CNTBRY",
                    "imageId": 172362
                  },
                  "venueInfo": {
                    "id": 420,
                    "ground": "Mainpower Oval",
                    "city": "Rangiora",
                    "timezone": "+13:00",
                    "latitude": "-43.305302",
                    "longitude": "172.593994"
                  },
                  "currBatTeamId": 312,
                  "seriesStartDt": "1761350400000",
                  "seriesEndDt": "1771891200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "CNTBRY Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 264,
                      "wickets": 5,
                      "overs": 49.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 266,
                      "wickets": 2,
                      "overs": 43.4
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10823,
            "seriesName": "Sheffield Shield 2025-26",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 133281,
                  "seriesId": 10823,
                  "seriesName": "Sheffield Shield 2025-26",
                  "matchDesc": "12th Match",
                  "matchFormat": "TEST",
                  "startDate": "1762828200000",
                  "endDate": "1763112600000",
                  "state": "Complete",
                  "status": "Western Australia won by 1 wkt",
                  "team1": {
                    "teamId": 164,
                    "teamName": "Queensland",
                    "teamSName": "QL",
                    "imageId": 172233
                  },
                  "team2": {
                    "teamId": 87,
                    "teamName": "Western Australia",
                    "teamSName": "WA",
                    "imageId": 172180
                  },
                  "venueInfo": {
                    "id": 38,
                    "ground": "W.A.C.A. Ground",
                    "city": "Perth",
                    "timezone": "+08:00",
                    "latitude": "-31.959806",
                    "longitude": "115.879585"
                  },
                  "currBatTeamId": 87,
                  "seriesStartDt": "1759536000000",
                  "seriesEndDt": "1774915200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "WA Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 390,
                      "wickets": 10,
                      "overs": 104.6
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 203,
                      "wickets": 10,
                      "overs": 58.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 322,
                      "wickets": 7,
                      "overs": 107.3,
                      "isDeclared": True
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 272,
                      "wickets": 9,
                      "overs": 82.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 133264,
                  "seriesId": 10823,
                  "seriesName": "Sheffield Shield 2025-26",
                  "matchDesc": "10th Match",
                  "matchFormat": "TEST",
                  "startDate": "1762731000000",
                  "endDate": "1763015400000",
                  "state": "Complete",
                  "status": "Victoria won by 300 runs",
                  "team1": {
                    "teamId": 52,
                    "teamName": "Victoria",
                    "teamSName": "VIC",
                    "imageId": 172153
                  },
                  "team2": {
                    "teamId": 104,
                    "teamName": "New South Wales",
                    "teamSName": "NSW",
                    "imageId": 172196
                  },
                  "venueInfo": {
                    "id": 34,
                    "ground": "Sydney Cricket Ground",
                    "city": "Sydney",
                    "timezone": "+11:00",
                    "latitude": "-33.868820",
                    "longitude": "151.209296"
                  },
                  "currBatTeamId": 52,
                  "seriesStartDt": "1759536000000",
                  "seriesEndDt": "1774915200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "VIC Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 382,
                      "wickets": 10,
                      "overs": 103.1
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 171,
                      "wickets": 9,
                      "overs": 63.3,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 128,
                      "wickets": 10,
                      "overs": 49.5
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 125,
                      "wickets": 10,
                      "overs": 39.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 133270,
                  "seriesId": 10823,
                  "seriesName": "Sheffield Shield 2025-26",
                  "matchDesc": "11th Match",
                  "matchFormat": "TEST",
                  "startDate": "1762731000000",
                  "endDate": "1763015400000",
                  "state": "Complete",
                  "status": "South Australia won by 3 wkts",
                  "team1": {
                    "teamId": 166,
                    "teamName": "Tasmania",
                    "teamSName": "TAS",
                    "imageId": 172235
                  },
                  "team2": {
                    "teamId": 158,
                    "teamName": "South Australia",
                    "teamSName": "SAUS",
                    "imageId": 172225
                  },
                  "venueInfo": {
                    "id": 39,
                    "ground": "Bellerive Oval",
                    "city": "Hobart",
                    "timezone": "+11:00",
                    "latitude": "-42.877296",
                    "longitude": "147.374013"
                  },
                  "currBatTeamId": 158,
                  "seriesStartDt": "1759536000000",
                  "seriesEndDt": "1774915200000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SAUS Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 209,
                      "wickets": 10,
                      "overs": 64.2
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 184,
                      "wickets": 10,
                      "overs": 51.5
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 177,
                      "wickets": 10,
                      "overs": 47.6
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 219,
                      "wickets": 7,
                      "overs": 51.5
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10829,
            "seriesName": "Australia Domestic One-Day Cup 2025-26",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 133567,
                  "seriesId": 10829,
                  "seriesName": "Australia Domestic One-Day Cup 2025-26",
                  "matchDesc": "14th Match",
                  "matchFormat": "ODI",
                  "startDate": "1763163000000",
                  "endDate": "1763191800000",
                  "state": "Complete",
                  "status": "Tasmania won by 4 wkts",
                  "team1": {
                    "teamId": 158,
                    "teamName": "South Australia",
                    "teamSName": "SAUS",
                    "imageId": 172225
                  },
                  "team2": {
                    "teamId": 166,
                    "teamName": "Tasmania",
                    "teamSName": "TAS",
                    "imageId": 172235
                  },
                  "venueInfo": {
                    "id": 39,
                    "ground": "Bellerive Oval",
                    "city": "Hobart",
                    "timezone": "+11:00",
                    "latitude": "-42.877296",
                    "longitude": "147.374013"
                  },
                  "currBatTeamId": 166,
                  "seriesStartDt": "1757980800000",
                  "seriesEndDt": "1772409600000",
                  "isTimeAnnounced": True,
                  "stateTitle": "TAS Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 195,
                      "wickets": 10,
                      "overs": 46.2
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 196,
                      "wickets": 6,
                      "overs": 39.4
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11188,
            "seriesName": "England Lions tour of Australia, 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 137844,
                  "seriesId": 11188,
                  "seriesName": "England Lions tour of Australia, 2025",
                  "matchDesc": "3-day Warm-up Match",
                  "matchFormat": "TEST",
                  "startDate": "1762999200000",
                  "endDate": "1763197200000",
                  "state": "Complete",
                  "status": "England won by 5 wkts",
                  "team1": {
                    "teamId": 42,
                    "teamName": "England Lions",
                    "teamSName": "ENGA",
                    "imageId": 776239
                  },
                  "team2": {
                    "teamId": 9,
                    "teamName": "England",
                    "teamSName": "ENG",
                    "imageId": 776237
                  },
                  "venueInfo": {
                    "id": 481,
                    "ground": "Lilac Hill Park",
                    "city": "Perth",
                    "timezone": "+08:00",
                    "latitude": "-31.950527",
                    "longitude": "115.860457"
                  },
                  "currBatTeamId": 9,
                  "seriesStartDt": "1762992000000",
                  "seriesEndDt": "1765324800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 375,
                      "wickets": 10,
                      "overs": 79.3
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 251,
                      "wickets": 6,
                      "overs": 44.5,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 426,
                      "wickets": 10,
                      "overs": 85.3
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 202,
                      "wickets": 5,
                      "overs": 34.4
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 10333,
            "seriesName": "Ranji Trophy Plate 2025-26",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 123782,
                  "seriesId": 10333,
                  "seriesName": "Ranji Trophy Plate 2025-26",
                  "matchDesc": "Plate",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Manipur won by 5 wkts",
                  "team1": {
                    "teamId": 461,
                    "teamName": "Manipur",
                    "teamSName": "MNP",
                    "imageId": 172509
                  },
                  "team2": {
                    "teamId": 463,
                    "teamName": "Mizoram",
                    "teamSName": "MIZ",
                    "imageId": 776489
                  },
                  "venueInfo": {
                    "id": 1839,
                    "ground": "Lal Bahadur Shastri Stadium",
                    "city": "Vallabh Vidyanagar, Anand",
                    "timezone": "+05:30",
                    "latitude": "22.5535346",
                    "longitude": "72.9622762"
                  },
                  "currBatTeamId": 461,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1769558400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MNP Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 400,
                      "wickets": 10,
                      "overs": 133.1
                    },
                    "inngs2": {
                      "inningsId": 4,
                      "runs": 12,
                      "wickets": 5,
                      "overs": 4.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 143,
                      "wickets": 10,
                      "overs": 51.4
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 268,
                      "wickets": 10,
                      "overs": 73.5,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 123771,
                  "seriesId": 10333,
                  "seriesName": "Ranji Trophy Plate 2025-26",
                  "matchDesc": "Plate",
                  "matchFormat": "TEST",
                  "startDate": "1762574400000",
                  "endDate": "1762858800000",
                  "state": "Complete",
                  "status": "Meghalaya won by an innings and 446 runs",
                  "team1": {
                    "teamId": 462,
                    "teamName": "Meghalaya",
                    "teamSName": "MGLY",
                    "imageId": 172510
                  },
                  "team2": {
                    "teamId": 468,
                    "teamName": "Arunachal Pradesh",
                    "teamSName": "ARNP",
                    "imageId": 172516
                  },
                  "venueInfo": {
                    "id": 552,
                    "ground": "Pithwala Stadium",
                    "city": "Bhimpore, Surat",
                    "timezone": "+05:30",
                    "latitude": "21.082924",
                    "longitude": "72.732645"
                  },
                  "currBatTeamId": 462,
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1769558400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MGLY Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 628,
                      "wickets": 6,
                      "overs": 127,
                      "isDeclared": True
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 73,
                      "wickets": 10,
                      "overs": 27.4
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 109,
                      "wickets": 10,
                      "overs": 42.4,
                      "isFollowOn": True
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 123760,
                  "seriesId": 10333,
                  "seriesName": "Ranji Trophy Plate 2025-26",
                  "matchDesc": "Plate",
                  "matchFormat": "TEST",
                  "startDate": "1762569900000",
                  "endDate": "1762854300000",
                  "state": "Complete",
                  "status": "Match drawn",
                  "team1": {
                    "teamId": 460,
                    "teamName": "Bihar",
                    "teamSName": "BIH",
                    "imageId": 172508
                  },
                  "team2": {
                    "teamId": 466,
                    "teamName": "Sikkim",
                    "teamSName": "SKM",
                    "imageId": 172514
                  },
                  "venueInfo": {
                    "id": 1265,
                    "ground": "SICA ground",
                    "city": "Rangpo",
                    "timezone": "+05:30",
                    "latitude": "27.177401",
                    "longitude": "88.530701"
                  },
                  "seriesStartDt": "1760486400000",
                  "seriesEndDt": "1769558400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 265,
                      "wickets": 10,
                      "overs": 77.4
                    },
                    "inngs2": {
                      "inningsId": 3,
                      "runs": 392,
                      "wickets": 6,
                      "overs": 115.1
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 429,
                      "wickets": 10,
                      "overs": 143.5
                    }
                  }
                }
              }
            ]
          }
        }
      ]
    },
    {
      "matchType": "Women",
      "seriesMatches": [
        {
          "seriesAdWrapper": {
            "seriesId": 10405,
            "seriesName": "Womens Big Bash League 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 126724,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "8th Match",
                  "matchFormat": "T20",
                  "startDate": "1763095200000",
                  "endDate": "1763107800000",
                  "state": "Complete",
                  "status": "Melbourne Stars Women won by 16 runs (DLS Method)",
                  "team1": {
                    "teamId": 359,
                    "teamName": "Melbourne Stars Women",
                    "teamSName": "MLSW",
                    "imageId": 172405
                  },
                  "team2": {
                    "teamId": 360,
                    "teamName": "Perth Scorchers Women",
                    "teamSName": "PRSW",
                    "imageId": 172406
                  },
                  "venueInfo": {
                    "id": 527,
                    "ground": "Karen Rolton Oval",
                    "city": "Adelaide, South Australia",
                    "timezone": "+10:30",
                    "latitude": "-34.9191215",
                    "longitude": "138.5815232"
                  },
                  "currBatTeamId": 359,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MLSW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 173,
                      "wickets": 4,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 78,
                      "wickets": 8,
                      "overs": 8.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126741,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "10th Match",
                  "matchFormat": "T20",
                  "startDate": "1763181600000",
                  "endDate": "1763194200000",
                  "state": "Complete",
                  "status": "Hobart Hurricanes Women won by 16 runs (DLS Method)",
                  "team1": {
                    "teamId": 357,
                    "teamName": "Hobart Hurricanes Women",
                    "teamSName": "HBHW",
                    "imageId": 172403
                  },
                  "team2": {
                    "teamId": 356,
                    "teamName": "Brisbane Heat Women",
                    "teamSName": "BRHW",
                    "imageId": 172402
                  },
                  "venueInfo": {
                    "id": 378,
                    "ground": "Drummoyne Oval",
                    "city": "Sydney",
                    "timezone": "+11:00",
                    "latitude": "-33.868820",
                    "longitude": "151.209296"
                  },
                  "currBatTeamId": 357,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HBHW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 114,
                      "wickets": 1,
                      "overs": 11.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 108,
                      "wickets": 9,
                      "overs": 11.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126730,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "9th Match",
                  "matchFormat": "T20",
                  "startDate": "1763107800000",
                  "endDate": "1763120400000",
                  "state": "Complete",
                  "status": "Adelaide Strikers Women won by 7 wkts",
                  "team1": {
                    "teamId": 358,
                    "teamName": "Melbourne Renegades Women",
                    "teamSName": "MLRW",
                    "imageId": 172404
                  },
                  "team2": {
                    "teamId": 355,
                    "teamName": "Adelaide Strikers Women",
                    "teamSName": "ADSW",
                    "imageId": 172401
                  },
                  "venueInfo": {
                    "id": 527,
                    "ground": "Karen Rolton Oval",
                    "city": "Adelaide, South Australia",
                    "timezone": "+10:30",
                    "latitude": "-34.9191215",
                    "longitude": "138.5815232"
                  },
                  "currBatTeamId": 355,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "ADSW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 141,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 143,
                      "wickets": 3,
                      "overs": 17.4
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126713,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "7th Match",
                  "matchFormat": "T20",
                  "startDate": "1763021400000",
                  "endDate": "1763034000000",
                  "state": "Complete",
                  "status": "Hobart Hurricanes Women won by 6 wkts",
                  "team1": {
                    "teamId": 361,
                    "teamName": "Sydney Sixers Women",
                    "teamSName": "SYSW",
                    "imageId": 172407
                  },
                  "team2": {
                    "teamId": 357,
                    "teamName": "Hobart Hurricanes Women",
                    "teamSName": "HBHW",
                    "imageId": 172403
                  },
                  "venueInfo": {
                    "id": 301,
                    "ground": "North Sydney Oval",
                    "city": "Sydney",
                    "timezone": "+11:00",
                    "latitude": "-33.868820",
                    "longitude": "151.209296"
                  },
                  "currBatTeamId": 357,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HBHW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 152,
                      "wickets": 9,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 154,
                      "wickets": 4,
                      "overs": 16.5
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126702,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "6th Match",
                  "matchFormat": "T20",
                  "startDate": "1762935000000",
                  "endDate": "1762947600000",
                  "state": "Complete",
                  "status": "Perth Scorchers Women won by 23 runs",
                  "team1": {
                    "teamId": 360,
                    "teamName": "Perth Scorchers Women",
                    "teamSName": "PRSW",
                    "imageId": 172406
                  },
                  "team2": {
                    "teamId": 356,
                    "teamName": "Brisbane Heat Women",
                    "teamSName": "BRHW",
                    "imageId": 172402
                  },
                  "venueInfo": {
                    "id": 300,
                    "ground": "Allan Border Field",
                    "city": "Brisbane",
                    "timezone": "+10:00",
                    "latitude": "-27.435145",
                    "longitude": "153.046143"
                  },
                  "currBatTeamId": 360,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "PRSW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 172,
                      "wickets": 3,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 149,
                      "wickets": 10,
                      "overs": 19.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126686,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "4th Match",
                  "matchFormat": "T20",
                  "startDate": "1762747800000",
                  "endDate": "1762760400000",
                  "state": "Complete",
                  "status": "No result  -  due to rain",
                  "team1": {
                    "teamId": 359,
                    "teamName": "Melbourne Stars Women",
                    "teamSName": "MLSW",
                    "imageId": 172405
                  },
                  "team2": {
                    "teamId": 355,
                    "teamName": "Adelaide Strikers Women",
                    "teamSName": "ADSW",
                    "imageId": 172401
                  },
                  "venueInfo": {
                    "id": 122,
                    "ground": "Junction Oval",
                    "city": "Melbourne",
                    "timezone": "+11:00",
                    "latitude": "-37.856007",
                    "longitude": "144.980155"
                  },
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 184,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 32,
                      "wickets": 1,
                      "overs": 4.2
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126669,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "2nd Match",
                  "matchFormat": "T20",
                  "startDate": "1762668600000",
                  "endDate": "1762681200000",
                  "state": "Complete",
                  "status": "Hobart Hurricanes Women won by 6 wkts",
                  "team1": {
                    "teamId": 362,
                    "teamName": "Sydney Thunder Women",
                    "teamSName": "SYTW",
                    "imageId": 172408
                  },
                  "team2": {
                    "teamId": 357,
                    "teamName": "Hobart Hurricanes Women",
                    "teamSName": "HBHW",
                    "imageId": 172403
                  },
                  "venueInfo": {
                    "id": 300,
                    "ground": "Allan Border Field",
                    "city": "Brisbane",
                    "timezone": "+10:00",
                    "latitude": "-27.435145",
                    "longitude": "153.046143"
                  },
                  "currBatTeamId": 357,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "HBHW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 181,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 182,
                      "wickets": 4,
                      "overs": 19.3
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126680,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "3rd Match",
                  "matchFormat": "T20",
                  "startDate": "1762680600000",
                  "endDate": "1762693200000",
                  "state": "Complete",
                  "status": "Sydney Sixers Women won by 10 wkts",
                  "team1": {
                    "teamId": 360,
                    "teamName": "Perth Scorchers Women",
                    "teamSName": "PRSW",
                    "imageId": 172406
                  },
                  "team2": {
                    "teamId": 361,
                    "teamName": "Sydney Sixers Women",
                    "teamSName": "SYSW",
                    "imageId": 172407
                  },
                  "venueInfo": {
                    "id": 38,
                    "ground": "W.A.C.A. Ground",
                    "city": "Perth",
                    "timezone": "+08:00",
                    "latitude": "-31.959806",
                    "longitude": "115.879585"
                  },
                  "currBatTeamId": 361,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SYSW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 109,
                      "wickets": 10,
                      "overs": 19.3
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 112,
                      "overs": 12.5
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126691,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "5th Match",
                  "matchFormat": "T20",
                  "startDate": "1762834200000",
                  "endDate": "1762846800000",
                  "state": "Complete",
                  "status": "Melbourne Renegades Women won by 4 wkts",
                  "team1": {
                    "teamId": 362,
                    "teamName": "Sydney Thunder Women",
                    "teamSName": "SYTW",
                    "imageId": 172408
                  },
                  "team2": {
                    "teamId": 358,
                    "teamName": "Melbourne Renegades Women",
                    "teamSName": "MLRW",
                    "imageId": 172404
                  },
                  "venueInfo": {
                    "id": 122,
                    "ground": "Junction Oval",
                    "city": "Melbourne",
                    "timezone": "+11:00",
                    "latitude": "-37.856007",
                    "longitude": "144.980155"
                  },
                  "currBatTeamId": 358,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MLRW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 148,
                      "wickets": 7,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 151,
                      "wickets": 6,
                      "overs": 18.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 126658,
                  "seriesId": 10405,
                  "seriesName": "Womens Big Bash League 2025",
                  "matchDesc": "1st Match",
                  "matchFormat": "T20",
                  "startDate": "1762656000000",
                  "endDate": "1762668600000",
                  "state": "Complete",
                  "status": "Melbourne Renegades Women won by 7 wkts (2nd innings reduced to 8 overs due to rain, DLS target 66)",
                  "team1": {
                    "teamId": 356,
                    "teamName": "Brisbane Heat Women",
                    "teamSName": "BRHW",
                    "imageId": 172402
                  },
                  "team2": {
                    "teamId": 358,
                    "teamName": "Melbourne Renegades Women",
                    "teamSName": "MLRW",
                    "imageId": 172404
                  },
                  "venueInfo": {
                    "id": 300,
                    "ground": "Allan Border Field",
                    "city": "Brisbane",
                    "timezone": "+10:00",
                    "latitude": "-27.435145",
                    "longitude": "153.046143"
                  },
                  "currBatTeamId": 358,
                  "seriesStartDt": "1762646400000",
                  "seriesEndDt": "1765756800000",
                  "isTimeAnnounced": True,
                  "stateTitle": "MLRW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 133,
                      "wickets": 10,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 66,
                      "wickets": 3,
                      "overs": 7.3
                    }
                  }
                }
              }
            ]
          }
        },
        {
          "seriesAdWrapper": {
            "seriesId": 11099,
            "seriesName": "Womens T20I Quadrangular Series in Thailand 2025",
            "matches": [
              {
                "matchInfo": {
                  "matchId": 135906,
                  "seriesId": 11099,
                  "seriesName": "Womens T20I Quadrangular Series in Thailand 2025",
                  "matchDesc": "4th Match",
                  "matchFormat": "T20",
                  "startDate": "1763188200000",
                  "endDate": "1763200800000",
                  "state": "Complete",
                  "status": "Scotland Women won by 2 wkts",
                  "team1": {
                    "teamId": 382,
                    "teamName": "Thailand Women",
                    "teamSName": "THAIW",
                    "imageId": 172435
                  },
                  "team2": {
                    "teamId": 389,
                    "teamName": "Scotland Women",
                    "teamSName": "SCOW",
                    "imageId": 776283
                  },
                  "venueInfo": {
                    "id": 474,
                    "ground": "Terdthai Cricket Ground",
                    "city": "Bangkok",
                    "timezone": "+07:00",
                    "latitude": "13.756331",
                    "longitude": "100.501765"
                  },
                  "currBatTeamId": 389,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1763510400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SCOW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 136,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 137,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135895,
                  "seriesId": 11099,
                  "seriesName": "Womens T20I Quadrangular Series in Thailand 2025",
                  "matchDesc": "3rd Match",
                  "matchFormat": "T20",
                  "startDate": "1763172000000",
                  "endDate": "1763184600000",
                  "state": "Complete",
                  "status": "Papua New Guinea Women won by 6 wkts",
                  "team1": {
                    "teamId": 503,
                    "teamName": "Namibia Women",
                    "teamSName": "NAMW",
                    "imageId": 776329
                  },
                  "team2": {
                    "teamId": 390,
                    "teamName": "Papua New Guinea Women",
                    "teamSName": "PNGW",
                    "imageId": 776305
                  },
                  "venueInfo": {
                    "id": 474,
                    "ground": "Terdthai Cricket Ground",
                    "city": "Bangkok",
                    "timezone": "+07:00",
                    "latitude": "13.756331",
                    "longitude": "100.501765"
                  },
                  "currBatTeamId": 390,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1763510400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "Complete"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 74,
                      "wickets": 10,
                      "overs": 19.4
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 75,
                      "wickets": 4,
                      "overs": 19.1
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135873,
                  "seriesId": 11099,
                  "seriesName": "Womens T20I Quadrangular Series in Thailand 2025",
                  "matchDesc": "1st Match",
                  "matchFormat": "T20",
                  "startDate": "1763085600000",
                  "endDate": "1763098200000",
                  "state": "Complete",
                  "status": "Scotland Women won by 55 runs",
                  "team1": {
                    "teamId": 389,
                    "teamName": "Scotland Women",
                    "teamSName": "SCOW",
                    "imageId": 776283
                  },
                  "team2": {
                    "teamId": 390,
                    "teamName": "Papua New Guinea Women",
                    "teamSName": "PNGW",
                    "imageId": 776305
                  },
                  "venueInfo": {
                    "id": 474,
                    "ground": "Terdthai Cricket Ground",
                    "city": "Bangkok",
                    "timezone": "+07:00",
                    "latitude": "13.756331",
                    "longitude": "100.501765"
                  },
                  "currBatTeamId": 389,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1763510400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "SCOW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 146,
                      "wickets": 4,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 91,
                      "wickets": 8,
                      "overs": 19.6
                    }
                  }
                }
              },
              {
                "matchInfo": {
                  "matchId": 135884,
                  "seriesId": 11099,
                  "seriesName": "Womens T20I Quadrangular Series in Thailand 2025",
                  "matchDesc": "2nd Match",
                  "matchFormat": "T20",
                  "startDate": "1763101800000",
                  "endDate": "1763114400000",
                  "state": "Complete",
                  "status": "Thailand Women won by 39 runs",
                  "team1": {
                    "teamId": 382,
                    "teamName": "Thailand Women",
                    "teamSName": "THAIW",
                    "imageId": 172435
                  },
                  "team2": {
                    "teamId": 503,
                    "teamName": "Namibia Women",
                    "teamSName": "NAMW",
                    "imageId": 776329
                  },
                  "venueInfo": {
                    "id": 474,
                    "ground": "Terdthai Cricket Ground",
                    "city": "Bangkok",
                    "timezone": "+07:00",
                    "latitude": "13.756331",
                    "longitude": "100.501765"
                  },
                  "currBatTeamId": 382,
                  "seriesStartDt": "1763078400000",
                  "seriesEndDt": "1763510400000",
                  "isTimeAnnounced": True,
                  "stateTitle": "THAIW Won"
                },
                "matchScore": {
                  "team1Score": {
                    "inngs1": {
                      "inningsId": 1,
                      "runs": 124,
                      "wickets": 5,
                      "overs": 19.6
                    }
                  },
                  "team2Score": {
                    "inngs1": {
                      "inningsId": 2,
                      "runs": 85,
                      "wickets": 10,
                      "overs": 18.3
                    }
                  }
                }
              }
            ]
          }
        }
      ]
    }
  ],
  "filters": {
    "matchType": [
      "International",
      "League",
      "Domestic",
      "Women"
    ]
  },
  "appIndex": {
    "seoTitle": "Live Cricket Score - Scorecard and Match Results",
    "webURL": "www.cricbuzz.com/live-cricket-scores/"
  },
  "responseLastUpdated": "1763202476"
}

    typeMatches = data.get('typeMatches', [])
    stop = False
  
    for typeMatch in typeMatches:
       # print(typeMatch)
       
        series_matches = typeMatch.get('seriesMatches', [])
        for series in series_matches:
            
           # print(series)
            series_data = series.get('seriesAdWrapper', {})
            series_id   = series_data.get('seriesId')
            series_name = series_data.get('seriesName')
            matches     = series_data.get('matches', [])
            no_of_matches = len(matches)

            for match in matches:
              #print(match)
                match_info      = match.get('matchInfo', {})
                match_id        = match_info.get('matchId', '')
                match_desc      = match_info.get('matchDesc', '')
                match_format    = match_info.get('matchFormat', '')
                start_date      = match_info.get('startDate', '')
                
                team1           = match_info.get('team1', {})
                team1_name      = team1.get('teamName')
                
                team2           = match_info.get('team2', {})
                team2_name      = team2.get('teamName', '')
                
                state           = match_info.get('state', '')
                
                venue_info      = match_info.get('venueInfo', {})
                venue           = venue_info.get('ground', '')
                city            = venue_info.get('city', '')
                status          = match_info.get('status', '')

                match_parameters = (
                    match_id, match_desc, team1_name, team2_name,
                    venue, datetime.fromtimestamp(float(start_date) / 1000.0),state
                )

                print("inserting mathces record.....")
                insert_query = """
                    INSERT INTO matches
                    (match_id, match_description, team_1_name, team_2_name, venue_name, match_date, match_state)
                    VALUES (%s, %s, %s, %s, %s, %s, %s) ON CONFLICT DO NOTHING;
                """
                print("inserting mathces record.....",match_parameters)
                execute(query=insert_query, params=match_parameters)
                print("Successfully inserted....")
                # -----------------------------------------------
                # EXTRACT matchheaders (flatten dict)
                # -----------------------------------------------
                
                url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{match_id}/leanback"

                headers = {
                  "x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
                  "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
                }

                response = requests.get(url, headers=headers)
                
                data = response.json()
                headers_df = pd.json_normalize(data["matchheaders"], sep="__")
                headers_df = headers_df[['winningteamid','tossresults__tosswinnerid','tossresults__tosswinnername','tossresults__decision','status']]
                headers_df["victory_type"] = headers_df["status"].apply(lambda x: "runs" if "runs" in x.lower() else "wickets" )
                headers_df["victory_margin"] = headers_df["status"].str.extract(r'(\d+)').astype(int)
                headers_df = headers_df[['winningteamid','tossresults__tosswinnerid','tossresults__tosswinnername','tossresults__decision','victory_type','victory_margin']]
              #  print(headers_df.head())
                create_mc_heaers_query =   """ CREATE TABLE  if not exists match_headers  (
                    match_id BIGINT,
                    winning_team_id BIGINT,
                    toss_winner_id BIGINT,
                    toss_winner_name VARCHAR(200),
                    toss_decision VARCHAR(20),
                    victory_type VARCHAR(20),
                    victory_margin int
                );"""

                #execute(query=create_mc_heaers_query)
                # Extract first row
                row = headers_df.iloc[0]
                print(row)
                match_header_insert_query = """
                INSERT INTO match_headers (
                    match_id,
                    winning_team_id,
                    toss_winner_id,
                    toss_winner_name,
                    toss_decision,
                    victory_type,
                    victory_margin
                )
                VALUES (%s, %s, %s, %s, %s,%s,%s) ON CONFLICT DO NOTHING;
                """

                mhparams = (
                    int(match_id),
                    int(row["winningteamid"]),
                    int(row["tossresults__tosswinnerid"]),
                    row["tossresults__tosswinnername"],
                    row["tossresults__decision"],
                    row["victory_type"],
                    int(row["victory_margin"])
                )

                execute(query=match_header_insert_query, params=mhparams)

                inningsscores = data.get("miniscore", {}).get("inningsscores", {})
                innings_list = inningsscores.get("inningsscore", [])

                flat_innings = []

                for entry in innings_list:
                    row = {}
                    for key, value in entry.items():

                        if isinstance(value, (str, int, float, bool)):
                            row[key] = value

                        elif isinstance(value, dict):
                            for nk, nv in value.items():
                                row[f"{key}_{nk}"] = nv
                        elif isinstance(value, list):
                            row[key] = str(value)
                    flat_innings.append(row)
                innings_score_df = pd.DataFrame(flat_innings)

                # Add matchId column
                innings_score_df['matchId'] = match_id

                innings_score_df = innings_score_df[['inningsid', 'batteamid', 'runs', 'wickets', 'overs', 'matchId']]
                innings_score_create_query = """CREATE TABLE if not exists innings_score (
                id SERIAL PRIMARY KEY,
                inningsid int,
                batteamid int,
                runs int,
                wickets int,
                overs DECIMAL(5,2),
                match_id int
                )"""
                
                
                #execute(query=innings_score_create_query)
                # -----------------------------------------------
                # INSERT INTO innings_score TABLE
                # -----------------------------------------------
                insert_innings_query = """
                    INSERT INTO innings_score
                    (inningsid, batteamid, runs, wickets, overs, match_id)
                    VALUES (%s, %s, %s, %s, %s, %s) ON CONFLICT DO NOTHING;

                """
                print("entering the df iterrows....")
                print(innings_score_df)
                for _, row in innings_score_df.iterrows():
                    print("-----",row)
                    inn_params = (int(row["inningsid"]),
                                   int(row["batteamid"]),
                                   int(row["runs"]),
                                   int(row["wickets"]),
                                   float(row["overs"]),
                                   int(row["matchId"])
                                  )
                    execute(query=insert_innings_query, params=inn_params)
except Exception as e:
    print("Error Occurred:", e)
# Out:
# inserting mathces record.....
# inserting mathces record..... (122610, '3rd T20I', 'New Zealand', 'West Indies', 'Saxton Oval', datetime.datetime(2025, 11, 9, 5, 45), 'Complete')
# Successfully inserted....
# winningteamid                           13
# tossresults__tosswinnerid               13
# tossresults__tosswinnername    New Zealand
# tossresults__decision              Batting
# victory_type                          runs
# victory_margin                           9
# Name: 0, dtype: object
# entering the df iterrows....
#    inningsid  batteamid  runs  wickets  overs  matchId
# 0          2         10   168       10   19.5   122610
# 1          1         13   177        9   19.6   122610
# ----- inningsid         2.0
# batteamid        10.0
# runs            168.0
# wickets          10.0
# overs            19.5
# matchId      122610.0
# Name: 0, dtype: float64
# ----- inningsid         1.0
# batteamid        13.0
# runs            177.0
# wickets           9.0
# ...

# %%
inserting mathces record.....
inserting mathces record..... (122610, '3rd T20I', 'New Zealand', 'West Indies', 'Saxton Oval', datetime.datetime(2025, 11, 9, 5, 45), 'Complete')
Successfully inserted....
winningteamid                           13
tossresults__tosswinnerid               13
tossresults__tosswinnername    New Zealand
tossresults__decision              Batting
victory_type                          runs
victory_margin                           9
Name: 0, dtype: object
entering the df iterrows....
   inningsid  batteamid  runs  wickets  overs  matchId
0          2         10   168       10   19.5   122610
1          1         13   177        9   19.6   122610
----- inningsid         2.0
batteamid        10.0
runs            168.0
wickets          10.0
overs            19.5
matchId      122610.0
Name: 0, dtype: float64
----- inningsid         1.0
batteamid        13.0
runs            177.0
wickets           9.0
overs            19.6
matchId      122610.0
Name: 1, dtype: float64
inserting mathces record.....
inserting mathces record..... (122616, '4th T20I', 'West Indies', 'New Zealand', 'Saxton Oval', datetime.datetime(2025, 11, 10, 5, 45), 'Complete')
Successfully inserted....
Error Occurred: cannot convert float NaN to integer

# %%
import psycopg2
import pandas as pd
def create_connection():
    try:
        conn = psycopg2.connect(
            host="localhost",        
            port="5432",             
            database="cricbuzz",  
            user="postgres",       
            password="postgres" 
        )
        return conn
    except Exception as e:
        return None

def execute(query, params=None):
        try:
            conn = create_connection()
            with conn.cursor() as cur:
                cur.execute(query, params or ())
                conn.commit()
                return True
        except Exception as e:
            print(f"Error executing query: {e}")
            return False
        finally:
            if conn:
                conn.close()
def fetch_records(query):
    try:
        conn = create_connection()
        cursor = conn.cursor()
        cursor.execute(query)
        rows = cursor.fetchall()
        columns = [desc[0] for desc in cursor.description]
        return pd.DataFrame(rows, columns=columns)
    except Exception as e:
        st.error(f"Error fetching records: {e}")
        return pd.DataFrame()
    finally:
        conn.close()

# %%
df = fetch_records("SELECT max(player_id)+1 as new_player_id from players")
value = int(df['new_player_id'][0])
int(value)
# Out:
# 24730

# %%
import requests         
headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists most_runs_stats (player_id int,player_name varchar,format varchar,matches smallint,innings smallint,runs int,average numeric)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"mostRuns","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        matches = values[2]
        innings = values[3]
        runs = values[4]
        average = values[5]
        parameter = (id,name,format,matches,innings,runs,average)
        insert_query = "insert into most_runs_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests         
headers = {
	"x-rapidapi-key": "2ff514151fmsh912ff982e96dabbp19c56cjsnea7d12a552fa",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists most_runs_stats (player_id int,player_name varchar,format varchar,matches smallint,innings smallint,runs int,average numeric)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"mostRuns","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        matches = values[2]
        innings = values[3]
        runs = values[4]
        average = values[5]
        parameter = (id,name,format,matches,innings,runs,average)
        insert_query = "insert into most_runs_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests   
def extract_int(val):
    if isinstance(val, str):
        digits = re.sub(r'[^\d]', '', val)
        return int(digits) if digits else None
    return val

headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists venue_info (ground varchar,city char(100),country char(100),capacity varchar,time_zone char(75),ends varchar,home_team varchar(255))"
execute(query=create_query)
#print("table created succesfully")
list_of_venues = [371,372,418,19,18,66,1843,290,152,228,335,380,154,506,512,40,34,123,83,35]
for i in list_of_venues:
    try:
        
        print("inside the try block")
        url = f"https://cricbuzz-cricket.p.rapidapi.com/venues/v1/{i}"
        response = requests.get(url, headers=headers, params=None)
        data = response.json()
        print(data)
        ground  = data.get('ground','')
        city    = data.get('city','')
        country = data.get('country','')
        capacity = extract_int(data.get('capacity',''))
        time_zone = data.get('timezone','')
        ends    = data.get('ends','')
        home_team = data.get('homeTeam','')
        parameter = (ground,city,country,capacity,time_zone,ends,home_team)
        insert_query = "insert into venue_info values(%s,%s,%s,%s,%s,%s,%s)"
        retrned = execute(query=insert_query,params=parameter)
        print("values inserted succesfully",retrned)
    except requests.exceptions.RequestException as e:
        print("Error Occured",e)

# %%
[3858, 4168, 4100, 4149, 3806, 3641, 4086, 3697, 4156, 3722, 4041, 3636, 4046, 3646, 4091, 4051, 4107, 4079, 2913, 3961]

# %%
import requests         
headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}    
create_query = "create table if not exists highest_score_stats (player_id int,batter_name varchar,format varchar,highest_score smallint,balls varchar,strike_rate varchar,opponent varchar)"
execute(query=create_query)
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/stats/v1/topstats/0"

    querystring = {"statsType":"highestScore","matchType":"3"}

    response = requests.get(url, headers=headers, params=querystring)
    data = response.json()
    for record_values in  data.get('values',{}):
        values = record_values.get('values')
        id = values[0]
        name = values[1]
        format = "T20"
        highest_score = values[2]
        balls = values[3]
        strike_rate = values[4]
        opponent = values[5]
        parameter = (id,name,format,highest_score,balls,strike_rate,opponent)
        insert_query = "insert into highest_score_stats values(%s,%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=parameter)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
# Out:
# 6297
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/6297
# [87493, 70326, 70333, 70340, 70347, 70354, 70361, 70368, 70375]

# %%
import requests
headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}
try:
    url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/10/players"

    response = requests.get(url, headers=headers, params=None)
    response_india_players = response.json()
    player_role = ""
    for player in response_india_players.get('player',{}):
        player_name = ""
        player_id   = ""
        batting_style = ""
        bowling_style = ""
        if(len(player.keys()) <= 2):
            player_role = player.get('name','')
            continue
        if(len(player.keys()) > 2):
            player_id = player.get('id',)
            player_name = player.get('name','')
            batting_style = player.get('battingStyle','')
            bowling_style = player.get('bowlingStyle','')
            team     = "West Indies"
        player_info   = (player_id,player_name,player_role,batting_style,bowling_style,team)
        insert_query = "insert into players (player_id,player_name,playing_role,batting_style,bowling_style,team) values (%s,%s,%s,%s,%s,%s)"
        execute(query=insert_query,params=player_info)
except requests.exceptions.RequestException as e:
    print("Error Occured",e)

# %%
import requests

#url = "https://cricbuzz-cricket.p.rapidapi.com/teams/v1/international"

headers = {
	"x-rapidapi-key": "c87e41eb49mshc9870ce8e2dab58p1f6680jsn03975c23a5f3",
	"x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
}

#response = requests.get(url, headers=headers)

#print(response.json())
team_data = { "list": [ { "teamName": "Test Teams" }, { "teamId": 2, "teamName": "India", "teamSName": "IND", "imageId": 776162, "countryName": "India" }, { "teamId": 96, "teamName": "Afghanistan", "teamSName": "AFG", "imageId": 776177 }, { "teamId": 27, "teamName": "Ireland", "teamSName": "IRE", "imageId": 776285 }, { "teamId": 3, "teamName": "Pakistan", "teamSName": "PAK", "imageId": 776308, "countryName": "Pakistan" }, { "teamId": 4, "teamName": "Australia", "teamSName": "AUS", "imageId": 776202, "countryName": "Australia" }, { "teamId": 5, "teamName": "Sri Lanka", "teamSName": "SL", "imageId": 776254, "countryName": "Sri Lanka" }, { "teamId": 6, "teamName": "Bangladesh", "teamSName": "BAN", "imageId": 776210 }, { "teamId": 9, "teamName": "England", "teamSName": "ENG", "imageId": 776237 }, { "teamId": 10, "teamName": "West Indies", "teamSName": "WI", "imageId": 776191 }, { "teamId": 11, "teamName": "South Africa", "teamSName": "RSA", "imageId": 776287 }, { "teamId": 12, "teamName": "Zimbabwe", "teamSName": "ZIM", "imageId": 776198, "countryName": "Zimbabwe" }, { "teamId": 13, "teamName": "New Zealand", "teamSName": "NZ", "imageId": 776333 }, { "teamName": "Associate Teams" }, { "teamId": 71, "teamName": "Malaysia", "teamSName": "MLY", "imageId": 776319 }, { "teamId": 72, "teamName": "Nepal", "teamSName": "NEP", "imageId": 776331 }, { "teamId": 77, "teamName": "Germany", "teamSName": "GER", "imageId": 776260 }, { "teamId": 161, "teamName": "Namibia", "teamSName": "NAM", "imageId": 776326 }, { "teamId": 185, "teamName": "Denmark", "teamSName": "DEN", "imageId": 776232 }, { "teamId": 190, "teamName": "Singapore", "teamSName": "SIN", "imageId": 776275 }, { "teamId": 287, "teamName": "Papua New Guinea", "teamSName": "PNG", "imageId": 776304 }, { "teamId": 298, "teamName": "Kuwait", "teamSName": "KUW", "imageId": 776312 }, { "teamId": 300, "teamName": "Vanuatu", "teamSName": "VAN", "imageId": 776229 }, { "teamId": 303, "teamName": "Jersey", "teamSName": "JER", "imageId": 776300 }, { "teamId": 304, "teamName": "Oman", "teamSName": "OMAN", "imageId": 776328 }, { "teamId": 343, "teamName": "Fiji", "teamSName": "FIJI", "imageId": 776251 }, { "teamId": 527, "teamName": "Italy", "teamSName": "ITA", "imageId": 776295 }, { "teamId": 529, "teamName": "Botswana", "teamSName": "BW", "imageId": 776225 }, { "teamId": 541, "teamName": "Belgium", "teamSName": "BEL", "imageId": 776219 }, { "teamId": 44, "teamName": "Uganda", "teamSName": "UGA", "imageId": 776233 }, { "teamId": 26, "teamName": "Canada", "teamSName": "CAN", "imageId": 776227 }, { "teamId": 7, "teamName": "United Arab Emirates", "teamSName": "UAE", "imageId": 776242 }, { "teamId": 8, "teamName": "Hong Kong", "teamSName": "HK", "imageId": 776271 }, { "teamId": 14, "teamName": "Kenya", "teamSName": "KEN", "imageId": 776303 }, { "teamId": 15, "teamName": "United States of America", "teamSName": "USA", "imageId": 776186, "countryName": "United States of America" }, { "teamId": 23, "teamName": "Scotland", "teamSName": "SCO", "imageId": 776280 }, { "teamId": 24, "teamName": "Netherlands", "teamSName": "NED", "imageId": 776335 }, { "teamId": 25, "teamName": "Bermuda", "teamSName": "BER", "imageId": 776221 }, { "teamId": 675, "teamName": "Iran", "teamSName": "IRN", "imageId": 776282 } ], "appIndex": { "seoTitle": "Live cricket scores, schedule, news, archive, series | Cricbuzz.com", "webURL": "www.cricbuzz.com/cricket-team/" } } 

try:
        create_team_table_query = "Create Table if not exists team(team_id int primary key,team_name varchar(255),team_s_name char(5),country varchar(255));"
        execute(query=create_team_table_query)
        for team in team_data.get('list',[]):
              if len(team) > 1:
                    team_id = team.get('teamId',0)
                    team_name = team.get('teamName','')
                    team_s_name = team.get('teamSName','')
                    country_name = team.get('countryName',team_name)

                    team_param = (team_id,team_name,team_s_name,country_name)
                    team_insert_query = "insert into team (team_id,team_name,team_s_name,country) values (%s,%s,%s,%s)"
                    execute(query=team_insert_query,params=team_param)
except Exception as e:
    print("Error Occured",e)

# %%
from datetime import datetime
schedule_data = {
  "matchScheduleMap": [
    {
      "scheduleAdWrapper": {
        "date": "TUE, SEP 10 2024",
        "matchScheduleList": [
          {
            "seriesName": "Afghanistan v New Zealand in India, 2024",
            "matchInfo": [
              {
                "matchId": 103285,
                "seriesId": 8625,
                "matchDesc": "Only Test, Day 2",
                "matchFormat": "TEST",
                "startDate": "1725942600000",
                "endDate": "1726271999000",
                "team1": {
                  "teamId": 96,
                  "teamName": "Afghanistan",
                  "teamSName": "AFG",
                  "isFullMember": True,
                  "imageId": 776177
                },
                "team2": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "venueInfo": {
                  "ground": "Greater Noida Sports Complex Ground",
                  "city": "Greater Noida",
                  "country": "India",
                  "timezone": "+05:30"
                }
              }
            ],
            "seriesId": 8625,
            "seriesHomeCountry": 1,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1725926400000"
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_1",
        "layout": "native_large",
        "position": 1
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "WED, SEP 11 2024",
        "matchScheduleList": [
          {
            "seriesName": "Afghanistan v New Zealand in India, 2024",
            "matchInfo": [
              {
                "matchId": 103285,
                "seriesId": 8625,
                "matchDesc": "Only Test, Day 3",
                "matchFormat": "TEST",
                "startDate": "1726029000000",
                "endDate": "1726271999000",
                "team1": {
                  "teamId": 96,
                  "teamName": "Afghanistan",
                  "teamSName": "AFG",
                  "isFullMember": True,
                  "imageId": 776177
                },
                "team2": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "venueInfo": {
                  "ground": "Greater Noida Sports Complex Ground",
                  "city": "Greater Noida",
                  "country": "India",
                  "timezone": "+05:30"
                }
              }
            ],
            "seriesId": 8625,
            "seriesHomeCountry": 1,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1726012800000"
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "THU, SEP 12 2024",
        "matchScheduleList": [
          {
            "seriesName": "Afghanistan v New Zealand in India, 2024",
            "matchInfo": [
              {
                "matchId": 103285,
                "seriesId": 8625,
                "matchDesc": "Only Test, Day 4",
                "matchFormat": "TEST",
                "startDate": "1726115400000",
                "endDate": "1726271999000",
                "team1": {
                  "teamId": 96,
                  "teamName": "Afghanistan",
                  "teamSName": "AFG",
                  "isFullMember": True,
                  "imageId": 776177
                },
                "team2": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "venueInfo": {
                  "ground": "Greater Noida Sports Complex Ground",
                  "city": "Greater Noida",
                  "country": "India",
                  "timezone": "+05:30"
                }
              }
            ],
            "seriesId": 8625,
            "seriesHomeCountry": 1,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1726099200000"
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "FRI, SEP 13 2024",
        "matchScheduleList": [
          {
            "seriesName": "Afghanistan v New Zealand in India, 2024",
            "matchInfo": [
              {
                "matchId": 103285,
                "seriesId": 8625,
                "matchDesc": "Only Test, Day 5",
                "matchFormat": "TEST",
                "startDate": "1726201800000",
                "endDate": "1726271999000",
                "team1": {
                  "teamId": 96,
                  "teamName": "Afghanistan",
                  "teamSName": "AFG",
                  "isFullMember": True,
                  "imageId": 776177
                },
                "team2": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "venueInfo": {
                  "ground": "Greater Noida Sports Complex Ground",
                  "city": "Greater Noida",
                  "country": "India",
                  "timezone": "+05:30"
                }
              }
            ],
            "seriesId": 8625,
            "seriesHomeCountry": 1,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1726185600000"
      }
    },
    {
      "adDetail": {
        "name": "native_news_index_random_2",
        "layout": "native_large",
        "position": 4
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "MON, NOV 10 2025",
        "matchScheduleList": [
          {
            "seriesName": "West Indies tour of New Zealand, 2025",
            "matchInfo": [
              {
                "matchId": 122616,
                "seriesId": 10223,
                "matchDesc": "4th T20I",
                "matchFormat": "T20",
                "startDate": "1762733700000",
                "endDate": "1762819199000",
                "team1": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "team2": {
                  "teamId": 10,
                  "teamName": "West Indies",
                  "teamSName": "WI",
                  "isFullMember": True,
                  "imageId": 776191
                },
                "venueInfo": {
                  "ground": "Saxton Oval",
                  "city": "Nelson",
                  "country": "New Zealand",
                  "timezone": "+13:00"
                }
              }
            ],
            "seriesId": 10223,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1762732800000"
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "TUE, NOV 11 2025",
        "matchScheduleList": [
          {
            "seriesName": "Indonesia Tri-Series 2025",
            "matchInfo": [
              {
                "matchId": 135985,
                "seriesId": 11108,
                "matchDesc": "7th Match",
                "matchFormat": "T20",
                "startDate": "1762822800000",
                "endDate": "1762905599000",
                "team1": {
                  "teamId": 566,
                  "teamName": "Indonesia",
                  "teamSName": "IDN",
                  "imageId": 172618
                },
                "team2": {
                  "teamId": 565,
                  "teamName": "Myanmar",
                  "teamSName": "MMR",
                  "imageId": 172617
                },
                "venueInfo": {
                  "ground": "Udayana Cricket Ground",
                  "city": "Bali",
                  "country": "Indonesia",
                  "timezone": "+07:00"
                }
              },
              {
                "matchId": 135996,
                "seriesId": 11108,
                "matchDesc": "8th Match",
                "matchFormat": "T20",
                "startDate": "1762840800000",
                "endDate": "1762905599000",
                "team1": {
                  "teamId": 566,
                  "teamName": "Indonesia",
                  "teamSName": "IDN",
                  "imageId": 172618
                },
                "team2": {
                  "teamId": 2850,
                  "teamName": "Timor Leste",
                  "teamSName": "TLS",
                  "imageId": 779912
                },
                "venueInfo": {
                  "ground": "Udayana Cricket Ground",
                  "city": "Bali",
                  "country": "Indonesia",
                  "timezone": "+07:00"
                }
              }
            ],
            "seriesId": 11108,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Ireland tour of Bangladesh, 2025",
            "matchInfo": [
              {
                "matchId": 135041,
                "seriesId": 10972,
                "matchDesc": "1st Test, Day 1",
                "matchFormat": "TEST",
                "startDate": "1762833600000",
                "endDate": "1763251199000",
                "team1": {
                  "teamId": 6,
                  "teamName": "Bangladesh",
                  "teamSName": "BAN",
                  "isFullMember": True,
                  "imageId": 776210
                },
                "team2": {
                  "teamId": 27,
                  "teamName": "Ireland",
                  "teamSName": "IRE",
                  "isFullMember": True,
                  "imageId": 776285
                },
                "venueInfo": {
                  "ground": "Sylhet International Cricket Stadium",
                  "city": "Sylhet",
                  "country": "Bangladesh",
                  "timezone": "+06:00"
                }
              }
            ],
            "seriesId": 10972,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Sri Lanka tour of Pakistan 2025",
            "matchInfo": [
              {
                "matchId": 134744,
                "seriesId": 10933,
                "matchDesc": "1st ODI",
                "matchFormat": "ODI",
                "startDate": "1762851600000",
                "endDate": "1762905599000",
                "team1": {
                  "teamId": 3,
                  "teamName": "Pakistan",
                  "teamSName": "PAK",
                  "isFullMember": True,
                  "imageId": 776308
                },
                "team2": {
                  "teamId": 5,
                  "teamName": "Sri Lanka",
                  "teamSName": "SL",
                  "isFullMember": True,
                  "imageId": 776254
                },
                "venueInfo": {
                  "ground": "Rawalpindi Cricket Stadium",
                  "city": "Rawalpindi",
                  "country": "Pakistan",
                  "timezone": "+05:00"
                }
              }
            ],
            "seriesId": 10933,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1762819200000"
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "WED, NOV 12 2025",
        "matchScheduleList": [
          {
            "seriesName": "Indonesia Tri-Series 2025",
            "matchInfo": [
              {
                "matchId": 136007,
                "seriesId": 11108,
                "matchDesc": "9th Match",
                "matchFormat": "T20",
                "startDate": "1762911000000",
                "endDate": "1762991999000",
                "team1": {
                  "teamId": 565,
                  "teamName": "Myanmar",
                  "teamSName": "MMR",
                  "imageId": 172617
                },
                "team2": {
                  "teamId": 2850,
                  "teamName": "Timor Leste",
                  "teamSName": "TLS",
                  "imageId": 779912
                },
                "venueInfo": {
                  "ground": "Udayana Cricket Ground",
                  "city": "Bali",
                  "country": "Indonesia",
                  "timezone": "+07:00"
                }
              }
            ],
            "seriesId": 11108,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Ireland tour of Bangladesh, 2025",
            "matchInfo": [
              {
                "matchId": 135041,
                "seriesId": 10972,
                "matchDesc": "1st Test, Day 2",
                "matchFormat": "TEST",
                "startDate": "1762920000000",
                "endDate": "1763251199000",
                "team1": {
                  "teamId": 6,
                  "teamName": "Bangladesh",
                  "teamSName": "BAN",
                  "isFullMember": True,
                  "imageId": 776210
                },
                "team2": {
                  "teamId": 27,
                  "teamName": "Ireland",
                  "teamSName": "IRE",
                  "isFullMember": True,
                  "imageId": 776285
                },
                "venueInfo": {
                  "ground": "Sylhet International Cricket Stadium",
                  "city": "Sylhet",
                  "country": "Bangladesh",
                  "timezone": "+06:00"
                }
              }
            ],
            "seriesId": 10972,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1762905600000"
      }
    },
    {
      "scheduleAdWrapper": {
        "date": "THU, NOV 13 2025",
        "matchScheduleList": [
          {
            "seriesName": "West Indies tour of New Zealand, 2025",
            "matchInfo": [
              {
                "matchId": 122627,
                "seriesId": 10223,
                "matchDesc": "5th T20I",
                "matchFormat": "T20",
                "startDate": "1762992900000",
                "endDate": "1763078399000",
                "team1": {
                  "teamId": 13,
                  "teamName": "New Zealand",
                  "teamSName": "NZ",
                  "isFullMember": True,
                  "imageId": 776333
                },
                "team2": {
                  "teamId": 10,
                  "teamName": "West Indies",
                  "teamSName": "WI",
                  "isFullMember": True,
                  "imageId": 776191
                },
                "venueInfo": {
                  "ground": "University Oval",
                  "city": "Dunedin",
                  "country": "New Zealand",
                  "timezone": "+13:00"
                }
              }
            ],
            "seriesId": 10223,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Indonesia Tri-Series 2025",
            "matchInfo": [
              {
                "matchId": 136018,
                "seriesId": 11108,
                "matchDesc": "10th Match",
                "matchFormat": "T20",
                "startDate": "1762997400000",
                "endDate": "1763078399000",
                "team1": {
                  "teamId": 2850,
                  "teamName": "Timor Leste",
                  "teamSName": "TLS",
                  "imageId": 779912
                },
                "team2": {
                  "teamId": 566,
                  "teamName": "Indonesia",
                  "teamSName": "IDN",
                  "imageId": 172618
                },
                "venueInfo": {
                  "ground": "Udayana Cricket Ground",
                  "city": "Bali",
                  "country": "Indonesia",
                  "timezone": "+07:00"
                }
              },
              {
                "matchId": 136029,
                "seriesId": 11108,
                "matchDesc": "11th Match",
                "matchFormat": "T20",
                "startDate": "1763013600000",
                "endDate": "1763078399000",
                "team1": {
                  "teamId": 565,
                  "teamName": "Myanmar",
                  "teamSName": "MMR",
                  "imageId": 172617
                },
                "team2": {
                  "teamId": 566,
                  "teamName": "Indonesia",
                  "teamSName": "IDN",
                  "imageId": 172618
                },
                "venueInfo": {
                  "ground": "Udayana Cricket Ground",
                  "city": "Bali",
                  "country": "Indonesia",
                  "timezone": "+07:00"
                }
              }
            ],
            "seriesId": 11108,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Ireland tour of Bangladesh, 2025",
            "matchInfo": [
              {
                "matchId": 135041,
                "seriesId": 10972,
                "matchDesc": "1st Test, Day 3",
                "matchFormat": "TEST",
                "startDate": "1763006400000",
                "endDate": "1763251199000",
                "team1": {
                  "teamId": 6,
                  "teamName": "Bangladesh",
                  "teamSName": "BAN",
                  "isFullMember": True,
                  "imageId": 776210
                },
                "team2": {
                  "teamId": 27,
                  "teamName": "Ireland",
                  "teamSName": "IRE",
                  "isFullMember": True,
                  "imageId": 776285
                },
                "venueInfo": {
                  "ground": "Sylhet International Cricket Stadium",
                  "city": "Sylhet",
                  "country": "Bangladesh",
                  "timezone": "+06:00"
                }
              }
            ],
            "seriesId": 10972,
            "seriesCategory": "International"
          },
          {
            "seriesName": "Sri Lanka tour of Pakistan 2025",
            "matchInfo": [
              {
                "matchId": 134749,
                "seriesId": 10933,
                "matchDesc": "2nd ODI",
                "matchFormat": "ODI",
                "startDate": "1763024400000",
                "endDate": "1763078399000",
                "team1": {
                  "teamId": 3,
                  "teamName": "Pakistan",
                  "teamSName": "PAK",
                  "isFullMember": True,
                  "imageId": 776308
                },
                "team2": {
                  "teamId": 5,
                  "teamName": "Sri Lanka",
                  "teamSName": "SL",
                  "isFullMember": True,
                  "imageId": 776254
                },
                "venueInfo": {
                  "ground": "Rawalpindi Cricket Stadium",
                  "city": "Rawalpindi",
                  "country": "Pakistan",
                  "timezone": "+05:00"
                }
              }
            ],
            "seriesId": 10933,
            "seriesCategory": "International"
          }
        ],
        "longDate": "1762992000000"
      }
    }
  ],
  "appIndex": {
    "seoTitle": "Cricket Schedule - International, domestic and T20 matches - Cricbuzz",
    "webURL": "www.cricbuzz.com/cricket-schedule/series"
  }
}


series_dict = {}

for entry in schedule_data["matchScheduleMap"]:
    schedule = entry.get("scheduleAdWrapper")
    if not schedule:
        continue
    for series in schedule["matchScheduleList"]:
        series_name = series.get("seriesName")
        series_id = series.get("seriesId")

        # Skip if already processed
        if series_id in series_dict:
            series_dict[series_id]["total_no_matches_planned"] += len(series["matchInfo"])
            continue

        # Get match info
        first_match = series["matchInfo"][0]
        start_timestamp = int(first_match["startDate"]) / 1000
        start_date = datetime.fromtimestamp(start_timestamp)
        start_year = start_date.year

        # Filter for 2024 series
        series_dict[series_id] = {
            "series_id"  : series_id,
            "series_name": series_name,
            "host_country": first_match["venueInfo"]["country"],
            "match_type": first_match["matchFormat"],
            "start_date": start_date.strftime("%Y-%m-%d"),
            "total_no_matches_planned": len(series["matchInfo"])
        }
        

# Convert to list for display
unique_series_2024 = list(series_dict.values())

create_series_table_query = """CREATE TABLE if not exists series (
                            series_id SERIAL PRIMARY KEY,
                            series_name VARCHAR(300) NOT NULL,
                            host_country VARCHAR(100),
                            match_type VARCHAR(50),
                            start_date DATE,
                            total_no_matches_planned INT
                            );"""


execute(query=create_series_table_query)
series_insert_query = """
INSERT INTO series (series_id,series_name, host_country, match_type, start_date, total_no_matches_planned)
VALUES (%s, %s, %s, %s, %s, %s)
ON CONFLICT DO NOTHING;
"""

for s in unique_series_2024:
    sparams = (
        s["series_id"],
        s["series_name"],
        s["host_country"],
        s["match_type"],
        s["start_date"],
        s["total_no_matches_planned"],
    )
    execute(query=series_insert_query, params=sparams)
    print("inserted")

# %%
import requests
def insert_scorecard(match_id):
    
    url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{match_id}/scard"

    headers = {
        "x-rapidapi-key": "096090eac4mshd73dfcde8a35834p1911efjsn4dcdb491bdcc",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
    }

    scorecard_response = requests.get(url, headers=headers)
    scorecard_res_json = scorecard_response.json()
    scorecard_json = scorecard_res_json.get('scorecard',[])
    print(scorecard_json)
    for innings in scorecard_json:
        innings_id = innings.get("inningsid")
        print("# ----- Insert Innings -----")
        innings_query = """
            INSERT INTO match_innings 
            (match_id, innings_no, bat_team, score, wickets, overs, run_rate)
            VALUES (%s,%s,%s,%s,%s,%s,%s);
        """
        execute(
           query=innings_query,
           params= (
                match_id,
                innings.get("inningsid"),
                innings.get("batteamname"),
                innings.get("score"),
                innings.get("wickets"),
                innings.get("overs"),
                innings.get("runrate")
            )
        )
        print("# ----- Insert Batsmen -----")
        for b in innings.get("batsman", []):
            execute(query="""
                INSERT INTO batsmen
                (match_id,innings_id, name, out_desc, runs, balls, fours, sixes, strike_rate, is_captain, is_keeper,batsman_id)
                VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
            """, params=(
                match_id,
                innings_id,
                b.get("name"),
                b.get("outdec"),
                b.get("runs"),
                b.get("balls"),
                b.get("fours"),
                b.get("sixes"),
                b.get("strkrate"),
                b.get("iscaptain", False),
                b.get("iskeeper", False),
                b.get("id",0)
            ))

        #print("# ----- Insert Bowlers -----")
        for bw in innings.get("bowler", []):
            #print("bowling data ",bw)
            execute(query="""
                INSERT INTO bowlers
                (match_id,innings_id, name, overs, maidens, runs, wickets, economy,bowler_id)
                VALUES (%s, %s,%s,%s,%s,%s,%s,%s,%s)
            """, params=(
                match_id,
                innings_id,
                bw.get("name"),
                bw.get("overs"),
                bw.get("maidens"),
                bw.get("runs"),
                bw.get("wickets"),
                bw.get("economy"),
                bw.get("id",0)
            ))

        print("# ----- Insert Partnerships -----")
        for p in innings.get("partnership", {}).get("partnership", []):
              #print(p)
              execute(query="""
                INSERT INTO partnerships
                (match_id,innings_id, bat1_name, bat1_runs, bat1_balls, total_runs, total_balls,
                 bat2_name, bat2_runs, bat2_balls,batsman1_id,batsman2_id)
                VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
            """,params= (
                match_id,
                innings_id,
                p.get("bat1name"),
                p.get("bat1runs"),
                p.get("bat1balls"),
                p.get("totalruns"),
                p.get("totalballs"),
                p.get("bat2name"),
                p.get("bat2runs"),
                p.get("bat2balls"),
                p.get('bat1id'),
                p.get('bat2id')
            ))

# %%
list_matches = [
    38362,
    38367,
    38647,
    38652,
    38657,
    38662,
    46499,
    46506,
    46511,
    46518,
    46520,
    56787,
    56789,
    59951,
    59958,
    59960,
    59965,
    59972,
    59979,
    70326,
    70333,
    70340,
    70347,
    70354,
    70361,
    70368,
    112285,
    112297,
    112309,
    112317,
    112385,
    112389
]
for matchid in list_matches:
    try:
        insert_scorecard(matchid)
    except Exception as e:
        print('Error Occured',e)
        break
# Out:
# [{'inningsid': 1, 'batsman': [{'id': 2239, 'balls': 42, 'runs': 12, 'fours': 1, 'sixes': 0, 'strkrate': '28.57', 'name': 'Elgar', 'nickname': '', 'iscaptain': True, 'iskeeper': False, 'outdec': 'c Bairstow b Broad', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 11271, 'balls': 12, 'runs': 3, 'fours': 0, 'sixes': 0, 'strkrate': '25', 'name': 'Sarel Erwee', 'nickname': '', 'iscaptain': False, 'iskeeper': False, 'outdec': 'c Foakes b James Anderson', 'videotype': '', 'videourl': '', 'videoid': 0, 'planid': 0, 'imageid': 0, 'premiumvideourl': '', 'iscbplusfree': False, 'ispremiumfree': False, 'inmatchchange': '', 'isoverseas': False, 'playingxichange': ''}, {'id': 10178, 'balls': 29, 'runs': 21, 'fours': 3, 'sixes': 0, 'strkrate': '72.41', 'name': 'Keegan Petersen', 'nickname': '', 'iscaptain': False, 'iskeeper': False,
# ...

# %%
match_details = {
  "matchDetails": [
    {
      "matchDetailsMap": {
        "key": "Tue, 06 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 70354,
              "seriesId": 6297,
              "seriesName": "West Indies tour of Australia, 2024",
              "matchDesc": "3rd ODI",
              "matchFormat": "ODI",
              "startDate": "1707190200000",
              "endDate": "1707190200000",
              "state": "complete",
              "status": "Australia won by 8 wkts",
              "team1": {
                "teamId": 4,
                "teamName": "AUSTRALIA",
                "teamSName": "AUS",
                "imageId": 776202
              },
              "team2": {
                "teamId": 10,
                "teamName": "WEST INDIES",
                "teamSName": "WI",
                "imageId": 776191
              },
              "venueInfo": {
                "ground": "Manuka Oval",
                "city": "Canberra",
                "timezone": "+11:00"
              },
              "currBatTeamId": 4,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 87,
                  "wickets": 2,
                  "overs": 6.5
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 86,
                  "wickets": 10,
                  "overs": 24.1
                }
              }
            }
          }
        ],
        "seriesId": 6297
      }
    },
    {
      "matchDetailsMap": {
        "key": "Fri, 09 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 70361,
              "seriesId": 6297,
              "seriesName": "West Indies tour of Australia, 2024",
              "matchDesc": "1st T20I",
              "matchFormat": "T20",
              "startDate": "1707465600000",
              "endDate": "1707465600000",
              "state": "complete",
              "status": "Australia won by 11 runs",
              "team1": {
                "teamId": 4,
                "teamName": "AUSTRALIA",
                "teamSName": "AUS",
                "imageId": 776202
              },
              "team2": {
                "teamId": 10,
                "teamName": "WEST INDIES",
                "teamSName": "WI",
                "imageId": 776191
              },
              "venueInfo": {
                "ground": "Bellerive Oval",
                "city": "Hobart",
                "timezone": "+11:00"
              },
              "currBatTeamId": 4,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 213,
                  "wickets": 7,
                  "overs": 20
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 202,
                  "wickets": 8,
                  "overs": 20
                }
              }
            }
          }
        ],
        "seriesId": 6297
      }
    },
    {
      "matchDetailsMap": {
        "key": "Sun, 11 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 70368,
              "seriesId": 6297,
              "seriesName": "West Indies tour of Australia, 2024",
              "matchDesc": "2nd T20I",
              "matchFormat": "T20",
              "startDate": "1707638400000",
              "endDate": "1707638400000",
              "state": "complete",
              "status": "Australia won by 34 runs",
              "team1": {
                "teamId": 4,
                "teamName": "AUSTRALIA",
                "teamSName": "AUS",
                "imageId": 776202
              },
              "team2": {
                "teamId": 10,
                "teamName": "WEST INDIES",
                "teamSName": "WI",
                "imageId": 776191
              },
              "venueInfo": {
                "ground": "Adelaide Oval",
                "city": "Adelaide",
                "timezone": "+10:30"
              },
              "currBatTeamId": 4,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 241,
                  "wickets": 4,
                  "overs": 20
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 207,
                  "wickets": 9,
                  "overs": 20
                }
              }
            }
          }
        ],
        "seriesId": 6297
      }
    },
    {
      "matchDetailsMap": {
        "key": "Tue, 13 Feb 2024",
        "match": [
          {
            "matchInfo": {
              "matchId": 70375,
              "seriesId": 6297,
              "seriesName": "West Indies tour of Australia, 2024",
              "matchDesc": "3rd T20I",
              "matchFormat": "T20",
              "startDate": "1707811200000",
              "endDate": "1707811200000",
              "state": "complete",
              "status": "West Indies won by 37 runs",
              "team1": {
                "teamId": 4,
                "teamName": "AUSTRALIA",
                "teamSName": "AUS",
                "imageId": 776202
              },
              "team2": {
                "teamId": 10,
                "teamName": "WEST INDIES",
                "teamSName": "WI",
                "imageId": 776191
              },
              "venueInfo": {
                "ground": "Perth Stadium",
                "city": "Perth",
                "timezone": "+08:00"
              },
              "currBatTeamId": 10,
              "isTimeAnnounced": True
            },
            "matchScore": {
              "team1Score": {
                "inngs1": {
                  "inningsId": 2,
                  "runs": 183,
                  "wickets": 5,
                  "overs": 20
                }
              },
              "team2Score": {
                "inngs1": {
                  "inningsId": 1,
                  "runs": 220,
                  "wickets": 6,
                  "overs": 20
                }
              }
            }
          }
        ],
        "seriesId": 6297
      }
    }
  ],
  "appIndex": {
    "seoTitle": "West Indies tour of Australia, 2024 live scores, schedule and results - Cricbuzz | Cricbuzz.com",
    "webURL": "www.cricbuzz.com/cricket-series/"
  }
}

# %%
import requests
from datetime import datetime
import pandas as pd

def convert_to_int(stringNumber):
    try:
        return int(stringNumber)
    except Exception as e:
        return 0
    
    
def get_match_details(series_id):
    url = f"https://cricbuzz-cricket.p.rapidapi.com/series/v1/{series_id}"
    print(url)
    headers = {
        "x-rapidapi-key": "096090eac4mshd73dfcde8a35834p1911efjsn4dcdb491bdcc",
        "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
      }
    try:
        response = requests.get(url, headers=headers)
       # print(response.json())
        return response.json()
    
    except Exception as ex:
        print(ex)
        return {}
    

series_id_list = [6652] # ,,,,,]
need_break = False
for series_id in series_id_list:
  print(series_id)
  if(need_break== True):
      break
  for mathcDetails in get_match_details(series_id).get('matchDetails',[]):
      if(need_break == True):
          break
      for i in mathcDetails.get('matchDetailsMap',{}).get('match',[]):
        if(need_break == True):
          break
        try:
            match_info = i.get('matchInfo',{})
            
            match_id        = match_info.get('matchId','')
            match_desc      = match_info.get('matchDesc', '')
            match_format    = match_info.get('matchFormat', '')
            start_date      = match_info.get('startDate', '')
            
            team1           = match_info.get('team1', {})
            team1_name      = team1.get('teamName')
            
            team2           = match_info.get('team2', {})
            team2_name      = team2.get('teamName', '')
            
            state           = match_info.get('state', '')
            
            venue_info      = match_info.get('venueInfo', {})
            venue           = venue_info.get('ground', '')
            city            = venue_info.get('city', '')
            status          = match_info.get('status', '')

            match_parameters = (
                match_id, match_desc, team1_name, team2_name,
                venue, datetime.fromtimestamp(float(start_date) / 1000.0),state,match_format
            )

            print("inserting mathces record.....",match_id)
            insert_query = """
                INSERT INTO matches
                (match_id, match_description, team_1_name, team_2_name, venue_name, match_date, match_state,match_format)
                VALUES (%s, %s, %s, %s, %s, %s, %s,%s) ON CONFLICT DO NOTHING;
            """
            print("inserting mathces record.....",match_parameters)
            execute(query=insert_query, params=match_parameters)
            print("Successfully inserted....")
            # -----------------------------------------------
            # EXTRACT matchheaders (flatten dict)
            # -----------------------------------------------
            
            url = f"https://cricbuzz-cricket.p.rapidapi.com/mcenter/v1/{match_id}/leanback"

            headers = {
                "x-rapidapi-key": "096090eac4mshd73dfcde8a35834p1911efjsn4dcdb491bdcc",
                "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
            }

            response = requests.get(url, headers=headers)
            
            data = response.json()
            headers_df = pd.json_normalize(data["matchheaders"], sep="__")
            headers_df = headers_df[['winningteamid','tossresults__tosswinnerid','tossresults__tosswinnername','tossresults__decision','status']]
            headers_df["victory_type"] = headers_df["status"].apply(lambda x: "runs" if "runs" in x.lower() else "wickets" )
            headers_df["victory_margin"] = headers_df["status"].str.extract(r'(\d+)').astype(float)
            headers_df = headers_df[['winningteamid','tossresults__tosswinnerid','tossresults__tosswinnername','tossresults__decision','victory_type','victory_margin']]
            #  print(headers_df.head())
            create_mc_heaers_query =   """ CREATE TABLE  if not exists match_headers  (
                match_id BIGINT,
                winning_team_id BIGINT,
                toss_winner_id BIGINT,
                toss_winner_name VARCHAR(200),
                toss_decision VARCHAR(20),
                victory_type VARCHAR(20),
                victory_margin int
            );"""

            #execute(query=create_mc_heaers_query)
            # Extract first row
            row = headers_df.iloc[0]
            #print(row)
            match_header_insert_query = """
            INSERT INTO match_headers (
                match_id,
                winning_team_id,
                toss_winner_id,
                toss_winner_name,
                toss_decision,
                victory_type,
                victory_margin
            )
            VALUES (%s, %s, %s, %s, %s,%s,%s) ON CONFLICT DO NOTHING;
            """

            mhparams = (
                convert_to_int(match_id),
                convert_to_int(row["winningteamid"]),
                convert_to_int(row["tossresults__tosswinnerid"]),
                row["tossresults__tosswinnername"],
                row["tossresults__decision"],
                row["victory_type"],
                convert_to_int(row["victory_margin"])
            )

            execute(query=match_header_insert_query, params=mhparams)

            inningsscores = data.get("miniscore", {}).get("inningsscores", {})
            innings_list = inningsscores.get("inningsscore", [])

            flat_innings = []

            for entry in innings_list:
                row = {}
                for key, value in entry.items():

                    if isinstance(value, (str, int, float, bool)):
                        row[key] = value

                    elif isinstance(value, dict):
                        for nk, nv in value.items():
                            row[f"{key}_{nk}"] = nv
                    elif isinstance(value, list):
                        row[key] = str(value)
                flat_innings.append(row)
            innings_score_df = pd.DataFrame(flat_innings)

            # Add matchId column
            innings_score_df['matchId'] = match_id

            innings_score_df = innings_score_df[['inningsid', 'batteamid', 'runs', 'wickets', 'overs', 'matchId']]
            innings_score_create_query = """CREATE TABLE if not exists innings_score (
            id SERIAL PRIMARY KEY,
            inningsid int,
            batteamid int,
            runs int,
            wickets int,
            overs DECIMAL(5,2),
            match_id int
            )"""
            
            
            #execute(query=innings_score_create_query)
            # -----------------------------------------------
            # INSERT INTO innings_score TABLE
            # -----------------------------------------------
            insert_innings_query = """
                INSERT INTO innings_score
                (inningsid, batteamid, runs, wickets, overs, match_id)
                VALUES (%s, %s, %s, %s, %s, %s) ON CONFLICT DO NOTHING;

            """
            print("entering the df iterrows....")
            #print(innings_score_df)
            for _, row in innings_score_df.iterrows():
                #print("-----",row)
                inn_params = (convert_to_int(row["inningsid"]),
                                convert_to_int(row["batteamid"]),
                                convert_to_int(row["runs"]),
                                convert_to_int(row["wickets"]),
                                float(row["overs"]),
                                convert_to_int(row["matchId"])
                                )
                execute(query=insert_innings_query, params=inn_params)
            
            insert_scorecard(match_id)
        except Exception as e:
                print("Exception occurred",e)
                need_break = True
                break
# Out:
# 6652
# https://cricbuzz-cricket.p.rapidapi.com/series/v1/6652
# inserting mathces record..... 73642
# inserting mathces record..... (73642, '2-day Practice Match', 'SRI LANKA CRICKET PRESIDENTS XI', 'PAKISTAN', 'Mahinda Rajapaksa International Stadium', datetime.datetime(2023, 7, 11, 9, 30), 'complete', 'TEST')
# Successfully inserted....
# entering the df iterrows....
# ...

# %%
import requests
def rename_stat_columns(columns):
    rename_map = {
        "50s": "fifty",
        "100s": "hundred",
        "200s": "double_hundred",
        "300s": "triple_hundred",
        "400s": "quadraple_hundred"
    }

    new_columns = []
    for col in columns:
        if col in rename_map:
            new_columns.append(rename_map[col])
        else:
            new_columns.append(col)

    return new_columns

def insert_bat_stat_to_db(headers, values, player_id):
    formats = headers[1:]  # Test, ODI, T20, IPL
    stats = values         # rows: Matches, Runs, Avg, SR...

    # Create a dict structure:
    format_rows = {fmt: {} for fmt in formats}

    for stat_row in stats:
        stat_name = stat_row[0]

        # Fill each format with its corresponding stat
        for i, fmt in enumerate(formats, start=1):
            format_rows[fmt][stat_name] = stat_row[i]

    # Now generate SQL insert statements
    sql_statements = []
    for fmt in formats:
        cols = ["player_id", "format"] + [s[0] for s in stats]
        vals = [player_id, fmt] + [format_rows[fmt][s[0]] for s in stats]
        cols = rename_stat_columns(cols)
        # Build SQL
        print('2',cols)
        col_str = ", ".join(cols)
        val_str = ", ".join(f"'{v}'" for v in vals)

        sql = f"INSERT INTO player_career_batting_stats VALUES ({val_str});"
        print(sql)
        result = execute(sql)
        if result :
            print("inserted successfully")

def get_batting_stats(player_id):
    batting_stats_url = f"https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/{player_id}/batting"

    headers = {
                "x-rapidapi-key": "096090eac4mshd73dfcde8a35834p1911efjsn4dcdb491bdcc",
                "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
            }
    
    try:
        response = requests.get(batting_stats_url, headers=headers)
        response.raise_for_status()
        return response.json()
        
    except Exception as e:
        print("Exception occurred:", e)
        return {}


player_id_list = [25
,1413
,104
,38
,102
,101
,35
,213
,576
,29]
for player_id in player_id_list:
  try:
    batting_career_stats = get_batting_stats(player_id)
    headers = batting_career_stats["headers"] 
    values = [item['values'] for item in batting_career_stats["values"]]
    insert_bat_stat_to_db(headers,values,player_id)
  except Exception as ex:
    print('Exception Occurred ',player_id_list,'---',ex)
    break
# Out:
# 2 ['player_id', 'format', 'Matches', 'Innings', 'Runs', 'Balls', 'Highest', 'Average', 'SR', 'Not Out', 'Fours', 'Sixes', 'Ducks', 'fifty', 'hundred', 'double_hundred', 'triple_hundred', 'quadraple_hundred']
# INSERT INTO player_career_batting_stats VALUES ('25', 'Test', '200', '329', '15921', '29437', '248', '53.79', '54.09', '33', '2058', '69', '14', '68', '51', '6', '0', '0');
# inserted successfully
# 2 ['player_id', 'format', 'Matches', 'Innings', 'Runs', 'Balls', 'Highest', 'Average', 'SR', 'Not Out', 'Fours', 'Sixes', 'Ducks', 'fifty', 'hundred', 'double_hundred', 'triple_hundred', 'quadraple_hundred']
# INSERT INTO player_career_batting_stats VALUES ('25', 'ODI', '463', '452', '18426', '21367', '200', '44.83', '86.24', '41', '2016', '195', '20', '96', '49', '1', '0', '0');
# inserted successfully
# ...

# %%
import requests
def rename_stat_columns(columns):
      rename_map = {
          "4w": "four_wickets",
          "5w": "five_wickets",
          "10w": "ten_wickets",
      }

      new_columns = []
      for col in columns:
          if col in rename_map:
              new_columns.append(rename_map[col])
          else:
              new_columns.append(col)

      return new_columns
def insert_to_db(headers, values, player_id):
      formats = headers[1:]  
      stats = values         

      
      format_rows = {fmt: {} for fmt in formats}

      for stat_row in stats:
          stat_name = stat_row[0]

          
          for i, fmt in enumerate(formats, start=1):
              format_rows[fmt][stat_name] = stat_row[i]

      
      sql_statements = []
      for fmt in formats:
          cols = ["player_id", "format"] + [s[0] for s in stats]
          vals = [player_id, fmt] + [format_rows[fmt][s[0]] for s in stats]
          cols = rename_stat_columns(cols)
          col_str = ", ".join(cols)
          val_str = ", ".join(f"'{v}'" for v in vals)
          
          sql = f"INSERT INTO player_career_bowling_stats VALUES ({val_str});"
          execute(sql)

def get_bowling_stats(player_id):
    bowling_stats_url = f"https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/{player_id}/bowling"
    headers = {
                "x-rapidapi-key": "0cad569e6emshfa7ed7dfb84ec66p1f382bjsn4416e1d60dc5",
                "x-rapidapi-host": "cricbuzz-cricket.p.rapidapi.com"
            }
    try:
        response = requests.get(bowling_stats_url, headers=headers)
        response.raise_for_status()
        return response.json()
        
    except Exception as e:
        print("Exception occurred:", e)
        return {}

player_id_list = [8808,9647,587,7662,6557,10100,14565,1629,8313,7736]
for player_id in player_id_list:
  try:
    bowling_career_stats = get_bowling_stats(player_id)
    headers = bowling_career_stats["headers"] 
    values = [item['values'] for item in bowling_career_stats["values"]]
    insert_to_db(headers,values,player_id)
  except Exception as ex:
    print('Exception Occurred ',player_id_list,'---',ex)
    break
# Out:
# Exception occurred: 429 Client Error: Too Many Requests for url: https://cricbuzz-cricket.p.rapidapi.com/stats/v1/player/7736/bowling
# Exception Occurred  [8808, 9647, 587, 7662, 6557, 10100, 14565, 1629, 8313, 7736] --- 'headers'
